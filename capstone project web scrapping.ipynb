# %% [markdown]
# # Scrapping Buy Properties data

# %%
import selenium
import pandas as pd

# %%
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import csv

# %%
#opening the naukari page on automated chrome browser
driver=webdriver.Chrome()
driver.get('https://www.redfin.com/')
driver.maximize_window()

# %%
from selenium import webdriver

# %%
buy=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div/div/header[2]/div[2]/div[1]")
buy.click()

# %%
chicago=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div[2]/div/div[1]/div[3]/div[2]/a")
chicago.click()

# %%
table=driver.find_element(By.XPATH,"/html/body/div[1]/div[8]/div[1]/div[2]/div[1]/div[2]/div/div/div/div[2]/div[2]/ul/li[2]/span")
table.click()

# %%
address_name=[]
location_name=[]
price_name=[]
beds_name=[]
baths_name=[]
sqft_name=[]
ppsqft_name=[]
balcony_name=[]
propertytype_name=[]

# %%
address_name
# Out:
# []

# %%
baths_name.clear()
sqft_name.clear()
address_name.clear()
price_name.clear()
beds_name.clear()
baths_name.clear()
address_name.clear()

# %%
Chicago------------

# %%
start=0
end=2
for page in range(start,end):
    price_tag = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in price_tag:
        price_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-af67c41d74c5> in <module>
#       4     price_tag = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
#       5     for i in price_tag:
# ----> 6         price_name.append(i.text)
#       7     next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
#       8     next_button.click()
#
# NameError: name 'price_name' is not defined

# %%
len(price_name)
# Out:
# 80

# %%
price_name
# Out:
# ['$459,000',
#  '$1,149,000',
#  '$469,999',
#  '$385,000',
#  '$250,000',
#  '$229,900',
#  '$335,000',
#  '$375,000',
#  '$375,000',
#  '$950,000',
#  '$220,000',
#  '$215,000',
#  '$739,000',
#  '$319,900',
#  '$369,900',
#  '$175,000',
#  '$235,000',
#  '$995,000',
#  '$269,000',
#  '$399,900',
#  '$790,000',
#  '$230,000',
#  '$2,599,000',
#  '$379,999',
#  '$340,000',
#  '$299,999',
#  '$790,000',
#  '$600,000',
#  '$239,900',
#  '$360,000',
#  '$325,000',
#  '$705,000',
#  '$360,000',
#  '$479,000',
#  '$199,000',
#  '$280,000',
#  '$310,000',
#  '$300,000',
#  '$379,000',
#  '$140,000',
#  '$328,900',
#  '$449,900',
#  '$229,999',
#  '$389,900',
#  '$129,000',
#  '$369,900',
#  '$805,000',
#  '$380,000',
#  '$674,800',
#  '$180,000',
#  '$250,000',
#  '$429,900',
#  '$400,000',
#  '$319,900',
#  '$699,000',
#  '$325,000',
#  '$225,000',
#  '$24,000',
#  '$379,900',
#  '$430,000',
#  '$375,000',
#  '$249,900',
#  '$284,999',
#  '$219,900',
#  '$129,000',
#  '$649,770',
# ...

# %%
# scrapping beds
beds_tag=driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
for i in beds_tag:
    beds=(i.text)
    beds_name.append(beds)

# %%
start=0
end=2
for page in range(start,end):
    beds_tag = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag:
        beds_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name
# Out:
# ['2 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '5 beds',
#  '7 beds',
#  '5 beds',
#  '5 beds',
#  '5 beds',
#  '3 beds',
#  '6 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '6 beds',
#  '2 beds',
#  '2 beds',
#  '5 beds',
#  '4 beds',
#  '5 beds',
#  '2 beds',
#  '6 beds',
#  '4 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '5 beds',
#  '1 bed',
#  '5 beds',
#  '2 beds',
#  '4 beds',
#  '5 beds',
#  '7 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '5 beds',
#  '4 beds',
#  '1 bed',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '9 beds',
#  '6 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '8 beds',
#  '6 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '8 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '4 beds',
# ...

# %%
len(beds_name)
# Out:
# 80

# %%
start=0
end=2
for page in range(start,end):
    baths_tag = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in baths_tag:
        baths_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
len(baths_name)
# Out:
# 80

# %%
baths_name
# Out:
# ['2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '5 baths',
#  '3.5 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '1.5 baths',
#  '3 baths',
#  '3 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '3.5 baths',
#  '1 bath',
#  '2 baths',
#  '3 baths',
#  '2.5 baths']

# %%
# scrapping sqft
start=0
end=2
for page in range(start,end):
    sqft_tag = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__LockedStat--value"]')
    for i in sqft_tag:
        sqft_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name
# Out:
# ['1,914',
#  '3,720',
#  '1,330',
#  '6,250',
#  '3,900',
#  '2,905',
#  '4,000',
#  '3,000',
#  '4,500',
#  '3,779',
#  '—',
#  '3,484',
#  '—',
#  '1,550',
#  '—',
#  '3,750',
#  '—',
#  '2,613',
#  '957',
#  '—',
#  '6,250',
#  '1,800',
#  '3,075',
#  '625',
#  '1,700',
#  '4,125',
#  '—',
#  '1,103',
#  '3,639',
#  '5,000',
#  '2,070',
#  '1,300',
#  '1,644',
#  '—',
#  '3,049',
#  '—',
#  '3,049',
#  '1,900',
#  '3,750',
#  '750',
#  '600',
#  '1,667',
#  '1,000',
#  '1,550',
#  '—',
#  '2,200',
#  '1,375',
#  '800',
#  '1,200',
#  '—',
#  '1,800',
#  '728',
#  '4,230',
#  '8,276',
#  '650',
#  '3,900',
#  '850',
#  '2,000',
#  '2,216',
#  '7,405',
#  '3,700',
#  '9,104',
#  '1,212',
#  '4,791',
#  '600',
#  '3,598',
#  '4,312',
#  '1,240',
#  '800',
#  '1,500',
#  '3,300',
#  '—',
#  '8,000',
#  '2,574',
#  '1,546',
#  '3,920',
#  '730',
#  '1,986',
#  '3,750',
#  '3,500',
#  '1,200',
#  '4,000',
#  '1,150',
#  '1,150',
#  '2,005',
#  '1,400',
#  '—',
#  '4,791',
#  '—',
# ...

# %%
del sqft_name[80]

# %%
len(sqft_name)
# Out:
# 80

# %%
# scrapping address
start=0
end=2
for page in range(start,end):
    address_tag = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag:
        address_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
 address_name
# Out:
# ['',
#  '',
#  '5349 W Grace St, Chicago, IL 60641',
#  '835 N Wood St Unit 102-202, Chicago, IL 60622',
#  '1732 W 19th St #2, Chicago, IL 60608',
#  '3110 W Berteau Ave #1, Chicago, IL 60618',
#  '802 Dobson St #1, Evanston, IL 60202',
#  '700 E 51st St Unit 2W, Chicago, IL 60615',
#  '2624 W 83rd St, Chicago, IL 60652',
#  '1111 S Wabash Ave #2501, Chicago, IL 60605',
#  '7910 S Greenwood Ave, Chicago, IL 60619',
#  '3915 N Monticello Ave, Chicago, IL 60618',
#  '1000 E 53rd St Unit 519S, Chicago, IL 60615',
#  '2909 N Sheridan Rd #1607, Chicago, IL 60657',
#  '1322 S Wabash Ave Ph 6, Chicago, IL 60605',
#  '2057 W Fargo Ave #1, Chicago, IL 60645',
#  '2908 N Halsted St #1, Chicago, IL 60657',
#  '2421 W Fitch Ave #2, Chicago, IL 60645',
#  '1210 W 109th St, Chicago, IL 60643',
#  '3111 N Lincoln Ave, Chicago, IL 60657',
#  '832 W Oakdale Ave Unit 1G, Chicago, IL 60657',
#  '565 W Quincy St #1508, Chicago, IL 60661',
#  '2130 W Farragut Ave, Chicago, IL 60625',
# ...

# %%
del address_name[0:-1]

# %%
ppsqft_name.pop(80)
# Out:
# '$226'

# %%
len(ppsqft_name)
# Out:
# 80

# %%
# scrapping ppsqft
start=0
end=2
for page in range(start,end):
    ppsqft_tag = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag:
        ppsqft_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
len(ppsqft_name)
# Out:
# 82

# %%
ppsqft_name
# Out:
# ['—',
#  '$239',
#  '$339',
#  '$84',
#  '$268',
#  '$167',
#  '$266',
#  '$433',
#  '$102',
#  '$197',
#  '—',
#  '$280',
#  '$152',
#  '—',
#  '$397',
#  '—',
#  '$230',
#  '$1,110',
#  '$361',
#  '—',
#  '$227',
#  '$438',
#  '$85',
#  '$229',
#  '—',
#  '$394',
#  '—',
#  '$150',
#  '—',
#  '—',
#  '$388',
#  '$712',
#  '$287',
#  '$410',
#  '$119',
#  '$254',
#  '$269',
#  '$326',
#  '—',
#  '—',
#  '$288',
#  '$447',
#  '—',
#  '—',
#  '$277',
#  '$204',
#  '$196',
#  '$159',
#  '$294',
#  '$177',
#  '—',
#  '$405',
#  '$892',
#  '$344',
#  '$292',
#  '$314',
#  '—',
#  '—',
#  '$283',
#  '$175',
#  '—',
#  '—',
#  '$225',
#  '$238',
#  '—',
#  '—',
#  '$415',
#  '$233',
#  '$514',
#  '$859',
#  '$261',
#  '—',
#  '—',
#  '—',
#  '$302',
#  '$466',
#  '$186',
#  '$183',
#  '—',
#  '$113',
#  '$226',
#  '$288']

# %%
# scrapping balcony
start=0
end=2
for page in range(start,end):
    balcony_tag = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in balcony_tag:
        balcony_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(address_name),len(price_name),len(beds_name),len(baths_name),len(sqft_name),len(ppsqft_name))
# Out:
# 80 80 80 80 80 80

# %%
# scrapping property type
start=0
end=2
for page in range(start,end):
    property_tag = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in property_tag:
        property_name.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
import pandas as pd
df=pd.DataFrame({'Address':address_name,'Price':price_name,'Beds':beds_name,'Baths':baths_name,'Total sqft':sqft_name,'Price per sqft':ppsqft_name})
df
# Out:
#                                           Address       Price    Beds  \
# 0                                                    $459,000  2 beds
# 1                                                  $1,149,000  3 beds
# 2              5349 W Grace St, Chicago, IL 60641    $469,999  2 beds
# 3   835 N Wood St Unit 102-202, Chicago, IL 60622    $385,000  3 beds
# 4            1732 W 19th St #2, Chicago, IL 60608    $250,000  2 beds
# ..                                            ...         ...     ...
# 75           7120 S Vernon Ave, Chicago, IL 60619    $405,000  4 beds
# 76        2904 N Francisco Ave, Chicago, IL 60618    $420,000  4 beds
# 77         6816 S Komensky Ave, Chicago, IL 60629    $550,000  4 beds
# 78     2001 S Calumet Ave #305, Chicago, IL 60616    $200,000  5 beds
# 79        5220 W Patterson Ave, Chicago, IL 60641    $699,000  2 beds
#
#         Baths Total sqft Price per sqft
# 0     2 baths      1,914              —
# 1     2 baths      3,720           $239
# ...

# %%
df
# Out:
#     Srno                                        Address       Price    Beds  \
# 0      0             5341 W Grace St, Chicago, IL 60641    $459,000  2 beds
# 1      1  825 N Wood St Unit 102-202, Chicago, IL 60622  $1,149,000  3 beds
# 2      2             5349 W Grace St, Chicago, IL 60641    $469,999  2 beds
# 3      3  835 N Wood St Unit 102-202, Chicago, IL 60622    $385,000  3 beds
# 4      4           1732 W 19th St #2, Chicago, IL 60608    $250,000  2 beds
# ..   ...                                            ...         ...     ...
# 75    75           7120 S Vernon Ave, Chicago, IL 60619    $405,000  4 beds
# 76    76        2904 N Francisco Ave, Chicago, IL 60618    $420,000  4 beds
# 77    77         6816 S Komensky Ave, Chicago, IL 60629    $550,000  4 beds
# 78    78     2001 S Calumet Ave #305, Chicago, IL 60616    $200,000  5 beds
# 79    79        5220 W Patterson Ave, Chicago, IL 60641    $699,000  2 beds
#
# ...

# %%
--------------Seattle, WA homes------------

# %%
seattle=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div[2]/div/div[1]/div[5]/div[2]/a")
seattle.click()

# %%
address_name1=[]
location_name1=[]
price_name1=[]
beds_name1=[]
baths_name1=[]
sqft_name1=[]
ppsqft_name1=[]

# %%
del next_button

# %%
price_name1=[]

# %%
# scrapping price type
start=0
end=2
for page in range(start,end):
    price_tag1 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag1:
        price_name1.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name1
# Out:
# ['$535,000',
#  '$850,000',
#  '$780,000',
#  '$425,000',
#  '$488,500',
#  '$985,000',
#  '$299,950',
#  '$899,999',
#  '$999,995',
#  '$675,000',
#  '$870,000',
#  '$399,000',
#  '$489,999',
#  '$500,000',
#  '$1,275,000',
#  '$674,000',
#  '$985,000',
#  '$470,000',
#  '$1,295,000',
#  '$2,550,000',
#  '$399,000',
#  '$724,900',
#  '$695,000',
#  '$549,950',
#  '$1,995,000',
#  '$559,950',
#  '$985,000',
#  '$975,000',
#  '$649,000',
#  '$699,950',
#  '$2,150,000',
#  '$969,000',
#  '$274,000',
#  '$612,000',
#  '$1,300,000',
#  '$712,500',
#  '$1,595,000',
#  '$669,000',
#  '$870,000',
#  '$540,000',
#  '$535,000',
#  '$850,000',
#  '$780,000',
#  '$425,000',
#  '$488,500',
#  '$985,000',
#  '$299,950',
#  '$899,999',
#  '$999,995',
#  '$675,000',
#  '$870,000',
#  '$399,000',
#  '$489,999',
#  '$500,000',
#  '$1,275,000',
#  '$674,000',
#  '$985,000',
#  '$470,000',
#  '$1,295,000',
#  '$2,550,000',
#  '$399,000',
#  '$724,900',
#  '$695,000',
#  '$549,950',
#  '$1,995,000',
# ...

# %%
len(price_name1)
# Out:
# 80

# %%
# scrapping beds
start=0
end=2
for page in range(start,end):
    beds_tag1 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag1:
        beds_name1.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name1
# Out:
# ['3 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '4 beds',
#  '4 beds',
#  '2 beds',
#  '1 bed',
#  '5 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '5 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '5 beds',
#  '3 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '5 beds']

# %%
len(beds_name1)
# Out:
# 80

# %%
# scrapping baths
start=0
end=2
for page in range(start,end):
    baths_tag1=driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag1:
        baths_name1.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_name1
# Out:
# ['2.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '1 bath',
#  '3 baths',
#  '1 bath',
#  '2 baths',
#  '3.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '4 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '3 baths',
#  '3 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '3 baths',
#  '3.5 baths']

# %%
len(baths_name1)
# Out:
# 80

# %%
sqft_name1=[]
# scrapping sqft
start=0
end=2
for page in range(start,end):
    sqft_tag1=driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__LockedStat--value"]')
    for i in sqft_tag1:
        sqft_name1.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name1
# Out:
# ['889',
#  '1,225',
#  '1,470',
#  '958',
#  '729',
#  '643',
#  '1,980',
#  '1,873',
#  '383',
#  '1,760',
#  '3,028',
#  '2,360',
#  '3,062',
#  '1,350',
#  '5,120',
#  '1,540',
#  '4,250',
#  '904',
#  '740',
#  '795',
#  '2,780',
#  '8,400',
#  '800',
#  '5,250',
#  '1,950',
#  '8,300',
#  '854',
#  '2,830',
#  '4,000',
#  '3,790',
#  '5,100',
#  '716',
#  '1,182',
#  '907',
#  '1,090',
#  '928',
#  '1,141',
#  '3,071',
#  '3,751',
#  '925',
#  '458',
#  '1,208',
#  '2,510',
#  '3,880',
#  '832',
#  '4,898',
#  '1,220',
#  '824',
#  '3,680',
#  '5,100',
#  '1,510',
#  '2,386',
#  '446',
#  '1,620',
#  '6,600',
#  '2,669',
#  '3,000',
#  '1,742',
#  '6,138',
#  '1,588',
#  '3,840',
#  '1,400',
#  '1,000',
#  '1,760',
#  '4,141',
#  '888',
#  '1,040',
#  '1,848',
#  '1',
#  '1,080',
#  '726',
#  '654',
#  '1,475',
#  '760',
#  '1,221',
#  '6,038',
#  '1,285',
#  '1,900',
#  '6,120',
#  '3,630',
#  '4,009',
#  '3,930',
#  '6,000',
#  '2,766',
#  '4,205',
#  '1,504',
#  '1,306',
# ...

# %%
len(sqft_name1)
# Out:
# 135

# %%
del sqft_tag1

# %%
ppsqft_name1=[]

# %%
# scrapping price per ppsqft
start=0
end=2
for page in range(start,end):
    ppsqft_tag1=driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag1:
        ppsqft_name1.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name1
# Out:
# ['$602',
#  '$694',
#  '$531',
#  '$583',
#  '$760',
#  '$497',
#  '$783',
#  '$511',
#  '$424',
#  '$500',
#  '$565',
#  '$441',
#  '$662',
#  '$629',
#  '$459',
#  '$843',
#  '$505',
#  '$550',
#  '$458',
#  '$673',
#  '$557',
#  '$613',
#  '$638',
#  '$482',
#  '$650',
#  '$605',
#  '$815',
#  '$388',
#  '$780',
#  '$574',
#  '$584',
#  '$642',
#  '$614',
#  '$378',
#  '$487',
#  '$409',
#  '$1,004',
#  '$478',
#  '$494',
#  '$608',
#  '$573',
#  '$313',
#  '$758',
#  '$537',
#  '$933',
#  '$454',
#  '$719',
#  '$506',
#  '$513',
#  '$385',
#  '$730',
#  '$649',
#  '$758',
#  '$874',
#  '$503',
#  '$403',
#  '$1,252',
#  '$1,545',
#  '$634',
#  '$408',
#  '$437',
#  '$503',
#  '$353',
#  '$546',
#  '$374',
#  '$640',
#  '$494',
#  '$551',
#  '$441',
#  '$554',
#  '$698',
#  '$549',
#  '$633',
#  '$661',
#  '$462',
#  '$572',
#  '$695',
#  '$474',
#  '$631',
#  '$606',
#  '$738',
#  '$573']

# %%
len(ppsqft_name1)
# Out:
# 82

# %%
# scrapping address
start=0
end=2
for page in range(start,end):
    address_tag1=driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag1:
        address_name1.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
# scrapping address
address_tag1=driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
for i in address_tag1:
    address1=(i.text)
    address_name1.append(address1)

# %%
 address_name1
# Out:
# ['',
#  '9518 Interlake Ave N, Seattle, WA 98103',
#  '1817 24th Ave Unit A, Seattle, WA 98122',
#  '2206 28th Ave W, Seattle, WA 98199',
#  '912 Martin Luther King Jr Way S, Seattle, WA 98144',
#  '4245 NE 89th St, Seattle, WA 98115',
#  '6755 25th Ave NW, Seattle, WA 98117',
#  '4539 21st Ave SW, Seattle, WA 98106',
#  '2904 W Bertona St, Seattle, WA 98199',
#  '2911 2nd Ave #319, Seattle, WA 98121',
#  '2420 Westlake Ave N #11, Seattle, WA 98109',
#  '9071 Matthews Ave NE, Seattle, WA 98115',
#  '7500 D 15th Ave NW, Seattle, WA 98117',
#  '2033 11th Ave E, Seattle, WA 98102',
#  '8418 46th Ave SW, Seattle, WA 98136',
#  '919 2nd Ave W #205, Seattle, WA 98119',
#  '7101 Highland Park Way SW, Seattle, WA 98106',
#  '4457 50th Ave SW, Seattle, WA 98116',
#  '4220 Evanston Ave N Unit A, Seattle, WA 98103',
#  '1770 19th Ave S Unit C, Seattle, WA 98144',
#  '12021 64th Ave S, Seattle, WA 98178',
#  '2101 3rd Ave W, Seattle, WA 98119',
#  '2440 Western Ave #513, Seattle, WA 98121',
# ...

# %%
len( address_name1)
# Out:
# 82

# %%
print(len(address_name1),len(price_name1),len(beds_name1),len(baths_name1),len(sqft_name1),len(ppsqft_name1))
# Out:
# 80 80 80 80 80 80

# %%
del address_name1[80]

# %%
import pandas as pd
df1=pd.DataFrame({'Address':address_name1,'Price':price_name1,'Beds':beds_name1,'Baths':baths_name1,'Total sqft':sqft_name1,'Price per sqft':ppsqft_name1})
df1
# Out:
#                                               Address       Price    Beds  \
# 0                                                        $535,000  2 beds
# 1             9518 Interlake Ave N, Seattle, WA 98103    $850,000  3 beds
# 2             1817 24th Ave Unit A, Seattle, WA 98122    $780,000  3 beds
# 3                  2206 28th Ave W, Seattle, WA 98199    $425,000  3 beds
# 4   912 Martin Luther King Jr Way S, Seattle, WA 9...    $488,500  2 beds
# ..                                                ...         ...     ...
# 75         10764 Sand Point Way NE, Seattle, WA 98125  $2,225,000  3 beds
# 76                  960 NW 96th St, Seattle, WA 98117  $1,190,000  2 beds
# 77           960 NW 96th St Unit B, Seattle, WA 98117    $990,000  2 beds
# 78          827 Hiawatha Pl S #612, Seattle, WA 98144    $330,000  3 beds
# 79                  147 NE 52nd St, Seattle, WA 98105    $474,500  3 beds
#
#         Baths Total sqft Price per sqft
# ...

# %%
df1.to_csv('file2.csv')

# %%
df1=pd.read_csv('file2.csv')
df1
# Out:
#     Srno                                            Address       Price  \
# 0      0            1813 24th Ave Unit A, Seattle, WA 98122    $535,000
# 1      1            9518 Interlake Ave N, Seattle, WA 98103    $850,000
# 2      2            1817 24th Ave Unit A, Seattle, WA 98122    $780,000
# 3      3                 2206 28th Ave W, Seattle, WA 98199    $425,000
# 4      4  912 Martin Luther King Jr Way S, Seattle, WA 9...    $488,500
# ..   ...                                                ...         ...
# 75    75         10764 Sand Point Way NE, Seattle, WA 98125  $2,225,000
# 76    76                  960 NW 96th St, Seattle, WA 98117  $1,190,000
# 77    77           960 NW 96th St Unit B, Seattle, WA 98117    $990,000
# 78    78          827 Hiawatha Pl S #612, Seattle, WA 98144    $330,000
# 79    79                  147 NE 52nd St, Seattle, WA 98105    $474,500
#
#       Beds      Baths Total sqft Price per sqft
# 0   2 beds    2 baths        889           $602
# ...

# %%
df1
# Out:
#     Srno                                            Address       Price  \
# 0      0            1813 24th Ave Unit A, Seattle, WA 98122    $535,000
# 1      1            9518 Interlake Ave N, Seattle, WA 98103    $850,000
# 2      2            1817 24th Ave Unit A, Seattle, WA 98122    $780,000
# 3      3                 2206 28th Ave W, Seattle, WA 98199    $425,000
# 4      4  912 Martin Luther King Jr Way S, Seattle, WA 9...    $488,500
# ..   ...                                                ...         ...
# 75    75         10764 Sand Point Way NE, Seattle, WA 98125  $2,225,000
# 76    76                  960 NW 96th St, Seattle, WA 98117  $1,190,000
# 77    77           960 NW 96th St Unit B, Seattle, WA 98117    $990,000
# 78    78          827 Hiawatha Pl S #612, Seattle, WA 98144    $330,000
# 79    79                  147 NE 52nd St, Seattle, WA 98105    $474,500
#
#       Beds      Baths Total sqft Price per sqft
# 0   2 beds    2 baths        889           $602
# ...

# %%
df=pd.read_csv('file1.csv')
df
# Out:
#     Srno                                        Address       Price    Beds  \
# 0      0             5341 W Grace St, Chicago, IL 60641    $459,000  2 beds
# 1      1  825 N Wood St Unit 102-202, Chicago, IL 60622  $1,149,000  3 beds
# 2      2             5349 W Grace St, Chicago, IL 60641    $469,999  2 beds
# 3      3  835 N Wood St Unit 102-202, Chicago, IL 60622    $385,000  3 beds
# 4      4           1732 W 19th St #2, Chicago, IL 60608    $250,000  2 beds
# ..   ...                                            ...         ...     ...
# 75    75           7120 S Vernon Ave, Chicago, IL 60619    $405,000  4 beds
# 76    76        2904 N Francisco Ave, Chicago, IL 60618    $420,000  4 beds
# 77    77         6816 S Komensky Ave, Chicago, IL 60629    $550,000  4 beds
# 78    78     2001 S Calumet Ave #305, Chicago, IL 60616    $200,000  5 beds
# 79    79        5220 W Patterson Ave, Chicago, IL 60641    $699,000  2 beds
#
# ...

# %%
-----------Los Angeles---------

# %%
los=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div[2]/div/div[1]/div[7]/div[2]/a")
los.click()

# %%
address_name3=[]
location_name3=[]
price_name3=[]
beds_name3=[]
baths_name3=[]
sqft_name3=[]
ppsqft_name3=[]

# %%
del ppsqft_name3

# %%
del ppsqft_tag3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7d37fa268992> in <module>
# ----> 1 del ppsqft_tag3
#
# NameError: name 'ppsqft_tag3' is not defined

# %%
## scraping address
start=0
end=2
for page in range(start,end):
    address_tag3 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag3:
        address_name3.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name3
# Out:
# ['7305 Milwood Ave #4, Canoga Park, CA 91303',
#  '25481 Dodge Ave #7, Harbor City, CA 90710',
#  '3014 S Norton Ave, Los Angeles, CA 90018',
#  '7713 Hinds Ave, North Hollywood, CA 91605',
#  '6607 Lindley Ave, Reseda, CA 91335',
#  '4107 Dalton Ave, Los Angeles, CA 90062',
#  '601 N Fuller Ave, Los Angeles, CA 90036',
#  '1660 W 220th St #3, Torrance, CA 90501',
#  '8121 Canby Ave #6, Reseda, CA 91335',
#  '141 S Clark Dr #529, West Hollywood, CA 90048',
#  '5102 Escobedo Dr, Woodland Hills, CA 91364',
#  '2125 Ames St, Los Angeles, CA 90027',
#  '457 S Lorena, Los Angeles, CA 90063',
#  '6648 Valley Circle Blvd, West Hills, CA 91307',
#  '455 S Lorena, Los Angeles, CA 90063',
#  '1509 Greenfield Ave #204, Los Angeles, CA 90025',
#  '6520 Tampa Ave #3, Reseda, CA 91335',
#  '1087 S Plymouth Blvd, Los Angeles, CA 90019',
#  '5745 Aldea Ave, Encino, CA 91316',
#  '8408 Moorcroft Ave, West Hills, CA 91304',
#  '1051 Via Cordova, San Pedro, CA 90732',
# ...

# %%
len(address_name3)
# Out:
# 80

# %%
ppsqft_name3=[]

# scrapping ppsqft
start=0
end=2
for page in range(start,end):
    ppsqft_tag3 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag3:
        ppsqft_name3.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name3
# Out:
# ['$461',
#  '$709',
#  '$445',
#  '$1,024',
#  '$598',
#  '$660',
#  '$657',
#  '$1,071',
#  '$471',
#  '$502',
#  '$482',
#  '$351',
#  '$749',
#  '$644',
#  '$317',
#  '$827',
#  '$557',
#  '$616',
#  '$676',
#  '$924',
#  '$601',
#  '$441',
#  '$834',
#  '$616',
#  '$518',
#  '$588',
#  '$503',
#  '$879',
#  '$504',
#  '$431',
#  '$515',
#  '$619',
#  '$762',
#  '$607',
#  '$1,502',
#  '$803',
#  '$1,027',
#  '$555',
#  '$841',
#  '$732',
#  '$688',
#  '$465',
#  '$1,124',
#  '$601',
#  '$688',
#  '$814',
#  '$471',
#  '$485',
#  '$793',
#  '$933',
#  '$963',
#  '$784',
#  '$765',
#  '$607',
#  '$775',
#  '$858',
#  '$528',
#  '$414',
#  '$627',
#  '$725',
#  '$504',
#  '$710',
#  '$562',
#  '$635',
#  '$692',
#  '$620',
#  '$401',
#  '$243',
#  '$712',
#  '$534',
#  '$494',
#  '$1,413',
#  '$880',
#  '$789',
#  '$744',
#  '$280',
#  '$1,687',
#  '$972',
#  '$610',
#  '$550',
#  '$973',
#  '$688']

# %%
len(ppsqft_name3)
# Out:
# 82

# %%
sqft_name3=[]
# scrapping sqft
start=0
end=2
for page in range(start,end):
    sqft_tag3 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__LockedStat--value"]')
    for i in sqft_tag3:
        sqft_name3.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name3
# Out:
# ['',
#  '690',
#  '1,780',
#  '2,500',
#  '5,978',
#  '811',
#  '7,022',
#  '1,026',
#  '6,002',
#  '1,684',
#  '6,694',
#  '3,258',
#  '3,980',
#  '1,460',
#  '0.37',
#  '1,717',
#  '6.12',
#  '720',
#  '1,538',
#  '9,106',
#  '2,228',
#  '0.23',
#  '770',
#  '3,416',
#  '8,233',
#  '815',
#  '1,698',
#  '1,269',
#  '2,000',
#  '6,000',
#  '1,795',
#  '6,001',
#  '1,959',
#  '0.26',
#  '2,309',
#  '0.41',
#  '1,244',
#  '5,139',
#  '2,402',
#  '8,324',
#  '856',
#  '2,117',
#  '1,852',
#  '5,973',
#  '3,540',
#  '0.35',
#  '1,290',
#  '3,767',
#  '7,185',
#  '826',
#  '905',
#  '1,986',
#  '7,915',
#  '5,400',
#  '0.66',
#  '1,804',
#  '6,505',
#  '800',
#  '2,262',
#  '0.62',
#  '5,425',
#  '6,478',
#  '1,700',
#  '6,763',
#  '2,362',
#  '0.46',
#  '1,462',
#  '',
#  '1,538',
#  '935',
#  '1,575',
#  '972',
#  '1,485',
#  '1,356',
#  '4,315',
#  '1,296',
#  '5,321',
#  '1,430',
#  '4,798',
#  '1,710',
#  '2,422',
#  '6,751',
#  '2,869',
#  '0.49',
#  '1,800',
#  '6,301',
# ...

# %%
len(sqft_name3)
# Out:
# 136

# %%
sqft_name3=[]
# scrapping sqft
start=0
end=2
for page in range(start,end):
    sqft_tag3 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__LockedStat--value"]')
    for i in sqft_tag3:
        sqft_name3.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_name1=[]
# scrapping baths
start=0
end=2
for page in range(start,end):
    baths_tag3=driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag3:
        baths_name3.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
del baths_name3

# %%
len(baths_name1)
# Out:
# 82

# %%
beds_name3=[]
# scrapping beds
start=0
end=2
for page in range(start,end):
    beds_tag3=driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag3:
        beds_name3.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
del beds_tag3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-20de472d1c6a> in <module>
# ----> 1 del beds_tag3
#
# NameError: name 'beds_tag3' is not defined

# %%
beds_name3
# Out:
# ['',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '5 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '8 beds',
#  '3 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '24 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '28 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '',
#  '3 beds',
#  '5 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '21 beds',
#  '20 beds',
#  '6 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '6 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '5 beds',
#  '8 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '27 beds',
# ...

# %%
len(beds_name3)
# Out:
# 82

# %%
price_name3=[]
# scrapping beds
start=0
end=2
for page in range(start,end):
    price_tag3=driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag3:
        price_name3.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name3
# Out:
# ['',
#  '$390,000',
#  '$775,000',
#  '$999,000',
#  '$699,000',
#  '$799,000',
#  '$969,000',
#  '$2,795,000',
#  '$739,900',
#  '$640,000',
#  '$649,000',
#  '$1,799,999',
#  '$2,398,000',
#  '$499,900',
#  '$1,399,999',
#  '$534,900',
#  '$1,200,000',
#  '$650,000',
#  '$2,249,000',
#  '$1,100,000',
#  '$1,350,000',
#  '$1,499,000',
#  '$579,500',
#  '$2,695,000',
#  '$649,000',
#  '$3,895,000',
#  '$829,999',
#  '$2,795,000',
#  '$959,000',
#  '$975,000',
#  '$370,000',
#  '$485,000',
#  '$925,000',
#  '$6,195,000',
#  '$1,400,000',
#  '$659,000',
#  '$1,495,950',
#  '$4,399,000',
#  '$2,195,000',
#  '$1,699,000',
#  '$850,000',
#  '',
#  '$1,169,000',
#  '$795,000',
#  '$795,000',
#  '$729,005',
#  '$629,900',
#  '$699,900',
#  '$1,995,000',
#  '$1,385,000',
#  '$1,649,900',
#  '$4,950,000',
#  '$900,000',
#  '$1,549,000',
#  '$3,999,999',
#  '$1,050,000',
#  '$2,250,000',
#  '$488,888',
#  '$1,195,000',
#  '$695,000',
#  '$435,000',
#  '$1,300,000',
#  '$650,000',
# ...

# %%
len(price_name3)
# Out:
# 82

# %%
print(len(address_name3),len(price_name3),len(beds_name3),len(baths_name1),len(sqft_name3),len(ppsqft_name3))
# Out:
# 80 80 80 80 80 80

# %%
del ppsqft_name3[80]

# %%
print(len(address_name3),len(price_name3),len(beds_name3),len(baths_name1),len(sqft_name3),len(ppsqft_name3))

import pandas as pd
df2=pd.DataFrame({'Address':address_name3,'Price':price_name3,'Beds':beds_name3,'Baths':baths_name1,'Total sqft':sqft_name3,'Price per sqft':ppsqft_name3})
df2
# Out:
#                                        Address       Price     Beds  \
# 0   7305 Milwood Ave #4, Canoga Park, CA 91303
# 1    25481 Dodge Ave #7, Harbor City, CA 90710    $390,000   2 beds
# 2     3014 S Norton Ave, Los Angeles, CA 90018    $775,000   3 beds
# 3    7713 Hinds Ave, North Hollywood, CA 91605    $999,000   3 beds
# 4           6607 Lindley Ave, Reseda, CA 91335    $699,000   3 beds
# ..                                         ...         ...      ...
# 75     6957 Fullbright Ave, Winnetka, CA 91306  $1,095,000    1 bed
# 76      2915 Avenel Ter, Los Angeles, CA 90039  $1,975,000  27 beds
# 77    11907 Ancona Way, Porter Ranch, CA 91326    $649,900   3 beds
# 78           19300 Yolie Ln, Tarzana, CA 91356  $1,899,000   5 beds
# 79    5545 Calhoun Ave, Sherman Oaks, CA 91401  $2,349,000   3 beds
#
#         Baths Total sqft Price per sqft
# 0                                  $461
# 1      1 bath        690           $709
# 2   2.5 baths      1,780           $445
# ...

# %%
df2.to_csv('file3.csv')

# %%
df2=pd.read_csv('file3.csv')
df2
# Out:
#     Srno                                     Address       Price     Beds  \
# 0      0  7305 Milwood Ave #4, Canoga Park, CA 91303    $775,000   2 beds
# 1      1   25481 Dodge Ave #7, Harbor City, CA 90710    $390,000   2 beds
# 2      2    3014 S Norton Ave, Los Angeles, CA 90018    $775,000   3 beds
# 3      3   7713 Hinds Ave, North Hollywood, CA 91605    $999,000   3 beds
# 4      4          6607 Lindley Ave, Reseda, CA 91335    $699,000   3 beds
# ..   ...                                         ...         ...      ...
# 75    75     6957 Fullbright Ave, Winnetka, CA 91306  $1,095,000    1 bed
# 76    76      2915 Avenel Ter, Los Angeles, CA 90039  $1,975,000  27 beds
# 77    77    11907 Ancona Way, Porter Ranch, CA 91326    $649,900   3 beds
# 78    78           19300 Yolie Ln, Tarzana, CA 91356  $1,899,000   5 beds
# 79    79    5545 Calhoun Ave, Sherman Oaks, CA 91401  $2,349,000   3 beds
#
#         Baths Total sqft Price per sqft
# ...

# %%
---------------San Diego------------

# %%
san=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div[2]/div/div[1]/div[9]/div[2]/a")
san.click()

# %%
address_name4=[]
price_name4=[]
beds_name4=[]
baths_name4=[]
sqft_name4=[]
ppsqft_name4=[]

# %%
## scraping address
start=0
end=2
for page in range(start,end):
    address_tag4 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag4:
        address_name4.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name4
# Out:
# ['3535 Monroe Ave #21, San Diego, CA 92116',
#  '2119 Illion St, San Diego, CA 92110',
#  '11130 Avenida de los Lobos, San Diego, CA 92127',
#  '4019 Taos Dr, San Diego, CA 92117',
#  'Sign in for address, San Diego, CA 92101',
#  'Sign in for address, San Diego, CA 92116',
#  '13864 Boquita Dr, Del Mar, CA 92014',
#  '12 Via Montisi, Santee, CA 92071',
#  '300 W Beech St #4, San Diego, CA 92101',
#  '12987 Caminito Dosamantes, San Diego, CA 92128',
#  '1643 6th Ave #417, San Diego, CA 92101',
#  '2431 Palace Dr, San Diego, CA 92123',
#  '7249 Park Village Rd, San Diego, CA 92129',
#  '3950 Ohio St #535, San Diego, CA 92104',
#  '7046 Park Mesa Way #39, San Diego, CA 92111',
#  '1021 Scott St #218, San Diego, CA 92106',
#  '3560-62 Island Ave, San Diego, CA 92102',
#  '3887 Pell Pl #114, San Diego, CA 92130',
#  '500 W Harbor Dr #507, San Diego, CA 92101',
#  '17094 Castello Cir, San Diego, CA 92127',
#  '6737 Friars #195, San Diego, CA 92108',
# ...

# %%
len(address_name4)
# Out:
# 80

# %%
ppsqft_name4=[]

# scrapping ppsqft
start=0
end=2
for page in range(start,end):
    ppsqft_tag4 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag4:
        ppsqft_name4.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name4
# Out:
# ['$580',
#  '$773',
#  '$610',
#  '$629',
#  '$785',
#  '$871',
#  '$712',
#  '$1,032',
#  '$747',
#  '$553',
#  '$733',
#  '$949',
#  '$1,023',
#  '$959',
#  '$1,573',
#  '$465',
#  '$931',
#  '$1,431',
#  '$1,190',
#  '$836',
#  '$756',
#  '$995',
#  '$525',
#  '$1,000',
#  '$2,302',
#  '$681',
#  '$1,260',
#  '$560',
#  '$611',
#  '$564',
#  '$603',
#  '$830',
#  '$617',
#  '$859',
#  '$625',
#  '$895',
#  '$937',
#  '$897',
#  '$696',
#  '$560',
#  '$746',
#  '$653',
#  '$684',
#  '$746',
#  '$854',
#  '$1,149',
#  '$1,492',
#  '$908',
#  '$511',
#  '$774',
#  '$708',
#  '$740',
#  '$814',
#  '$793',
#  '$887',
#  '$667',
#  '$1,684',
#  '$685',
#  '$903',
#  '$899',
#  '$753',
#  '$556',
#  '$563',
#  '$670',
#  '$1,110',
#  '$816',
#  '$662',
#  '$716',
#  '$680',
#  '$538',
#  '$631',
#  '$746',
#  '$1,000',
#  '$839',
#  '$606',
#  '$504',
#  '$755',
#  '$695',
#  '$710',
#  '$918',
#  '$697',
#  '$746']

# %%
len(ppsqft_name4)
# Out:
# 82

# %%
baths_name4=[]
# scrapping beds
start=0
end=2
for page in range(start,end):
    baths_tag4=driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag4:
        baths_name4.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name4
# Out:
# ['',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '6 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '8 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '— beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '5 beds',
#  '2 beds',
#  '',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '0 beds',
#  '3 beds',
#  '5 beds',
#  '2 beds',
#  '2 beds',
#  '0 beds',
#  '5 beds',
#  '2 beds',
#  '1 bed',
#  '6 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '1 bed',
# ...

# %%
len(beds_name4)
# Out:
# 82

# %%
baths_name4
# Out:
# ['',
#  '3 baths',
#  '2 baths',
#  '3 baths',
#  '1 bath',
#  '2.5 baths',
#  '1.5 baths',
#  '3.5 baths',
#  '3 baths',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '4 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '3 baths',
#  '2 baths',
#  '4.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '1.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '5.5 baths',
#  '3 baths',
#  '2 baths',
#  '1.5 baths',
#  '2 baths',
#  '',
#  '1.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '4 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '4.5 baths',
#  '2 baths',
#  '4.5 baths',
#  '5.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '4 baths',
#  '1.5 baths',
#  '2 baths',
# ...

# %%
len(baths_name4)
# Out:
# 82

# %%
# scrapping price type
start=0
end=2
for page in range(start,end):
    price_tag4 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag4:
        price_name4.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name4
# Out:
# ['',
#  '$724,900',
#  '$799,000',
#  '$949,900',
#  '$375,000',
#  '$1,249,000',
#  '$1,699,000',
#  '$1,100,000',
#  '$2,100,000',
#  '$1,249,000',
#  '$525,000',
#  '$988,800',
#  '$939,000',
#  '$6,990,000',
#  '$1,275,000',
#  '$2,650,000',
#  '$950,000',
#  '$1,425,000',
#  '$1,950,000',
#  '$2,395,000',
#  '$1,150,000',
#  '$500,000',
#  '$635,000',
#  '$1,365,000',
#  '$2,765,000',
#  '$33,995,000',
#  '$539,000',
#  '$3,250,000',
#  '$779,975',
#  '$499,000',
#  '$3,050,000',
#  '$625,000',
#  '$989,000',
#  '$949,000',
#  '$1,350,000',
#  '$1,090,000',
#  '$1,350,000',
#  '$1,150,000',
#  '$4,300,000',
#  '$2,175,000',
#  '$722,500',
#  '',
#  '$560,000',
#  '$1,999,999',
#  '$1,350,000',
#  '$1,350,000',
#  '$1,478,000',
#  '$2,978,000',
#  '$3,395,000',
#  '$729,900',
#  '$1,300,000',
#  '$1,259,000',
#  '$350,000',
#  '$895,000',
#  '$1,999,900',
#  '$725,000',
#  '$715,000',
#  '$485,000',
#  '$1,199,000',
#  '$950,000',
#  '$790,000',
#  '$3,995,000',
#  '$490,000',
# ...

# %%
len(price_name4)
# Out:
# 82

# %%
sqft_name4=[]
# scrapping sqft
start=0
end=2
for page in range(start,end):
    sqft_tag4 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag4:
        sqft_name4.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
del sqft_tag4

# %%
len(sqft_name4)
# Out:
# 82

# %%
sqft_name4
# Out:
# ['1,250',
#  '1,033',
#  '1,556',
#  '596',
#  '1,591',
#  '1,951',
#  '1,546',
#  '2,035',
#  '1,671',
#  '950',
#  '1,349',
#  '989',
#  '6,832',
#  '1,330',
#  '1,685',
#  '2,044',
#  '1,531',
#  '1,363',
#  '2,012',
#  '1,375',
#  '661',
#  '638',
#  '2,599',
#  '2,765',
#  '14,768',
#  '791',
#  '2,579',
#  '1,392',
#  '817',
#  '5,412',
#  '1,036',
#  '1,191',
#  '1,538',
#  '1,572',
#  '1,743',
#  '1,508',
#  '1,227',
#  '4,795',
#  '3,125',
#  '1,291',
#  '1,458',
#  '858',
#  '2,922',
#  '1,810',
#  '1,581',
#  '1,286',
#  '1,996',
#  '3,740',
#  '1,427',
#  '1,680',
#  '1,777',
#  '473',
#  '1,100',
#  '2,522',
#  '817',
#  '1,072',
#  '288',
#  '1,750',
#  '1,052',
#  '879',
#  '5,303',
#  '882',
#  '780',
#  '1,267',
#  '900',
#  '1,346',
#  '1,102',
#  '768',
#  '1,910',
#  '818',
#  '2,518',
#  '831',
#  '1,000',
#  '1,431',
#  '906',
#  '2,080',
#  '815',
#  '1,619',
#  '1,902',
#  '1,498',
#  '846',
#  '1,458']

# %%
print(len(address_name4),len(price_name4),len(beds_name4),len(baths_name4),len(sqft_name4),len(ppsqft_name4))
# Out:
# 80 80 80 80 80 80

# %%
del ppsqft_name4[80]

# %%
import pandas as pd
df3=pd.DataFrame({'Address':address_name4,'Price':price_name4,'Beds':beds_name4,'Baths':baths_name4,'Total sqft':sqft_name4,'Price per sqft':ppsqft_name4})
df3
# Out:
#                                              Address       Price    Beds  \
# 0           3535 Monroe Ave #21, San Diego, CA 92116
# 1                2119 Illion St, San Diego, CA 92110    $724,900  3 beds
# 2    11130 Avenida de los Lobos, San Diego, CA 92127    $799,000  3 beds
# 3                  4019 Taos Dr, San Diego, CA 92117    $949,900  2 beds
# 4           Sign in for address, San Diego, CA 92101    $375,000   1 bed
# ..                                               ...         ...     ...
# 75       5353 Aurora Summit Trl, San Diego, CA 92130    $549,000  2 beds
# 76             4685 Serenata Pl, San Diego, CA 92130  $1,049,000  4 beds
# 77  8614 Mission San Carlos Dr #62, Santee, CA 92071    $615,000   1 bed
# 78            4067 Palmetto Way, San Diego, CA 92103  $1,125,000  2 beds
# 79          9018 Chart House St, San Diego, CA 92126  $1,350,000  3 beds
#
#         Baths Total sqft Price per sqft
# 0                  1,250           $580
# ...

# %%
df3.to_csv('file4.csv')

# %%
missing_values = df3.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df3))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Address                      0             0.0
# Price                        0             0.0
# Beds                         0             0.0
# Baths                        0             0.0
# Total sqft                   0             0.0
# Price per sqft               0             0.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Address         80 non-null     object
#  1   Price           80 non-null     object
#  2   Beds            80 non-null     object
#  3   Baths           80 non-null     object
#  4   Total sqft      80 non-null     object
#  5   Price per sqft  80 non-null     object
# dtypes: object(6)
# memory usage: 3.9+ KB

# %%
df3.isnull()
# Out:
#     Address  Price   Beds  Baths  Total sqft  Price per sqft
# 0     False  False  False  False       False           False
# 1     False  False  False  False       False           False
# 2     False  False  False  False       False           False
# 3     False  False  False  False       False           False
# 4     False  False  False  False       False           False
# ..      ...    ...    ...    ...         ...             ...
# 75    False  False  False  False       False           False
# 76    False  False  False  False       False           False
# 77    False  False  False  False       False           False
# 78    False  False  False  False       False           False
# 79    False  False  False  False       False           False
#
# [80 rows x 6 columns]

# %%
df3.describe()
# Out:
#                                          Address       Price    Beds    Baths  \
# count                                         80          80      80       80
# unique                                        80          72      10       10
# top     3535 Monroe Ave #21, San Diego, CA 92116  $1,350,000  3 beds  2 baths
# freq                                           1           5      25       33
#
#        Total sqft Price per sqft
# count          80             80
# unique         79             76
# top           817           $746
# freq            2              3

# %%
df3.isnull().sum()
# Out:
# Address           0
# Price             0
# Beds              0
# Baths             0
# Total sqft        0
# Price per sqft    0
# dtype: int64

# %%
df3.head()
# Out:
#                                            Address     Price    Beds    Baths  \
# 0         3535 Monroe Ave #21, San Diego, CA 92116
# 1              2119 Illion St, San Diego, CA 92110  $724,900  3 beds  3 baths
# 2  11130 Avenida de los Lobos, San Diego, CA 92127  $799,000  3 beds  2 baths
# 3                4019 Taos Dr, San Diego, CA 92117  $949,900  2 beds  3 baths
# 4         Sign in for address, San Diego, CA 92101  $375,000   1 bed   1 bath
#
#   Total sqft Price per sqft
# 0      1,250           $580
# 1      1,033           $773
# 2      1,556           $610
# 3        596           $629
# 4      1,591           $785

# %%
df3=pd.read_csv('file4.csv')

# %%
df3.isnull()
# Out:
#      Srno  Address  Price   Beds  Baths  Total sqft  Price per sqft
# 0   False    False   True   True   True       False           False
# 1   False    False  False  False  False       False           False
# 2   False    False  False  False  False       False           False
# 3   False    False  False  False  False       False           False
# 4   False    False  False  False  False       False           False
# ..    ...      ...    ...    ...    ...         ...             ...
# 75  False    False  False  False  False       False           False
# 76  False    False  False  False  False       False           False
# 77  False    False  False  False  False       False           False
# 78  False    False  False  False  False       False           False
# 79  False    False  False  False  False       False           False
#
# [80 rows x 7 columns]

# %%
df1.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-9f07dfc367ff> in <module>
# ----> 1 df1.isnull()
#
# NameError: name 'df1' is not defined

# %%
----------Condos----------

# %%
San Diego condos

# %%
buy=driver.find_element(By.XPATH,"//a[@class="inheritColor dropdownWidget"]")
buy.click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-46-42afd396cc55> in <module>
# ----> 1 buy=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div/div/header[2]/div[2]/div[1]")
#       2 buy.click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     737             value = f'[name="{value}"]'
#     738
# --> 739         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     740
#     741     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     343         response = self.command_executor.execute(driver_command, params)
#     344         if response:
# --> 345             self.error_handler.check_response(response)
# ...

# %%
sandiego=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[23]/ul/li[1]/a').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-70-9cd3c7c74409> in <module>
# ----> 1 sandiego=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[23]/ul/li[1]/a').click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     737             value = f'[name="{value}"]'
#     738
# --> 739         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     740
#     741     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     343         response = self.command_executor.execute(driver_command, params)
#     344         if response:
# --> 345             self.error_handler.check_response(response)
# ...

# %%
san=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[9]/div[2]/a').click()

# %%
address_condossan=[]
price_condossan=[]
beds_condossan=[]
baths_condossan=[]
sqft_condossan=[]
ppsqft_condossan=[]

# %%
address_name5=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag5 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag5:
        address_name5.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name5
# Out:
# ['10846 Lamentin Ct, San Diego, CA 92124',
#  '6289 Jeff St, San Diego, CA 92115',
#  '6056 Portobelo Ct, San Diego, CA 92124',
#  '3645 Ash St #4, San Diego, CA 92105',
#  '4995 Rebel Rd, San Diego, CA 92117',
#  '3786 Pioneer Pl, San Diego, CA 92103',
#  '8655 Lepus Rd, San Diego, CA 92126',
#  '920 Moana Dr, San Diego, CA 92106',
#  '300 W Beech St #2, San Diego, CA 92101',
#  '1605 Hotel Cir S Unit B115, San Diego, CA 92108',
#  '3776 Alabama St #313, San Diego, CA 92104',
#  '4139 Taos Dr, San Diego, CA 92117',
#  '3340 Del Sol Blvd #265, San Diego, CA 92154',
#  '8734 Tommy Dr, San Diego, CA 92119',
#  '2920 Union St #201, San Diego, CA 92103',
#  '10428 Whitcomb Way #119, San Diego, CA 92127',
#  '1441 9Th Ave #2103, San Diego, CA 92101',
#  '2269 Alta View Dr, San Diego, CA 92139',
#  '230 20th St, San Diego, CA 92102',
#  '13773 Caminito Anzio, San Diego, CA 92129',
#  '620 State St #115, San Diego, CA 92101',
#  '8206 Caminito Lacayo, La Jolla, CA 92037',
# ...

# %%
len(address_name5)
# Out:
# 120

# %%
price_name5=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag5 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag5:
        price_name5.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name5
# Out:
# ['$724,900',
#  '$799,000',
#  '$949,900',
#  '$375,000',
#  '$1,249,000',
#  '$1,699,000',
#  '$1,100,000',
#  '$2,100,000',
#  '$1,249,000',
#  '$525,000',
#  '$299,000',
#  '$1,588,000',
#  '$245,000',
#  '$945,000',
#  '$775,000',
#  '$1,020,000',
#  '$1,175,000',
#  '$975,000',
#  '$899,000',
#  '$529,000',
#  '$615,000',
#  '$2,595,000',
#  '$2,180,000',
#  '$685,000',
#  '$1,099,000',
#  '$997,500',
#  '$1,375,000',
#  '$399,000',
#  '$2,400,000',
#  '$525,000',
#  '$889,000',
#  '$1,649,900',
#  '$2,295,000',
#  '$1,589,000',
#  '$2,750,000',
#  '$988,800',
#  '$939,000',
#  '$6,990,000',
#  '$1,275,000',
#  '$2,650,000',
#  '$950,000',
#  '$1,425,000',
#  '$1,950,000',
#  '$2,395,000',
#  '$1,150,000',
#  '$500,000',
#  '$635,000',
#  '$1,365,000',
#  '$2,765,000',
#  '$33,995,000',
#  '$539,000',
#  '$3,250,000',
#  '$779,975',
#  '$499,000',
#  '$3,050,000',
#  '$625,000',
#  '$989,000',
#  '$949,000',
#  '$1,350,000',
#  '$1,090,000',
#  '$1,350,000',
#  '$1,150,000',
# ...

# %%
len(price_name5)
# Out:
# 120

# %%
ppsqft_name5=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag5 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag5:
        ppsqft_name5.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name5
# Out:
# ['$580',
#  '$773',
#  '$610',
#  '$629',
#  '$785',
#  '$871',
#  '$712',
#  '$1,032',
#  '$747',
#  '$553',
#  '$791',
#  '$737',
#  '$107',
#  '$643',
#  '$547',
#  '$714',
#  '$867',
#  '$599',
#  '$690',
#  '$600',
#  '$837',
#  '$807',
#  '$762',
#  '$924',
#  '$723',
#  '$792',
#  '$637',
#  '$488',
#  '$1,002',
#  '$595',
#  '$612',
#  '$699',
#  '$1,223',
#  '$860',
#  '$1,186',
#  '$733',
#  '$949',
#  '$1,023',
#  '$959',
#  '$1,573',
#  '$746',
#  '$465',
#  '$931',
#  '$1,431',
#  '$1,190',
#  '$836',
#  '$756',
#  '$995',
#  '$525',
#  '$1,000',
#  '$2,302',
#  '$681',
#  '$1,260',
#  '$560',
#  '$611',
#  '$564',
#  '$603',
#  '$830',
#  '$617',
#  '$859',
#  '$625',
#  '$895',
#  '$937',
#  '$897',
#  '$696',
#  '$560',
#  '$653',
#  '$684',
#  '$746',
#  '$854',
#  '$1,149',
#  '$1,492',
#  '$908',
#  '$511',
#  '$774',
#  '$708',
#  '$740',
#  '$814',
#  '$793',
#  '$887',
#  '$667',
#  '$746',
#  '$1,684',
#  '$685',
#  '$903',
#  '$899',
#  '$753',
#  '$556',
# ...

# %%
len(ppsqft_name5)
# Out:
# 123

# %%
beds_name5=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag5 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag5:
        beds_name5.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name5
# Out:
# ['',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '4 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '6 beds',
#  '3 beds',
#  '3 beds',
#  '',
#  '4 beds',
#  '4 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '8 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '— beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '5 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '0 beds',
# ...

# %%
len(beds_name5)
# Out:
# 123

# %%
baths_name5=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag5 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag5:
        baths_name5.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_name5
# Out:
# ['',
#  '1.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '3 baths',
#  '3 baths',
#  '3 baths',
#  '3 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '7.5 baths',
#  '2 baths',
#  '2 baths',
#  '',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '3.5 baths',
#  '3.5 baths',
#  '8.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '— baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '3 baths',
#  '3 baths',
#  '4.5 baths',
#  '4.5 baths',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
# ...

# %%
len(baths_name5)
# Out:
# 123

# %%
sqft_name5=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag5 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"] ')
    for i in sqft_tag5:
        sqft_name5.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name5
# Out:
# ['1,250',
#  '1,033',
#  '1,556',
#  '596',
#  '1,591',
#  '1,951',
#  '1,546',
#  '2,035',
#  '1,671',
#  '950',
#  '378',
#  '2,155',
#  '2,280',
#  '1,470',
#  '1,417',
#  '1,428',
#  '1,355',
#  '1,629',
#  '1,302',
#  '882',
#  '735',
#  '3,214',
#  '2,861',
#  '741',
#  '1,520',
#  '1,260',
#  '2,158',
#  '818',
#  '2,396',
#  '882',
#  '1,453',
#  '2,360',
#  '1,876',
#  '1,848',
#  '2,319',
#  '1,349',
#  '989',
#  '6,832',
#  '1,330',
#  '1,685',
#  '1,453',
#  '2,044',
#  '1,531',
#  '1,363',
#  '2,012',
#  '1,375',
#  '661',
#  '638',
#  '2,599',
#  '2,765',
#  '14,768',
#  '791',
#  '2,579',
#  '1,392',
#  '817',
#  '5,412',
#  '1,036',
#  '1,191',
#  '1,538',
#  '1,572',
#  '1,743',
#  '1,508',
#  '1,227',
#  '4,795',
#  '3,125',
#  '1,291',
#  '858',
#  '2,922',
#  '1,810',
#  '1,581',
#  '1,286',
#  '1,996',
#  '3,740',
#  '1,427',
#  '1,680',
#  '1,777',
#  '473',
#  '1,100',
#  '2,522',
#  '817',
#  '1,072',
#  '1,453',
#  '288',
#  '1,750',
#  '1,052',
#  '879',
# ...

# %%
len(sqft_name5)
# Out:
# 123

# %%
print(len(address_name5),len(price_name5),len(beds_name5),len(baths_name5),len(sqft_name5),len(ppsqft_name5))
# Out:
# 80 80 80 80 80 80

# %%
del ppsqft_name5[80:123]

# %%
import pandas as pd
df5=pd.DataFrame({'Address':address_name5,'Price':price_name5,'Beds':beds_name5,'Baths':baths_name5,'Total sqft':sqft_name5,'Price per sqft':ppsqft_name5})
df5
# Out:
#                                         Address       Price    Beds  \
# 0        10846 Lamentin Ct, San Diego, CA 92124    $724,900
# 1             6289 Jeff St, San Diego, CA 92115    $799,000  3 beds
# 2        6056 Portobelo Ct, San Diego, CA 92124    $949,900  3 beds
# 3           3645 Ash St #4, San Diego, CA 92105    $375,000  2 beds
# 4            4995 Rebel Rd, San Diego, CA 92117  $1,249,000   1 bed
# ..                                          ...         ...     ...
# 75       1643 6th Ave #417, San Diego, CA 92101    $350,000  2 beds
# 76          2431 Palace Dr, San Diego, CA 92123    $895,000  3 beds
# 77    7249 Park Village Rd, San Diego, CA 92129  $1,999,900  0 beds
# 78       3950 Ohio St #535, San Diego, CA 92104    $725,000  3 beds
# 79  7046 Park Mesa Way #39, San Diego, CA 92111    $715,000  5 beds
#
#         Baths Total sqft Price per sqft
# 0                  1,250           $580
# 1   1.5 baths      1,033           $773
# ...

# %%
df5.to_csv('file5.csv')

# %%
----------Portland condos-------------

# %%
Portland_condos=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[11]/div[2]/a').click()

# %%
address_name6=[]
price_name6=[]
beds_name6=[]
baths_name6=[]
sqft_name6=[]
ppsqft_name6=[]

# %%
address_name6=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag6 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag6:
        address_name6.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name6
# Out:
# ['411 NW Flanders St, Portland, OR 97209',
#  '111 SW Harrison St Unit 19E, Portland, OR 97201',
#  '1638 SW 58th Ave, Portland, OR 97221',
#  '7835 SE 92nd Ave #15, Portland, OR 97266',
#  '1132 SW 19th Ave, Portland, OR 97205',
#  '222 SE Spokane St, Portland, OR 97202',
#  '1718 NE 11th Ave, Portland, OR 97212',
#  '1134 SW Jefferson St #502, Portland, OR 97201',
#  '1829 NW Lovejoy St, Portland, OR 97209',
#  '7742 SE Long St Unit A, Portland, OR 97206',
#  '47 Eagle Crest Dr #24, Lake Oswego, OR 97035',
#  '8517 NE Milton St #4, Portland, OR 97220',
#  '8523 NE Milton St #1, Portland, OR 97220',
#  '8521 NE Milton St #2, Portland, OR 97220',
#  '1025 NW Couch St #1018, Portland, OR 97209',
#  '14811 NE Sacramento St #96, Portland, OR 97230',
#  '330 NW 116th Ave #107, Portland, OR 97229',
#  '1260 NW Naito Pkwy Unit 311B, Portland, OR 97209',
#  '5170 S Landing Dr #201, Portland, OR 97239',
#  '1130 NW 12th Ave #516, Portland, OR 97209',
# ...

# %%
len(address_name6)
# Out:
# 120

# %%
price_name6=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag6 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag6:
        price_name6.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name6
# Out:
# ['',
#  '$325,000',
#  '$276,000',
#  '$525,000',
#  '$269,000',
#  '$799,000',
#  '$849,900',
#  '$270,000',
#  '$199,000',
#  '$219,000',
#  '$359,900',
#  '$240,000',
#  '$319,900',
#  '$299,900',
#  '$279,900',
#  '$475,000',
#  '$225,000',
#  '$450,000',
#  '$425,000',
#  '$489,900',
#  '$450,000',
#  '$319,000',
#  '$385,000',
#  '$412,000',
#  '$244,900',
#  '$429,900',
#  '$230,000',
#  '$400,000',
#  '$299,900',
#  '$775,000',
#  '$425,000',
#  '$329,000',
#  '$350,000',
#  '$415,000',
#  '$160,000',
#  '$199,900',
#  '$375,000',
#  '$255,900',
#  '$579,000',
#  '$419,900',
#  '$330,000',
#  '',
#  '$339,900',
#  '$279,000',
#  '$375,000',
#  '$495,000',
#  '$1,100,000',
#  '$255,000',
#  '$239,900',
#  '$249,900',
#  '$279,900',
#  '$269,900',
#  '$259,900',
#  '$525,000',
#  '$410,000',
#  '$235,000',
#  '$350,000',
#  '$239,900',
#  '$485,000',
#  '$250,000',
#  '$825,000',
#  '$347,500',
#  '$309,900',
#  '$575,000',
#  '$485,000',
#  '$475,000',
#  '$1,095,000',
# ...

# %%
len(price_name6)
# Out:
# 123

# %%
beds_name6=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag6 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag6:
        beds_name6.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name6
# Out:
# ['1 bed',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '0 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '0 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '0 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
# ...

# %%
len(beds_name6)
# Out:
# 120

# %%
baths_name6=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag6 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag6:
        baths_name6.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_name6
# Out:
# ['1 bath',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '1.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1.5 baths',
#  '3.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '3 baths',
#  '1 bath',
#  '1.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '1.5 baths',
# ...

# %%
len(baths_name6)
# Out:
# 120

# %%
sqft_name6=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag6 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag6:
        sqft_name6.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name6
# Out:
# ['954',
#  '579',
#  '2,096',
#  '1,146',
#  '2,001',
#  '2,625',
#  '689',
#  '484',
#  '636',
#  '1,115',
#  '672',
#  '889',
#  '994',
#  '876',
#  '998',
#  '766',
#  '1,300',
#  '869',
#  '1,045',
#  '981',
#  '901',
#  '817',
#  '875',
#  '864',
#  '1,787',
#  '572',
#  '1,004',
#  '680',
#  '1,885',
#  '979',
#  '718',
#  '982',
#  '874',
#  '312',
#  '844',
#  '904',
#  '712',
#  '1,083',
#  '1,013',
#  '757',
#  '955',
#  '859',
#  '1,638',
#  '810',
#  '1,330',
#  '1,811',
#  '954',
#  '677',
#  '895',
#  '933',
#  '940',
#  '922',
#  '1,094',
#  '1,859',
#  '764',
#  '764',
#  '724',
#  '1,473',
#  '1,359',
#  '3,303',
#  '827',
#  '842',
#  '1,605',
#  '973',
#  '1,624',
#  '2,587',
#  '744',
#  '800',
#  '915',
#  '657',
#  '912',
#  '1,437',
#  '1,267',
#  '2,667',
#  '730',
#  '1,485',
#  '742',
#  '837',
#  '1,950',
#  '1,579',
#  '636',
#  '955',
#  '959',
#  '1,059',
#  '367',
#  '1,167',
#  '2,927',
#  '932',
#  '360',
#  '715',
#  '1,078',
#  '2,101',
#  '1,592',
# ...

# %%
len(sqft_name6)
# Out:
# 123

# %%
ppsqft_name6=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag6 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag6:
        ppsqft_name6.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name6
# Out:
# ['$341',
#  '$477',
#  '$250',
#  '$235',
#  '$399',
#  '$324',
#  '$392',
#  '$411',
#  '$344',
#  '$323',
#  '$357',
#  '$360',
#  '$302',
#  '$320',
#  '$476',
#  '$294',
#  '$346',
#  '$489',
#  '$469',
#  '$459',
#  '$354',
#  '$471',
#  '$471',
#  '$283',
#  '$241',
#  '$402',
#  '$398',
#  '$441',
#  '$411',
#  '$434',
#  '$458',
#  '$356',
#  '$475',
#  '$513',
#  '$237',
#  '$415',
#  '$359',
#  '$535',
#  '$415',
#  '$436',
#  '$392',
#  '$396',
#  '$170',
#  '$463',
#  '$372',
#  '$607',
#  '$267',
#  '$354',
#  '$279',
#  '$300',
#  '$287',
#  '$282',
#  '$480',
#  '$221',
#  '$308',
#  '$458',
#  '$331',
#  '$329',
#  '$184',
#  '$250',
#  '$420',
#  '$368',
#  '$358',
#  '$498',
#  '$292',
#  '$423',
#  '$383',
#  '$400',
#  '$361',
#  '$495',
#  '$258',
#  '$264',
#  '$355',
#  '$208',
#  '$384',
#  '$401',
#  '$404',
#  '$406',
#  '$307',
#  '$221',
#  '$456',
#  '$392',
#  '$604',
#  '$392',
#  '$441',
#  '$556',
#  '$752',
#  '$338',
#  '$444',
#  '$469',
# ...

# %%
len(ppsqft_name6)
# Out:
# 123

# %%
print(len(address_name6),len(price_name6),len(beds_name6),len(baths_name6),len(sqft_name6),len(ppsqft_name6))
# Out:
# 100 100 100 100 100 100

# %%
del ppsqft_name6[100:123]

# %%
del price_tag6

# %%
import pandas as pd
df6=pd.DataFrame({'Address':address_name6,'Price':price_name6,'Beds':beds_name6,'Baths':baths_name6,'Total sqft':sqft_name6,'Price per sqft':ppsqft_name6})
df6
# Out:
#                                               Address       Price    Beds  \
# 0              411 NW Flanders St, Portland, OR 97209               1 bed
# 1     111 SW Harrison St Unit 19E, Portland, OR 97201    $325,000   1 bed
# 2                1638 SW 58th Ave, Portland, OR 97221    $276,000  3 beds
# 3            7835 SE 92nd Ave #15, Portland, OR 97266    $525,000  3 beds
# 4                1132 SW 19th Ave, Portland, OR 97205    $269,000  2 beds
# ..                                                ...         ...     ...
# 95           1125 NW 9th Ave #302, Portland, OR 97209    $379,000  2 beds
# 96       12 NE Fremont St Unit 4E, Portland, OR 97212  $1,299,000  2 beds
# 97  2015 SE Columbia River Dr #450, Vancouver, WA ...    $374,900  3 beds
# 98       7980 SE Cooper St Unit A, Portland, OR 97206    $520,000  2 beds
# 99              2027 SE Harold St, Portland, OR 97202    $859,900  4 beds
#
#         Baths Total sqft Price per sqft
# ...

# %%
df6.to_csv('file6.csv')

# %%
-----------Washington DC-----------

# %%
/html/body/div[1]/div[6]/div[2]/div/div[1]/div[13]/div[2]/a

# %%
washington_condos=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[13]/div[2]/a').click()

# %%
address_name7=[]
price_name7=[]
beds_name7=[]
baths_name7=[]
sqft_name7=[]
ppsqft_name7=[]

# %%
address_name7=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag7 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag7:
        address_name7.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name7
# Out:
# ['1315 Harvard St NW #1, Washington, DC 20009',
#  '1315 Harvard St NW #2, Washington, DC 20009',
#  '800 4th St SW Unit N812, Washington, DC 20024',
#  '1209 G St SE #11, Washington, DC 20003',
#  '709 Rock Creek Church Rd NW #2, Washington, DC 20010',
#  '4013 Davis Pl NW #8, Washington, DC 20007',
#  '3804 Porter St NW #101, Washington, DC 20016',
#  '811 4th St NW #618, Washington, DC 20001',
#  '57 N St NW Unit N134, Washington, DC 20001',
#  '3812 V St SE #301, Washington, DC 20020',
#  '2500 Q St NW Unit 141-142, Washington, DC 20007',
#  '1454 Belmont St NW #12, Washington, DC 20009',
#  '3255 Prospect St NW Unit ONE, Washington, DC 20007',
#  '2555 Pennsylvania Ave NW #406, Washington, DC 20037',
#  '2125 14th St NW #319, Washington, DC 20009',
#  '810 O St NW #207, Washington, DC 20001',
#  '732 5th St SE #1, Washington, DC 20003',
#  '7700 Georgia Ave NW #301, Washington, DC 20012',
#  '1320 13th St NW #21, Washington, DC 20005',
# ...

# %%
len(address_name7)
# Out:
# 120

# %%
price_name7=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag7 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag7:
        price_name7.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name7
# Out:
# ['$649,900',
#  '$389,900',
#  '$247,000',
#  '$1,050,000',
#  '$40,000',
#  '$244,900',
#  '$100,000',
#  '$139,900',
#  '$1,375,000',
#  '$1,200,000',
#  '$179,900',
#  '$550,000',
#  '$260,000',
#  '$264,999',
#  '$495,000',
#  '$419,998',
#  '$474,900',
#  '$425,000',
#  '$305,000',
#  '$489,777',
#  '$285,000',
#  '$204,900',
#  '$280,000',
#  '$799,000',
#  '$1,150,000',
#  '$559,900',
#  '$438,900',
#  '$729,500',
#  '$675,000',
#  '$173,000',
#  '$749,900',
#  '$299,000',
#  '$849,000',
#  '$175,000',
#  '$429,000',
#  '$609,000',
#  '$269,900',
#  '$369,000',
#  '$930,000',
#  '$475,000',
#  '$329,000',
#  '$315,000',
#  '$819,000',
#  '$585,000',
#  '$559,900',
#  '$634,888',
#  '$550,000',
#  '$299,900',
#  '$425,500',
#  '$6,900,000',
#  '$1,295,000',
#  '$365,000',
#  '$285,000',
#  '$534,900',
#  '$499,000',
#  '$247,000',
#  '$246,600',
#  '$949,900',
#  '$729,000',
#  '$275,000',
#  '$399,995',
#  '$400,000',
#  '$130,000',
#  '$275,000',
#  '$425,000',
# ...

# %%
len(price_name7)
# Out:
# 120

# %%
beds_name7=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag7 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag7:
        beds_name7.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name7
# Out:
# ['3 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '0 beds',
#  '0 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '0 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '0 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '0 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '1 bed',
# ...

# %%
len(beds_name7)
# Out:
# 120

# %%
baths_name7=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag7 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag7:
        baths_name7.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_name7
# Out:
# ['2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '3.5 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '3 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '1.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '1.5 baths',
#  '1 bath',
#  '1 bath',
# ...

# %%
len(baths_name7)
# Out:
# 120

# %%
sqft_name7=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag7 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag7:
        sqft_name7.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name7
# Out:
# ['447',
#  '816',
#  '706',
#  '1,978',
#  '513',
#  '852',
#  '1,290',
#  '676',
#  '1,793',
#  '1,460',
#  '934',
#  '746',
#  '517',
#  '445',
#  '571',
#  '649',
#  '730',
#  '631',
#  '833',
#  '—',
#  '440',
#  '565',
#  '499',
#  '1,500',
#  '1,460',
#  '711',
#  '747',
#  '1,135',
#  '1,029',
#  '749',
#  '1,081',
#  '588',
#  '925',
#  '662',
#  '689',
#  '711',
#  '—',
#  '687',
#  '2,050',
#  '1,180',
#  '809',
#  '585',
#  '587',
#  '1,121',
#  '1,000',
#  '746',
#  '1,068',
#  '526',
#  '653',
#  '3,968',
#  '1,406',
#  '843',
#  '600',
#  '788',
#  '1,063',
#  '590',
#  '592',
#  '1,115',
#  '1,410',
#  '580',
#  '768',
#  '654',
#  '679',
#  '517',
#  '628',
#  '700',
#  '836',
#  '483',
#  '1,270',
#  '480',
#  '643',
#  '1,493',
#  '894',
#  '547',
#  '767',
#  '865',
#  '1,000',
#  '517',
#  '1,095',
#  '581',
#  '1,535',
#  '809',
#  '688',
#  '903',
#  '660',
#  '801',
#  '802',
#  '—',
#  '—',
#  '—',
#  '413',
#  '—',
#  '1,303',
#  '—',
#  '605',
#  '641',
# ...

# %%
len(sqft_name7)
# Out:
# 123

# %%
ppsqft_name7=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag7 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag7:
        ppsqft_name7.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name7
# Out:
# ['$527',
#  '$567',
#  '$510',
#  '$836',
#  '$632',
#  '$1,065',
#  '$503',
#  '$634',
#  '$755',
#  '$252',
#  '$440',
#  '$643',
#  '$1,369',
#  '$859',
#  '$680',
#  '$773',
#  '$907',
#  '$529',
#  '$704',
#  '$552',
#  '$498',
#  '$690',
#  '$457',
#  '$778',
#  '$678',
#  '$682',
#  '$686',
#  '$543',
#  '$460',
#  '$621',
#  '$608',
#  '$489',
#  '$504',
#  '$172',
#  '$776',
#  '$483',
#  '$548',
#  '$480',
#  '$624',
#  '$487',
#  '$588',
#  '$639',
#  '$893',
#  '$697',
#  '$397',
#  '—',
#  '$475',
#  '$625',
#  '$877',
#  '$426',
#  '$751',
#  '$587',
#  '$546',
#  '$508',
#  '$440',
#  '$868',
#  '$449',
#  '$691',
#  '$470',
#  '$599',
#  '$447',
#  '$409',
#  '$289',
#  '$520',
#  '$671',
#  '$439',
#  '$398',
#  '$548',
#  '$566',
#  '$735',
#  '$345',
#  '$685',
#  '$457',
#  '$571',
#  '$679',
#  '$608',
#  '$738',
#  '$631',
#  '$511',
#  '$686',
#  '$531',
#  '$588',
#  '$616',
#  '$731',
#  '$374',
#  '—',
#  '$596',
#  '$645',
#  '$590',
#  '$654',
#  '$474',
# ...

# %%
len(ppsqft_name7)
# Out:
# 123

# %%
print(len(address_name7),len(price_name7),len(beds_name7),len(baths_name7),len(sqft_name7),len(ppsqft_name7))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name7[120:123]

# %%
import pandas as pd
df7=pd.DataFrame({'Address':address_name7,'Price':price_name7,'Beds':beds_name7,'Baths':baths_name7,'Total sqft':sqft_name7,'Price per sqft':ppsqft_name7})
df7
# Out:
#                                                Address       Price    Beds  \
# 0          1315 Harvard St NW #1, Washington, DC 20009    $649,900  3 beds
# 1          1315 Harvard St NW #2, Washington, DC 20009    $389,900  3 beds
# 2        800 4th St SW Unit N812, Washington, DC 20024    $247,000   1 bed
# 3               1209 G St SE #11, Washington, DC 20003  $1,050,000  2 beds
# 4    709 Rock Creek Church Rd NW #2, Washington, DC...     $40,000  2 beds
# ..                                                 ...         ...     ...
# 115         2250 11th St NW #108, Washington, DC 20001    $789,000   1 bed
# 116         1628 11th St NW #203, Washington, DC 20001    $797,000   1 bed
# 117          2709 N N St NW #101, Washington, DC 20007    $479,000  0 beds
# 118  4014 Georgia Ave NW Unit C02, Washington, DC 2...    $499,700  2 beds
# 119       1920 Naylor Rd SE #107, Washington, DC 20020    $624,900   1 bed
#
#          Baths Total sqft Price per sqft
# ...

# %%
df7.to_csv('file7.csv')

# %%
SanFrancisco_condos=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[15]/div[2]/a').click()

# %%
address_name8=[]
price_name8=[]
beds_name8=[]
baths_name8=[]
sqft_name8=[]
ppsqft_name8=[]

# %%
address_name8=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag8 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag8:
        address_name8.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name8
# Out:
# ['368 Elm St #304, San Francisco, CA 94102',
#  '960 Natoma St #4, San Francisco, CA 94103',
#  '288 Union St #3, San Francisco, CA 94133',
#  '960 Market St #509, San Francisco, CA 94102',
#  '2 Mint Plz #308, San Francisco, CA 94103',
#  '403 Main St Unit 608N, San Francisco, CA 94105',
#  '333 Main St Unit 5K, San Francisco, CA 94105',
#  '4537 California St, San Francisco, CA 94118',
#  '1585 10th Ave #3, San Francisco, CA 94122',
#  '200 Brannan St #136, San Francisco, CA 94107',
#  '239 Brannan St Unit 10G, San Francisco, CA 94107',
#  '597 21st Ave, San Francisco, CA 94121',
#  '875 La Playa St #182, San Francisco, CA 94121',
#  '338 Potrero Ave #607, San Francisco, CA 94103',
#  '1624 Larkin St #1, San Francisco, CA 94109',
#  '1028 Sanchez St, San Francisco, CA 94114',
#  '152 Lombard St #707, San Francisco, CA 94111',
#  '425 1st St #3406, San Francisco, CA 94105',
#  '875 California St #601, San Francisco, CA 94108',
#  '719 Clementina St #2, San Francisco, CA 94103',
# ...

# %%
len(address_name8)
# Out:
# 120

# %%
price_name8=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag8 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag8:
        price_name8.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name8

# %%
len(price_name8)
# Out:
# 120

# %%
beds_name8=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag8 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag8:
        beds_name8.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name8
# Out:
# ['2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '0 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '0 beds',
#  '0 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '0 beds',
#  '1 bed',
#  '1 bed',
#  '0 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '0 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '3 beds',
# ...

# %%
len(beds_name8)
# Out:
# 120

# %%
baths_name8=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag8 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag8:
        baths_name8.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_tag8
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fe82916cfe2bb1ccf1dad1985910c058", element="f.11507EF77D504AAE45C4AD3EE6D8FF7E.d.EA9CD2567B43C08E158BF5338A63C1C1.e.85103")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe82916cfe2bb1ccf1dad1985910c058", element="f.11507EF77D504AAE45C4AD3EE6D8FF7E.d.EA9CD2567B43C08E158BF5338A63C1C1.e.85040")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe82916cfe2bb1ccf1dad1985910c058", element="f.11507EF77D504AAE45C4AD3EE6D8FF7E.d.EA9CD2567B43C08E158BF5338A63C1C1.e.84980")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe82916cfe2bb1ccf1dad1985910c058", element="f.11507EF77D504AAE45C4AD3EE6D8FF7E.d.EA9CD2567B43C08E158BF5338A63C1C1.e.84917")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe82916cfe2bb1ccf1dad1985910c058", element="f.11507EF77D504AAE45C4AD3EE6D8FF7E.d.EA9CD2567B43C08E158BF5338A63C1C1.e.84854")>,
# ...

# %%
len(baths_name8)
# Out:
# 120

# %%
sqft_name8=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag8 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag8:
        sqft_name8.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
del sqft_tag8

# %%
sqft_name8
# Out:
# ['699',
#  '904',
#  '970',
#  '970',
#  '727',
#  '539',
#  '829',
#  '2,206',
#  '732',
#  '866',
#  '1,516',
#  '1,248',
#  '986',
#  '653',
#  '—',
#  '1,270',
#  '1,460',
#  '1,238',
#  '1,408',
#  '2,175',
#  '2,290',
#  '1,358',
#  '843',
#  '1,637',
#  '896',
#  '2,065',
#  '551',
#  '882',
#  '485',
#  '427',
#  '1,080',
#  '1,034',
#  '825',
#  '828',
#  '1,068',
#  '655',
#  '650',
#  '1,645',
#  '600',
#  '1,275',
#  '1,102',
#  '1,023',
#  '1,100',
#  '1,505',
#  '1,374',
#  '1,128',
#  '1,493',
#  '—',
#  '868',
#  '1,413',
#  '1,131',
#  '1,479',
#  '760',
#  '1,309',
#  '1,850',
#  '—',
#  '1,792',
#  '1,571',
#  '941',
#  '1,237',
#  '1,079',
#  '1,284',
#  '1,538',
#  '2,039',
#  '2,300',
#  '968',
#  '738',
#  '851',
#  '500',
#  '1,202',
#  '1,600',
#  '1,405',
#  '1,023',
#  '1,311',
#  '1,658',
#  '—',
#  '—',
#  '—',
#  '846',
#  '1,086',
#  '1,192',
#  '1,102',
#  '1,353',
#  '568',
#  '1,951',
#  '1,370',
#  '598',
#  '1,875',
#  '1,101',
#  '1,378',
# ...

# %%
len(sqft_name8)
# Out:
# 123

# %%
ppsqft_name8=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag8 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag8:
        ppsqft_name8.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name8
# Out:
# ['$856',
#  '$773',
#  '$2,500',
#  '$1,015',
#  '$860',
#  '$963',
#  '$995',
#  '$768',
#  '$990',
#  '$1,039',
#  '$1,186',
#  '$841',
#  '$862',
#  '$1,217',
#  '—',
#  '$941',
#  '$925',
#  '$1,413',
#  '$1,634',
#  '$667',
#  '$1,037',
#  '$1,619',
#  '$1,062',
#  '$886',
#  '$876',
#  '$1,308',
#  '$1,134',
#  '$1,076',
#  '$1,289',
#  '$1,054',
#  '$1,097',
#  '$927',
#  '$927',
#  '$905',
#  '$1,215',
#  '$1,107',
#  '$1,115',
#  '$1,213',
#  '$1,100',
#  '$1,098',
#  '$1,015',
#  '$1,271',
#  '$1,077',
#  '$1,096',
#  '$797',
#  '$1,100',
#  '$737',
#  '—',
#  '$1,066',
#  '$919',
#  '$880',
#  '$1,011',
#  '$1,183',
#  '$1,066',
#  '$754',
#  '—',
#  '$1,054',
#  '$859',
#  '$923',
#  '$614',
#  '$1,108',
#  '$1,246',
#  '$647',
#  '$1,175',
#  '$1,128',
#  '$1,235',
#  '$676',
#  '$1,055',
#  '$1,040',
#  '$914',
#  '$1,122',
#  '$853',
#  '$508',
#  '$645',
#  '$1,806',
#  '—',
#  '—',
#  '—',
#  '$1,022',
#  '$1,169',
#  '$1,174',
#  '$1,015',
#  '$1,401',
#  '$1,144',
# ...

# %%
len(ppsqft_name8)
# Out:
# 123

# %%
print(len(address_name8),len(price_name8),len(beds_name8),len(baths_name8),len(sqft_name8),len(ppsqft_name8))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name8[120:123]

# %%
import pandas as pd
df8=pd.DataFrame({'Address':address_name8,'Price':price_name8,'Beds':beds_name8,'Baths':baths_name8,'Total sqft':sqft_name8,'Price per sqft':ppsqft_name8})
df8
# Out:
#                                                Address       Price    Beds  \
# 0             368 Elm St #304, San Francisco, CA 94102    $598,000  2 beds
# 1            960 Natoma St #4, San Francisco, CA 94103    $699,000  2 beds
# 2             288 Union St #3, San Francisco, CA 94133  $2,425,000   1 bed
# 3          960 Market St #509, San Francisco, CA 94102    $985,000  3 beds
# 4             2 Mint Plz #308, San Francisco, CA 94103    $625,000  3 beds
# ..                                                 ...         ...     ...
# 115     2412 Harrison St #114, San Francisco, CA 94110  $1,295,000  3 beds
# 116          119 St Marys Ave, San Francisco, CA 94112    $998,000  3 beds
# 117           555 4th St #103, San Francisco, CA 94107    $474,999  3 beds
# 118  944 South South Van Ness Ave, San Francisco, C...  $1,995,000   1 bed
# 119         1348 Scott St #17, San Francisco, CA 94115    $463,876  2 beds
#
#          Baths Total sqft Price per sqft
# ...

# %%
df8.to_csv('file8.csv')

# %%
----San JoseSan ----------------

# %%
sanjose_condos=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[17]/div[2]/a').click()

# %%
address_name9=[]
price_name9=[]
beds_name9=[]
baths_name9=[]
sqft_name9=[]
ppsqft_name9=[]

# %%
address_name9=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag9 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag9:
        address_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name9
# Out:
# ['4691 Albany Cir #133, San Jose, CA 95129',
#  '30 E Julian St #309, San Jose, CA 95112',
#  '214 Fairway Glen Ln, San Jose, CA 95139',
#  '5007 Cribari Vale, San Jose, CA 95135',
#  '3223 Lake Albano Cir, San Jose, CA 95135',
#  '3458 Wine Cask Way, San Jose, CA 95124',
#  '6822 Shutter Ct, San Jose, CA 95119',
#  '411 Park Ave #125, San Jose, CA 95110',
#  '1501 Desdemona Ct, San Jose, CA 95121',
#  '4779 Pine Forest Ln, San Jose, CA 95118',
#  '800 N 8th St #220, San Jose, CA 95112',
#  '92 Rancho Dr Unit C, San Jose, CA 95111',
#  '334 Santana Row #240, San Jose, CA 95128',
#  '1509 Briartree Dr, San Jose, CA 95131',
#  '848 Printempo Pl, San Jose, CA 95134',
#  '125 Patterson St #333, San Jose, CA 95112',
#  '820 Blossom Hill Rd #3, San Jose, CA 95123',
#  '5482 Sean Cir #20, San Jose, CA 95123',
#  '2881 Meridian Ave #367, San Jose, CA 95124',
#  '477 Tower Hill Ave, San Jose, CA 95136',
#  '38 N Almaden Blvd #1620, San Jose, CA 95110',
# ...

# %%
len(address_name9)
# Out:
# 120

# %%
price_name9=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag9 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag9:
        price_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name9
# Out:
# ['$880,000',
#  '$798,000',
#  '$789,000',
#  '$575,000',
#  '$925,000',
#  '$558,998',
#  '$1,080,000',
#  '$669,000',
#  '$749,000',
#  '$595,000',
#  '$799,888',
#  '$550,000',
#  '$798,000',
#  '$699,800',
#  '$849,000',
#  '$685,000',
#  '$569,950',
#  '$649,950',
#  '$725,000',
#  '$798,000',
#  '$1,148,000',
#  '$988,000',
#  '$735,000',
#  '$1,399,000',
#  '$399,000',
#  '$649,888',
#  '$1,200,000',
#  '$749,000',
#  '$565,000',
#  '$800,000',
#  '$800,000',
#  '$1,099,000',
#  '$599,000',
#  '$699,000',
#  '$410,000',
#  '$738,898',
#  '$708,800',
#  '$848,800',
#  '$809,800',
#  '$809,800',
#  '$807,800',
#  '$713,800',
#  '$807,800',
#  '$941,800',
#  '$789,800',
#  '$760,000',
#  '$675,000',
#  '$898,000',
#  '$795,000',
#  '$698,000',
#  '$800,000',
#  '$610,888',
#  '$899,000',
#  '$739,800',
#  '$1,016,900',
#  '$1,244,239',
#  '$549,999',
#  '$1,288,000',
#  '$1,069,000',
#  '$599,000',
#  '$515,000',
#  '$599,999',
#  '$680,000',
#  '$485,000',
#  '$540,000',
# ...

# %%
len(price_name9)
# Out:
# 120

# %%
beds_name9=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag9 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag9:
        beds_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name9
# Out:
# ['2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
# ...

# %%
len(beds_name9)
# Out:
# 120

# %%
baths_name9=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag9 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag9:
        baths_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_name9
# Out:
# ['2 baths',
#  '2 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '2 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '3 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '3 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '3.5 baths',
# ...

# %%
len( baths_name9)
# Out:
# 120

# %%
sqft_name9=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag9 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag9:
        sqft_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name9
# Out:
# ['1,350',
#  '1,271',
#  '1,220',
#  '1,223',
#  '1,457',
#  '498',
#  '1,563',
#  '1,048',
#  '1,292',
#  '817',
#  '1,214',
#  '918',
#  '736',
#  '913',
#  '925',
#  '1,218',
#  '903',
#  '1,060',
#  '971',
#  '1,104',
#  '1,296',
#  '1,529',
#  '1,096',
#  '2,506',
#  '482',
#  '1,138',
#  '1,296',
#  '1,097',
#  '831',
#  '1,245',
#  '1,187',
#  '1,581',
#  '1,056',
#  '1,242',
#  '632',
#  '1,490',
#  '902',
#  '1,119',
#  '1,067',
#  '1,067',
#  '1,138',
#  '1,067',
#  '938',
#  '1,067',
#  '1,295',
#  '1,067',
#  '1,093',
#  '922',
#  '1,071',
#  '1,420',
#  '1,066',
#  '700',
#  '988',
#  '1,267',
#  '1,034',
#  '1,291',
#  '1,690',
#  '955',
#  '2,099',
#  '1,422',
#  '1,099',
#  '798',
#  '959',
#  '1,252',
#  '1,223',
#  '1,223',
#  '2,029',
#  '1,067',
#  '813',
#  '920',
#  '1,855',
#  '1,317',
#  '777',
#  '667',
#  '990',
#  '1,156',
#  '1,127',
#  '1,178',
#  '1,250',
#  '903',
#  '1,296',
#  '1,138',
#  '1,056',
#  '1,116',
#  '1,067',
#  '1,193',
#  '1,359',
# ...

# %%
len(sqft_name9)
# Out:
# 123

# %%
ppsqft_name9=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag9 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag9:
        ppsqft_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name9
# Out:
# ['$652',
#  '$628',
#  '$647',
#  '$470',
#  '$635',
#  '$1,122',
#  '$691',
#  '$638',
#  '$580',
#  '$728',
#  '$659',
#  '$599',
#  '$1,084',
#  '$766',
#  '$918',
#  '$562',
#  '$631',
#  '$613',
#  '$747',
#  '$723',
#  '$886',
#  '$646',
#  '$671',
#  '$558',
#  '$828',
#  '$571',
#  '$926',
#  '$683',
#  '$680',
#  '$643',
#  '$674',
#  '$695',
#  '$567',
#  '$563',
#  '$649',
#  '$496',
#  '$786',
#  '$759',
#  '$759',
#  '$759',
#  '$671',
#  '$757',
#  '$761',
#  '$757',
#  '$727',
#  '$740',
#  '$695',
#  '$732',
#  '$838',
#  '$560',
#  '$655',
#  '$1,143',
#  '$618',
#  '$710',
#  '$715',
#  '$788',
#  '$736',
#  '$576',
#  '$614',
#  '$752',
#  '$545',
#  '$645',
#  '$626',
#  '$543',
#  '$397',
#  '$442',
#  '$695',
#  '$655',
#  '$711',
#  '$685',
#  '$646',
#  '$606',
#  '$579',
#  '$719',
#  '$696',
#  '$605',
#  '$788',
#  '$573',
#  '$640',
#  '$554',
#  '$871',
#  '$671',
#  '$596',
#  '$650',
#  '$655',
#  '$654',
#  '$736',
#  '$458',
#  '$650',
#  '$715',
# ...

# %%
len(ppsqft_name9)
# Out:
# 123

# %%
print(len(address_name9),len(price_name9),len(beds_name9),len(baths_name9),len(sqft_name9),len(ppsqft_name9))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name9[120:123]

# %%
import pandas as pd
df9=pd.DataFrame({'Address':address_name9,'Price':price_name9,'Beds':beds_name9,'Baths':baths_name9,'Total sqft':sqft_name9,'Price per sqft':ppsqft_name9})
df9
# Out:
#                                       Address       Price    Beds      Baths  \
# 0    4691 Albany Cir #133, San Jose, CA 95129    $880,000  2 beds    2 baths
# 1     30 E Julian St #309, San Jose, CA 95112    $798,000  2 beds    2 baths
# 2     214 Fairway Glen Ln, San Jose, CA 95139    $789,000  3 beds  1.5 baths
# 3       5007 Cribari Vale, San Jose, CA 95135    $575,000  2 beds    2 baths
# 4    3223 Lake Albano Cir, San Jose, CA 95135    $925,000  2 beds    2 baths
# ..                                        ...         ...     ...        ...
# 115  1487 Tierra Buena Dr, San Jose, CA 95121    $650,000  2 beds  1.5 baths
# 116         888 Catkin Ct, San Jose, CA 95128    $475,000   1 bed     1 bath
# 117      88 Bush St #3207, San Jose, CA 95126    $949,000  2 beds    2 baths
# 118    2503 Easton Pl #40, San Jose, CA 95133    $599,000  2 beds    2 baths
# 119  333 Santana Row #208, San Jose, CA 95128  $1,300,000  2 beds  1.5 baths
#
#     Total sqft Price per sqft
# ...

# %%
df9.to_csv('file9.csv')

# %%
------------Austin-------

# %%
austin_condos=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[19]/div[2]/a').click()

# %%
address_name10=[]
price_name10=[]
beds_name10=[]
baths_name10=[]
sqft_name10=[]
ppsqft_name10=[]

# %%
address_name10=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag10 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag10:
        address_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-10-b3a752acded2> in <module>
#       8         address_name10.append(i.text)
#       9     next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
# ---> 10     next_button.click()
#      11     time.sleep(3)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      92     def click(self) -> None:
#      93         """Clicks the element."""
# ---> 94         self._execute(Command.CLICK_ELEMENT)
#      95
#      96     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     393             params = {}
#     394         params["id"] = self._id
# ...

# %%
 address_name10
# Out:
# ['2906 Kuhlman Ave Unit B, Austin, TX 78702',
#  '2906 S 1st St #203, Austin, TX 78704',
#  '12166 Metric Blvd #213, Austin, TX 78758',
#  '2207 Leon St #302, Austin, TX 78705',
#  'Undisclosed address, Austin, TX 78703',
#  '313 Hackberry Ln Unit B, Austin, TX 78753',
#  '5924 S Congress Ave Unit 71-S, Austin, TX 78745',
#  '1010 W 23rd St #16, Austin, TX 78705',
#  '908 Nueces St #32, Austin, TX 78701',
#  '1212 Guadalupe St #803, Austin, TX 78701',
#  '501 West Ave #1306, Austin, TX 78701',
#  '5820 Berkman Dr #215, Austin, TX 78723',
#  '4801 Springdale Rd #1211, Austin, TX 78723',
#  '360 Nueces St #2508, Austin, TX 78701',
#  '14618 Mansfield Dam Ct #11, Austin, TX 78734',
#  '7401 Evening Sky Cir Unit G1, Austin, TX 78735',
#  '14001 Avery Ranch Blvd #2203, Austin, TX 78717',
#  '4209 Burnet Rd #206, Austin, TX 78756',
#  '13420 Lyndhurst St #505, Austin, TX 78729',
#  '1701 Simond Ave #520, Austin, TX 78723',
#  '3815 Guadalupe St #304, Austin, TX 78751',
# ...

# %%
len( address_name10)
# Out:
# 120

# %%
price_name10=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag10 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag10:
        price_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
price_name10

# %%
len(price_name10)
# Out:
# 120

# %%
beds_name10=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag10 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag10:
        beds_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name10
# Out:
# ['2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '0 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '3 beds',
# ...

# %%
len(beds_name10)
# Out:
# 120

# %%
baths_name10=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag10 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag10:
        baths_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
baths_name10
# Out:
# ['2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1.5 baths',
#  '1 bath',
#  '3 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '1 bath',
#  '2 baths',
#  '3.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
# ...

# %%
len(baths_name10)
# Out:
# 120

# %%
sqft_name10=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag10 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag10:
        sqft_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name10
# Out:
# ['1,100',
#  '1,040',
#  '516',
#  '550',
#  '1,211',
#  '2,187',
#  '1,380',
#  '394',
#  '1,146',
#  '850',
#  '652',
#  '633',
#  '872',
#  '732',
#  '3,058',
#  '2,276',
#  '1,571',
#  '750',
#  '1,376',
#  '1,131',
#  '880',
#  '2,078',
#  '713',
#  '750',
#  '1,932',
#  '796',
#  '935',
#  '1,004',
#  '403',
#  '2,607',
#  '3,248',
#  '878',
#  '1,500',
#  '2,197',
#  '1,373',
#  '1,033',
#  '756',
#  '2,244',
#  '1,837',
#  '777',
#  '1,142',
#  '820',
#  '1,839',
#  '1,236',
#  '689',
#  '1,322',
#  '904',
#  '796',
#  '2,119',
#  '1,565',
#  '2,087',
#  '2,000',
#  '652',
#  '857',
#  '1,550',
#  '2,003',
#  '1,753',
#  '764',
#  '811',
#  '701',
#  '450',
#  '1,476',
#  '1,004',
#  '732',
#  '1,207',
#  '981',
#  '450',
#  '945',
#  '2,252',
#  '515',
#  '1,614',
#  '2,009',
#  '1,144',
#  '2,871',
#  '1,108',
#  '1,092',
#  '1,480',
#  '918',
#  '1,983',
#  '515',
#  '633',
#  '1,142',
#  '992',
#  '1,350',
#  '1,080',
#  '1,176',
#  '969',
#  '892',
#  '1,172',
#  '968',
# ...

# %%
len(sqft_name10)
# Out:
# 123

# %%
ppsqft_name10=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag10 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag10:
        ppsqft_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
ppsqft_name10
# Out:
# ['$258',
#  '$421',
#  '$430',
#  '$580',
#  '$441',
#  '$386',
#  '$983',
#  '$342',
#  '$238',
#  '$301',
#  '$298',
#  '$338',
#  '$1,132',
#  '$323',
#  '$312',
#  '$404',
#  '$293',
#  '$605',
#  '$455',
#  '$280',
#  '$258',
#  '$428',
#  '$446',
#  '$281',
#  '$421',
#  '$262',
#  '$329',
#  '$545',
#  '$271',
#  '$390',
#  '$400',
#  '$382',
#  '$362',
#  '$333',
#  '$358',
#  '$351',
#  '$224',
#  '$556',
#  '$252',
#  '$453',
#  '$393',
#  '$248',
#  '$448',
#  '$321',
#  '$548',
#  '$528',
#  '$443',
#  '$367',
#  '$904',
#  '$2,721',
#  '$2,364',
#  '$268',
#  '$343',
#  '$1,058',
#  '$642',
#  '$574',
#  '$360',
#  '$352',
#  '$385',
#  '$353',
#  '$357',
#  '$703',
#  '$512',
#  '$239',
#  '$176',
#  '$263',
#  '$284',
#  '$520',
#  '$528',
#  '$203',
#  '$506',
#  '$919',
#  '$321',
#  '$568',
#  '$251',
#  '$477',
#  '$437',
#  '$495',
#  '$330',
#  '$651',
#  '$307',
#  '$393',
#  '$346',
#  '$489',
#  '$251',
#  '$275',
#  '$313',
#  '$351',
#  '$966',
#  '$353',
# ...

# %%
len(ppsqft_name10)
# Out:
# 123

# %%
print(len(address_name10),len(price_name10),len(beds_name10),len(baths_name10),len(sqft_name10),len(ppsqft_name10))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name10[120:123]

# %%
import pandas as pd
df10=pd.DataFrame({'Address':address_name10,'Price':price_name10,'Beds':beds_name10,'Baths':baths_name10,'Total sqft':sqft_name10,'Price per sqft':ppsqft_name10})
df10
# Out:
#                                          Address     Price    Beds      Baths  \
# 0      2906 Kuhlman Ave Unit B, Austin, TX 78702  $575,000  2 beds    2 baths
# 1           2906 S 1st St #203, Austin, TX 78704  $439,000   1 bed     1 bath
# 2       12166 Metric Blvd #213, Austin, TX 78758  $179,900   1 bed     1 bath
# 3            2207 Leon St #302, Austin, TX 78705  $235,000   1 bed     1 bath
# 4          Undisclosed address, Austin, TX 78703  $535,000  2 beds    2 baths
# ..                                           ...       ...     ...        ...
# 115  2701 Northeast Dr Unit B2, Austin, TX 78723  $319,000  3 beds  2.5 baths
# 116     2525 S Lamar Blvd #218, Austin, TX 78704  $549,000  2 beds     1 bath
# 117      935 La Posada Dr #116, Austin, TX 78752  $229,900   1 bed     1 bath
# 118      1900 Albury Cv Unit B, Austin, TX 78758  $399,900  2 beds    2 baths
# 119        2303 E Side Dr #102, Austin, TX 78704  $349,950  2 beds    2 baths
#
#     Total sqft Price per sqft
# ...

# %%
df10.to_csv('file10.csv')

# %%
----------Las Vegas------------

# %%
/html/body/div[1]/div[6]/div[2]/div/div[1]/div[21]/div[2]/a

# %%
lasvagas_condos=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div[2]/div/div[1]/div[21]/div[2]/a').click()

# %%
address_name10=[]
price_name10=[]
beds_name10=[]
baths_name10=[]
sqft_name10=[]
ppsqft_name10=[]

# %%
address_name10=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag10 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag10:
        address_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
address_name10
# Out:
# ['2451 N Rainbow Blvd #2149, Las Vegas, NV 89108',
#  '353 E Bonneville Ave #145, Las Vegas, NV 89101',
#  '6512 Ironbark Ln, Las Vegas, NV 89107',
#  '35 Agate Ave #405, Las Vegas, NV 89123',
#  '3450 Erva St #252, Las Vegas, NV 89117',
#  '10550 W Alexander Rd #2227, Las Vegas, NV 89129',
#  '322 Karen Ave #2003, Las Vegas, NV 89109',
#  '353 E Bonneville Ave #762, Las Vegas, NV 89101',
#  '4575 Dean Martin Dr #601, Las Vegas, NV 89103',
#  '7950 W Flamingo Rd #1096, Las Vegas, NV 89147',
#  '8255 Las Vegas Blvd #1318, Las Vegas, NV 89123',
#  '5260 Indian River Dr #247, Las Vegas, NV 89103',
#  '1725 Pacific Breeze Dr, Las Vegas, NV 89144',
#  '6170 E Sahara Ave #1063, Las Vegas, NV 89142',
#  '4720 Obannon Dr Unit D, Las Vegas, NV 89102',
#  '8725 W Flamingo Rd #139, Las Vegas, NV 89147',
#  '7203 Mission Hills Dr, Las Vegas, NV 89113',
#  '7123 S Durango Dr #206, Las Vegas, NV 89113',
#  '3750 Las Vegas Blvd #4603, Las Vegas, NV 89158',
# ...

# %%
len(address_name10)
# Out:
# 120

# %%
price_name10=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag10 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag10:
        price_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
 price_name10
# Out:
# ['$175,000',
#  '$480,000',
#  '$289,999',
#  '$299,500',
#  '$260,000',
#  '$330,000',
#  '$405,000',
#  '$449,900',
#  '$397,000',
#  '$290,000',
#  '$385,000',
#  '$225,000',
#  '$459,900',
#  '$238,000',
#  '$204,900',
#  '$310,000',
#  '$487,500',
#  '$275,000',
#  '$8,995,000',
#  '$255,000',
#  '$409,888',
#  '$279,000',
#  '$220,000',
#  '$265,000',
#  '$232,000',
#  '$238,000',
#  '$235,000',
#  '$333,000',
#  '$237,000',
#  '$300,000',
#  '$1,249,000',
#  '$170,000',
#  '$339,000',
#  '$250,000',
#  '$242,000',
#  '$298,900',
#  '$177,000',
#  '$229,900',
#  '$364,900',
#  '$259,000',
#  '$319,000',
#  '$255,888',
#  '$290,000',
#  '$214,900',
#  '$265,000',
#  '$220,000',
#  '$170,000',
#  '$240,000',
#  '$335,000',
#  '$207,500',
#  '$175,000',
#  '$225,000',
#  '$360,000',
#  '$530,000',
#  '$249,900',
#  '$319,900',
#  '$215,000',
#  '$299,900',
#  '$3,500,000',
#  '$260,000',
#  '$549,000',
#  '$240,000',
#  '$455,000',
#  '$190,000',
#  '$249,995',
#  '$499,000',
# ...

# %%
len( price_name10)
# Out:
# 120

# %%
//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]

# %%
beds_name10=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag10 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag10:
        beds_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
beds_name10
# Out:
# ['1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
# ...

# %%
len(beds_name10)
# Out:
# 120

# %%
first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
first_button.click()

# %%
baths_name10=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag10 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag10:
        baths_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name10
# Out:
# ['1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
# ...

# %%
len(baths_name10)
# Out:
# 120

# %%
sqft_name10=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag10 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag10:
        sqft_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)

# %%
sqft_name10
# Out:
# ['720',
#  '1,271',
#  '1,374',
#  '1,155',
#  '882',
#  '1,180',
#  '814',
#  '1,194',
#  '955',
#  '1,023',
#  '1,338',
#  '978',
#  '1,694',
#  '1,047',
#  '1,073',
#  '1,253',
#  '1,398',
#  '943',
#  '3,980',
#  '1,091',
#  '874',
#  '1,098',
#  '705',
#  '786',
#  '1,074',
#  '959',
#  '752',
#  '1,248',
#  '940',
#  '1,234',
#  '1,106',
#  '593',
#  '1,343',
#  '862',
#  '816',
#  '1,198',
#  '695',
#  '776',
#  '974',
#  '1,136',
#  '1,038',
#  '1,396',
#  '996',
#  '1,180',
#  '876',
#  '1,053',
#  '876',
#  '774',
#  '1,008',
#  '1,208',
#  '945',
#  '724',
#  '942',
#  '847',
#  '1,054',
#  '987',
#  '1,279',
#  '1,122',
#  '1,183',
#  '2,094',
#  '981',
#  '1,295',
#  '1,186',
#  '1,805',
#  '806',
#  '963',
#  '874',
#  '1,050',
#  '1,026',
#  '1,050',
#  '849',
#  '1,071',
#  '1,183',
#  '1,053',
#  '668',
#  '998',
#  '774',
#  '1,068',
#  '1,127',
#  '1,053',
#  '636',
#  '1,038',
#  '1,067',
#  '542',
#  '1,612',
#  '998',
#  '2,455',
#  '987',
#  '1,337',
# ...

# %%
first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
first_button.click()

# %%
ppsqft_name10=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag10 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag10:
        ppsqft_name10.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name10
# Out:
# ['$243',
#  '$378',
#  '$211',
#  '$259',
#  '$295',
#  '$280',
#  '$498',
#  '$377',
#  '$416',
#  '$283',
#  '$288',
#  '$230',
#  '$271',
#  '$227',
#  '$191',
#  '$247',
#  '$349',
#  '$292',
#  '$2,260',
#  '$234',
#  '$469',
#  '$254',
#  '$312',
#  '$337',
#  '$216',
#  '$248',
#  '$313',
#  '$267',
#  '$252',
#  '$243',
#  '$1,129',
#  '$287',
#  '$252',
#  '$290',
#  '$297',
#  '$249',
#  '$255',
#  '$296',
#  '$375',
#  '$228',
#  '$263',
#  '$243',
#  '$378',
#  '$211',
#  '$259',
#  '$295',
#  '$280',
#  '$498',
#  '$377',
#  '$416',
#  '$283',
#  '$288',
#  '$230',
#  '$271',
#  '$227',
#  '$191',
#  '$247',
#  '$349',
#  '$292',
#  '$2,260',
#  '$234',
#  '$469',
#  '$254',
#  '$312',
#  '$337',
#  '$216',
#  '$248',
#  '$313',
#  '$267',
#  '$252',
#  '$243',
#  '$1,129',
#  '$287',
#  '$252',
#  '$290',
#  '$297',
#  '$249',
#  '$255',
#  '$296',
#  '$375',
#  '$228',
#  '$263',
#  '$243',
#  '$378',
#  '$211',
#  '$259',
#  '$295',
#  '$280',
#  '$498',
#  '$377',
# ...

# %%
len(ppsqft_name10)
# Out:
# 123

# %%
print(len(address_name10),len(price_name10),len(beds_name10),len(baths_name10),len(sqft_name10),len(ppsqft_name10))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name10[120:123]

# %%
import pandas as pd
df10=pd.DataFrame({'Address':address_name10,'Price':price_name10,'Beds':beds_name10,'Baths':baths_name10,'Total sqft':sqft_name10,'Price per sqft':ppsqft_name10})
df10
# Out:
#                                              Address     Price    Beds  \
# 0     2451 N Rainbow Blvd #2149, Las Vegas, NV 89108  $175,000   1 bed
# 1     353 E Bonneville Ave #145, Las Vegas, NV 89101  $480,000  2 beds
# 2              6512 Ironbark Ln, Las Vegas, NV 89107  $289,999  2 beds
# 3             35 Agate Ave #405, Las Vegas, NV 89123  $299,500  2 beds
# 4             3450 Erva St #252, Las Vegas, NV 89117  $260,000  2 beds
# ..                                               ...       ...     ...
# 115        908 Duckhorn Ct #205, Las Vegas, NV 89144  $335,000  2 beds
# 116          322 Karen Ave #202, Las Vegas, NV 89109  $580,000  2 beds
# 117      7255 W Sunset Rd #2018, Las Vegas, NV 89113  $248,000   1 bed
# 118         2838 Geary Pl #4002, Las Vegas, NV 89109  $195,000   1 bed
# 119  2000 Fashion Show Dr #2922, Las Vegas, NV 89109  $495,000   1 bed
#
#          Baths Total sqft Price per sqft
# 0       1 bath        720           $243
# ...

# %%
df10.to_csv('file10.csv')

# %%
----------New York homes---------

# %%
address_name11=[]
price_name11=[]
beds_name11=[]
baths_name11=[]
sqft_name11=[]
ppsqft_name11=[]

# %%
address_name11=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag11 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag11:
        address_name11.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name11
# Out:
# ['25 Tudor City Pl #1605, New York, NY 10017',
#  '141-17 Union Tpke #2, Kew Garden Hills, NY 11367',
#  '1 Plaza St W Unit 10C, Brooklyn, NY 11217',
#  '261 W 112th St Unit 5E, New York, NY 10026',
#  '103 Beach 221st St, New York, NY 11697',
#  '750 Kappock St #807, Bronx, NY 10463',
#  '350 W 42nd St Unit 18B, New York, NY 10036',
#  '135 W 58th St Unit 4C5C, New York, NY 10019',
#  '549 41st St Unit 2A, Brooklyn, NY 11232',
#  '485 Central Park W Unit 2-G, New York, NY 10025',
#  '460 E 79th St Unit 15-A, New York, NY 10075',
#  '785 Park Ave Unit 19B, New York, NY 10021',
#  '137 Covington Cir, Staten Island, NY 10312',
#  '123 Ridgeway Ave, Staten Island, NY 10314',
#  '240 W 121st St, New York, NY 10027',
#  '231 Berry St, Brooklyn, NY 11249',
#  '780 W End Ave Unit 5B, New York, NY 10025',
#  '49 W 12th St Unit 10C, New York, NY 10011',
#  '231 E 60th St, New York, NY 10022',
#  '345 E 80th St Unit 6EF, New York, NY 10075',
#  '4380 Vireo Ave Unit 1D, Bronx, NY 10470',
# ...

# %%
len(address_name11)
# Out:
# 120

# %%
price_name11=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag11 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag11:
        price_name11.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name11
# Out:
# ['$499,000',
#  '$275,000',
#  '$925,000',
#  '$995,000',
#  '$1,495,000',
#  '$569,999',
#  '$998,000',
#  '$1,495,000',
#  '$599,000',
#  '$599,995',
#  '$1,695,000',
#  '$4,500,000',
#  '$1,425,000',
#  '$599,999',
#  '$3,595,000',
#  '$2,500,000',
#  '$2,300,000',
#  '$1,995,000',
#  '$4,495,000',
#  '$2,200,000',
#  '$179,000',
#  '$1,379,999',
#  '$690,000',
#  '$2,195,000',
#  '$1,975,000',
#  '$980,000',
#  '$525,000',
#  '$4,500,000',
#  '$998,000',
#  '$950,000',
#  '$599,000',
#  '$688,800',
#  '$749,000',
#  '$850,000',
#  '$1,295,000',
#  '$1,850,000',
#  '$1,425,000',
#  '$1,900,000',
#  '$5,200,000',
#  '$1,250,000',
#  '$499,000',
#  '$275,000',
#  '$925,000',
#  '$995,000',
#  '$1,495,000',
#  '$569,999',
#  '$998,000',
#  '$1,495,000',
#  '$599,000',
#  '$599,995',
#  '$1,695,000',
#  '$4,500,000',
#  '$1,425,000',
#  '$599,999',
#  '$3,595,000',
#  '$2,500,000',
#  '$2,300,000',
#  '$1,995,000',
#  '$4,495,000',
#  '$2,200,000',
#  '$179,000',
#  '$1,379,999',
# ...

# %%
len(price_name11)
# Out:
# 120

# %%
beds_name11=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag11 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag11:
        beds_name11.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name11
# Out:
# ['1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '10 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
#  '0 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '10 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
#  '0 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
# ...

# %%
len(beds_name11)
# Out:
# 120

# %%
baths_name11=[]
# scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag11 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag11:
        baths_name11.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name11
# Out:
# ['1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '3 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '3.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '3.5 baths',
#  '3.5 baths',
#  '3 baths',
#  '2 baths',
#  '4.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '4.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1.5 baths',
#  '4.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '4 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '3 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '3.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '3.5 baths',
#  '3.5 baths',
#  '3 baths',
#  '2 baths',
#  '4.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '4.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1.5 baths',
#  '4.5 baths',
#  '2 baths',
# ...

# %%
sqft_name11=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag11 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag11:
        sqft_name11.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
del sqft_tag11

# %%
sqft_name11
# Out:
# ['—',
#  '—',
#  '—',
#  '1,061',
#  '—',
#  '1,500',
#  '712',
#  '—',
#  '850',
#  '600',
#  '1,241',
#  '—',
#  '2,554',
#  '1,204',
#  '4,080',
#  '1,800',
#  '1,562',
#  '—',
#  '5,100',
#  '1,550',
#  '750',
#  '2,838',
#  '502',
#  '—',
#  '2,000',
#  '838',
#  '—',
#  '—',
#  '1,635',
#  '1,679',
#  '—',
#  '—',
#  '1,085',
#  '—',
#  '—',
#  '—',
#  '—',
#  '—',
#  '2,630',
#  '—',
#  '1,826',
#  '—',
#  '—',
#  '—',
#  '1,061',
#  '—',
#  '1,500',
#  '712',
#  '—',
#  '850',
#  '600',
#  '1,241',
#  '—',
#  '2,554',
#  '1,204',
#  '4,080',
#  '1,800',
#  '1,562',
#  '—',
#  '5,100',
#  '1,550',
#  '750',
#  '2,838',
#  '502',
#  '—',
#  '2,000',
#  '838',
#  '—',
#  '—',
#  '1,635',
#  '1,679',
#  '—',
#  '—',
#  '1,085',
#  '—',
#  '—',
#  '—',
#  '—',
#  '—',
#  '2,630',
#  '—',
#  '1,826',
#  '—',
#  '—',
#  '—',
#  '1,061',
#  '—',
#  '1,500',
#  '712',
#  '—',
#  '850',
#  '600',
#  '1,241',
#  '—',
#  '2,554',
#  '1,204',
#  '4,080',
#  '1,800',
#  '1,562',
#  '—',
# ...

# %%
ppsqft_name9=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag11 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag11:
        ppsqft_name11.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name11
# Out:
# ['—',
#  '—',
#  '—',
#  '$938',
#  '—',
#  '$380',
#  '$1,402',
#  '—',
#  '$705',
#  '$1,000',
#  '$1,366',
#  '—',
#  '$558',
#  '$498',
#  '$881',
#  '$1,389',
#  '$1,472',
#  '—',
#  '$881',
#  '$1,419',
#  '$239',
#  '$486',
#  '$1,375',
#  '—',
#  '$988',
#  '$1,169',
#  '—',
#  '—',
#  '$610',
#  '$566',
#  '—',
#  '—',
#  '$690',
#  '—',
#  '—',
#  '—',
#  '—',
#  '—',
#  '$1,977',
#  '—',
#  '$938',
#  '—',
#  '—',
#  '—',
#  '$938',
#  '—',
#  '$380',
#  '$1,402',
#  '—',
#  '$705',
#  '$1,000',
#  '$1,366',
#  '—',
#  '$558',
#  '$498',
#  '$881',
#  '$1,389',
#  '$1,472',
#  '—',
#  '$881',
#  '$1,419',
#  '$239',
#  '$486',
#  '$1,375',
#  '—',
#  '$988',
#  '$1,169',
#  '—',
#  '—',
#  '$610',
#  '$566',
#  '—',
#  '—',
#  '$690',
#  '—',
#  '—',
#  '—',
#  '—',
#  '—',
#  '$1,977',
#  '—',
#  '$938',
#  '—',
#  '—',
#  '—',
#  '$938',
#  '—',
#  '$380',
#  '$1,402',
#  '—',
#  '$705',
#  '$1,000',
#  '$1,366',
#  '—',
#  '$558',
#  '$498',
#  '$881',
#  '$1,389',
# ...

# %%
print(len(address_name11),len(price_name11),len(beds_name11),len(baths_name11),len(sqft_name11),len(ppsqft_name11))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name11[120:123]

# %%
import pandas as pd
df11=pd.DataFrame({'Address':address_name11,'Price':price_name9,'Beds':beds_name11,'Baths':baths_name11,'Total sqft':sqft_name11,'Price per sqft':ppsqft_name11})
df11
# Out:
#                                               Address       Price    Beds  \
# 0          25 Tudor City Pl #1605, New York, NY 10017    $880,000   1 bed
# 1    141-17 Union Tpke #2, Kew Garden Hills, NY 11367    $798,000   1 bed
# 2           1 Plaza St W Unit 10C, Brooklyn, NY 11217    $789,000   1 bed
# 3          261 W 112th St Unit 5E, New York, NY 10026    $575,000  2 beds
# 4              103 Beach 221st St, New York, NY 11697    $925,000  4 beds
# ..                                                ...         ...     ...
# 115         201 E 79th St Unit 4D, New York, NY 10075    $650,000  2 beds
# 116                  21-61 47th St, Astoria, NY 11105    $475,000  3 beds
# 117               112 Hicks St #3, Brooklyn, NY 11201    $949,000  2 beds
# 118       475 Park Ave Unit 11-BC, New York, NY 10022    $599,000  3 beds
# 119          13 W 13th St Unit 1A, New York, NY 10011  $1,300,000  2 beds
#
#          Baths Total sqft Price per sqft
# ...

# %%
df11.to_csv('file11.csv')

# %%
------------Raleigh homes---

# %%
address_name12=[]
price_name12=[]
beds_name12=[]
baths_name12=[]
sqft_name12=[]
ppsqft_name12=[]

# %%
address_name12=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag12 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag12:
        address_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name12
# Out:
# ['412 Grosvenor Dr, Raleigh, NC 27615',
#  '651 Pine Ridge Pl #651, Raleigh, NC 27609',
#  '7406 Randshire Way, Raleigh, NC 27616',
#  '6220 Braidwood Ct, Raleigh, NC 27612',
#  '1213 Brookside Dr, Raleigh, NC 27604',
#  '1921 Carthage Cir, Raleigh, NC 27604',
#  '5908 Crepe Myrtle Ct, Raleigh, NC 27609',
#  '10651 Tarton Fields Cir, Raleigh, NC 27617',
#  '511 S Saunders St, Raleigh, NC 27603',
#  '4441 Moss Spring Dr, Raleigh, NC 27616',
#  '3635 Water Mist Ln, Raleigh, NC 27604',
#  '5500 Southern Cross Ave, Raleigh, NC 27606',
#  '8600 Colville Ct, Raleigh, NC 27617',
#  '1308 Hedgelawn Way, Raleigh, NC 27615',
#  '5935 Paducah Dr, Raleigh, NC 27610',
#  '1201 Shaw View Aly #201, Raleigh, NC 27601',
#  '318 Glen Valley Dr, Raleigh, NC 27609',
#  '8618 Red Canyon Way, Raleigh, NC 27616',
#  '2329 Big Sky Ln #5, Raleigh, NC 27615',
#  '4233 Timberwood Dr, Raleigh, NC 27612',
#  '2805 London Bridge Ct, Raleigh, NC 27613',
#  '701 Hardin Hill Ln Unit Landrum, Knightdale, NC 27545',
# ...

# %%
price_name12=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag12 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag12:
        price_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name12
# Out:
# ['$879,900',
#  '$249,000',
#  '$599,000',
#  '$430,000',
#  '$495,000',
#  '$375,000',
#  '$485,000',
#  '$1,099,000',
#  '$400,000',
#  '$370,000',
#  '$345,000',
#  '$579,000',
#  '$525,000',
#  '$3,600,000',
#  '$385,000',
#  '$595,240',
#  '$650,000',
#  '$370,000',
#  '$575,000',
#  '$375,000',
#  '$675,000',
#  '$524,990',
#  '$499,800',
#  '$549,965',
#  '$293,000',
#  '$338,049',
#  '$947,000',
#  '$725,000',
#  '$509,725',
#  '$350,000',
#  '$600,000',
#  '$289,500',
#  '$324,900',
#  '$1,189,000',
#  '$433,801',
#  '$489,000',
#  '$563,268',
#  '$480,990',
#  '$1,650,000',
#  '$995,000',
#  '$879,900',
#  '$249,000',
#  '$599,000',
#  '$430,000',
#  '$495,000',
#  '$375,000',
#  '$485,000',
#  '$1,099,000',
#  '$400,000',
#  '$370,000',
#  '$345,000',
#  '$579,000',
#  '$525,000',
#  '$3,600,000',
#  '$385,000',
#  '$595,240',
#  '$650,000',
#  '$370,000',
#  '$575,000',
#  '$375,000',
#  '$675,000',
#  '$524,990',
#  '$499,800',
#  '$549,965',
#  '$293,000',
# ...

# %%
beds_name12=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag12 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag12:
        beds_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name12
# Out:
# ['4 beds',
#  '3 beds',
#  '6 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '6 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '5 beds',
#  '4 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '5 beds',
#  '3 beds',
#  '5 beds',
#  '5 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '6 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '6 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '5 beds',
#  '4 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '5 beds',
#  '3 beds',
# ...

# %%
baths_name12=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag12 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag12:
        baths_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name12
# Out:
# ['3.5 baths',
#  '2 baths',
#  '4 baths',
#  '3.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '5.5 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '4.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '3 baths',
#  '2.5 baths',
#  '3 baths',
#  '2 baths',
#  '2.5 baths',
#  '3 baths',
#  '3 baths',
#  '4 baths',
#  '2 baths',
#  '2.5 baths',
#  '4.5 baths',
#  '3 baths',
#  '4 baths',
#  '1.5 baths',
#  '4 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '3 baths',
#  '4.5 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '4 baths',
#  '3.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '5.5 baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '4.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '3 baths',
#  '2.5 baths',
#  '3 baths',
#  '2 baths',
#  '2.5 baths',
#  '3 baths',
#  '3 baths',
#  '4 baths',
#  '2 baths',
#  '2.5 baths',
# ...

# %%
sqft_name12=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag12 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag12:
        sqft_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 sqft_name12
# Out:
# ['3,550',
#  '1,168',
#  '3,449',
#  '2,296',
#  '1,156',
#  '1,410',
#  '1,873',
#  '5,302',
#  '748',
#  '1,285',
#  '1,679',
#  '2,777',
#  '1,693',
#  '5,413',
#  '2,377',
#  '2,599',
#  '1,868',
#  '2,106',
#  '2,387',
#  '938',
#  '2,511',
#  '2,619',
#  '2,472',
#  '3,037',
#  '1,094',
#  '1,560',
#  '3,920',
#  '3,500',
#  '3,000',
#  '1,330',
#  '2,746',
#  '1,145',
#  '1,052',
#  '2,386',
#  '1,501',
#  '2,187',
#  '2,095',
#  '2,714',
#  '4,238',
#  '2,626',
#  '2,199',
#  '3,550',
#  '1,168',
#  '3,449',
#  '2,296',
#  '1,156',
#  '1,410',
#  '1,873',
#  '5,302',
#  '748',
#  '1,285',
#  '1,679',
#  '2,777',
#  '1,693',
#  '5,413',
#  '2,377',
#  '2,599',
#  '1,868',
#  '2,106',
#  '2,387',
#  '938',
#  '2,511',
#  '2,619',
#  '2,472',
#  '3,037',
#  '1,094',
#  '1,560',
#  '3,920',
#  '3,500',
#  '3,000',
#  '1,330',
#  '2,746',
#  '1,145',
#  '1,052',
#  '2,386',
#  '1,501',
#  '2,187',
#  '2,095',
#  '2,714',
#  '4,238',
#  '2,626',
#  '2,199',
#  '3,550',
#  '1,168',
# ...

# %%
ppsqft_name12=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag12 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag12:
        ppsqft_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name12
# Out:
# ['$248',
#  '$213',
#  '$174',
#  '$187',
#  '$428',
#  '$266',
#  '$259',
#  '$207',
#  '$535',
#  '$288',
#  '$205',
#  '$208',
#  '$310',
#  '$665',
#  '$162',
#  '$229',
#  '$348',
#  '$176',
#  '$241',
#  '$400',
#  '$269',
#  '$200',
#  '$202',
#  '$181',
#  '$268',
#  '$217',
#  '$242',
#  '$207',
#  '$170',
#  '$263',
#  '$218',
#  '$253',
#  '$309',
#  '$498',
#  '$289',
#  '$224',
#  '$269',
#  '$177',
#  '$389',
#  '$379',
#  '$246',
#  '$248',
#  '$213',
#  '$174',
#  '$187',
#  '$428',
#  '$266',
#  '$259',
#  '$207',
#  '$535',
#  '$288',
#  '$205',
#  '$208',
#  '$310',
#  '$665',
#  '$162',
#  '$229',
#  '$348',
#  '$176',
#  '$241',
#  '$400',
#  '$269',
#  '$200',
#  '$202',
#  '$181',
#  '$268',
#  '$217',
#  '$242',
#  '$207',
#  '$170',
#  '$263',
#  '$218',
#  '$253',
#  '$309',
#  '$498',
#  '$289',
#  '$224',
#  '$269',
#  '$177',
#  '$389',
#  '$379',
#  '$246',
#  '$248',
#  '$213',
#  '$174',
#  '$187',
#  '$428',
#  '$266',
#  '$259',
#  '$207',
# ...

# %%
print(len(address_name12),len(price_name12),len(beds_name12),len(baths_name12),len(sqft_name12),len(ppsqft_name12))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name12[120:123]

# %%
import pandas as pd
df12=pd.DataFrame({'Address':address_name12,'Price':price_name12,'Beds':beds_name12,'Baths':baths_name12,'Total sqft':sqft_name12,'Price per sqft':ppsqft_name12})
df12
# Out:
#                                                Address       Price    Beds  \
# 0                  412 Grosvenor Dr, Raleigh, NC 27615    $879,900  4 beds
# 1            651 Pine Ridge Pl #651, Raleigh, NC 27609    $249,000  3 beds
# 2                7406 Randshire Way, Raleigh, NC 27616    $599,000  6 beds
# 3                 6220 Braidwood Ct, Raleigh, NC 27612    $430,000  4 beds
# 4                 1213 Brookside Dr, Raleigh, NC 27604    $495,000  3 beds
# ..                                                 ...         ...     ...
# 115                6405 Dry Fork Ln, Raleigh, NC 27617    $489,000  5 beds
# 116            7900 Berry Crest Ave, Raleigh, NC 27617    $563,268  3 beds
# 117  3742 Mason Bluff Dr Unit Leighton, Raleigh, NC...    $480,990  5 beds
# 118               5308 Montclair Dr, Raleigh, NC 27609  $1,650,000  5 beds
# 119             100 N Bloodworth St, Raleigh, NC 27601    $995,000  4 beds
#
#          Baths Total sqft Price per sqft
# ...

# %%
df12.to_csv('file12.csv')

# %%
-----------philadelphia -----------

# %%
address_name13=[]
price_name13=[]
beds_name13=[]
baths_name13=[]
sqft_name13=[]
ppsqft_name13=[]

# %%
address_name12=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag12 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag12:
        address_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name12
# Out:
# ['2135 Clymer St, Philadelphia, PA 19146',
#  '912 E Phil Ellena St, Philadelphia, PA 19150',
#  '3013 Glenview St, Philadelphia, PA 19149',
#  '2001 Hamilton St #1501, Philadelphia, PA 19130',
#  '224 W Ontario St, Philadelphia, PA 19140',
#  '1227 N 5th St #1, Philadelphia, PA 19122',
#  '1205 E Durham St, Philadelphia, PA 19150',
#  '6333-35 N Norwood St, Philadelphia, PA 19138',
#  '2456 N 19th St, Philadelphia, PA 19132',
#  '2825 Guilford St, Philadelphia, PA 19152',
#  '6144 Vandike St, Philadelphia, PA 19135',
#  '3301 Fitler St, Philadelphia, PA 19114',
#  '2838 N Mutter St, Philadelphia, PA 19133',
#  '2122 S Frazier St, Philadelphia, PA 19143',
#  '148 W Sharpnack St, Philadelphia, PA 19119',
#  '4328 Benner St, Philadelphia, PA 19135',
#  '1632 W Mentor St, Philadelphia, PA 19141',
#  '2504 E Hagert St, Philadelphia, PA 19125',
#  '7206 N Broad St, Philadelphia, PA 19126',
#  '2401 Pennsylvania Ave Unit 7B34, Philadelphia, PA 19130',
# ...

# %%
len(address_name12)
# Out:
# 120

# %%
price_name12=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag12 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag12:
        price_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name12
# Out:
# ['$374,999',
#  '$495,000',
#  '$271,000',
#  '$464,900',
#  '$199,999',
#  '$405,000',
#  '$424,900',
#  '$184,900',
#  '$130,000',
#  '$374,900',
#  '$199,900',
#  '$434,900',
#  '$105,000',
#  '$169,900',
#  '$364,900',
#  '$139,999',
#  '$219,900',
#  '$279,000',
#  '$389,000',
#  '$775,000',
#  '$285,000',
#  '$218,000',
#  '$237,000',
#  '$84,000',
#  '$69,900',
#  '$430,000',
#  '$429,000',
#  '$275,000',
#  '$225,000',
#  '$284,900',
#  '$689,000',
#  '$369,900',
#  '$279,900',
#  '$250,000',
#  '$354,000',
#  '$172,500',
#  '$754,900',
#  '$395,000',
#  '$299,900',
#  '$200,000',
#  '$374,999',
#  '$495,000',
#  '$271,000',
#  '$464,900',
#  '$199,999',
#  '$405,000',
#  '$424,900',
#  '$184,900',
#  '$130,000',
#  '$374,900',
#  '$199,900',
#  '$434,900',
#  '$105,000',
#  '$169,900',
#  '$364,900',
#  '$139,999',
#  '$219,900',
#  '$279,000',
#  '$389,000',
#  '$775,000',
#  '$285,000',
#  '$218,000',
#  '$237,000',
#  '$84,000',
#  '$69,900',
#  '$430,000',
# ...

# %%
len(price_name12)
# Out:
# 120

# %%
beds_name12=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag12 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag12:
        beds_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name12
# Out:
# ['2 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '— beds',
#  '3 beds',
#  '3 beds',
#  '— beds',
#  '2 beds',
#  '4 beds',
#  '6 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '0 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '6 beds',
#  '1 bed',
#  '3 beds',
#  '5 beds',
#  '— beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '— beds',
#  '3 beds',
#  '3 beds',
#  '— beds',
#  '2 beds',
#  '4 beds',
#  '6 beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '0 beds',
#  '3 beds',
#  '2 beds',
#  '4 beds',
#  '6 beds',
#  '1 bed',
#  '3 beds',
#  '5 beds',
#  '— beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
# ...

# %%
len(beds_name12)
# Out:
# 120

# %%
baths_name12=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag12 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag12:
        baths_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name12
# Out:
# ['1 bath',
#  '3.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '1.5 baths',
#  '— baths',
#  '2.5 baths',
#  '1 bath',
#  '— baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '1.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '— baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '3 baths',
#  '1 bath',
#  '1.5 baths',
#  '2 baths',
#  '— baths',
#  '1.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '3 baths',
#  '1 bath',
#  '3.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '1.5 baths',
#  '— baths',
#  '2.5 baths',
#  '1 bath',
#  '— baths',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '1 bath',
#  '1.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '— baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '3 baths',
#  '1 bath',
# ...

# %%
len(baths_name12)
# Out:
# 120

# %%
sqft_name12=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag12 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag12:
        sqft_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
sqft_name12
# Out:
# ['864',
#  '1,701',
#  '1,703',
#  '978',
#  '1,120',
#  '1,566',
#  '1,672',
#  '1,138',
#  '2,053',
#  '1,472',
#  '1,056',
#  '2,070',
#  '840',
#  '1,350',
#  '2,688',
#  '1,152',
#  '1,524',
#  '976',
#  '3,050',
#  '1,876',
#  '900',
#  '626',
#  '1,585',
#  '1,429',
#  '1,110',
#  '1,346',
#  '2,139',
#  '3,024',
#  '626',
#  '1,260',
#  '2,240',
#  '2,627',
#  '1,656',
#  '1,054',
#  '1,068',
#  '1,158',
#  '1,734',
#  '1,664',
#  '1,400',
#  '1,390',
#  '1,408',
#  '864',
#  '1,701',
#  '1,703',
#  '978',
#  '1,120',
#  '1,566',
#  '1,672',
#  '1,138',
#  '2,053',
#  '1,472',
#  '1,056',
#  '2,070',
#  '840',
#  '1,350',
#  '2,688',
#  '1,152',
#  '1,524',
#  '976',
#  '3,050',
#  '1,876',
#  '900',
#  '626',
#  '1,585',
#  '1,429',
#  '1,110',
#  '1,346',
#  '2,139',
#  '3,024',
#  '626',
#  '1,260',
#  '2,240',
#  '2,627',
#  '1,656',
#  '1,054',
#  '1,068',
#  '1,158',
#  '1,734',
#  '1,664',
#  '1,400',
#  '1,390',
#  '1,408',
#  '864',
#  '1,701',
#  '1,703',
#  '978',
# ...

# %%
len(sqft_name12)
# Out:
# 123

# %%
ppsqft_name12=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag12 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag12:
        ppsqft_name12.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name12
# Out:
# ['$434',
#  '$291',
#  '$159',
#  '$475',
#  '$179',
#  '$259',
#  '$254',
#  '$162',
#  '$63',
#  '$255',
#  '$189',
#  '$210',
#  '$125',
#  '$126',
#  '$136',
#  '$122',
#  '$144',
#  '$286',
#  '$128',
#  '$413',
#  '$317',
#  '$348',
#  '$150',
#  '$59',
#  '$63',
#  '$319',
#  '$201',
#  '$91',
#  '$359',
#  '$226',
#  '$308',
#  '$141',
#  '$169',
#  '$237',
#  '$331',
#  '$149',
#  '$435',
#  '$237',
#  '$214',
#  '$144',
#  '$214',
#  '$434',
#  '$291',
#  '$159',
#  '$475',
#  '$179',
#  '$259',
#  '$254',
#  '$162',
#  '$63',
#  '$255',
#  '$189',
#  '$210',
#  '$125',
#  '$126',
#  '$136',
#  '$122',
#  '$144',
#  '$286',
#  '$128',
#  '$413',
#  '$317',
#  '$348',
#  '$150',
#  '$59',
#  '$63',
#  '$319',
#  '$201',
#  '$91',
#  '$359',
#  '$226',
#  '$308',
#  '$141',
#  '$169',
#  '$237',
#  '$331',
#  '$149',
#  '$435',
#  '$237',
#  '$214',
#  '$144',
#  '$214',
#  '$434',
#  '$291',
#  '$159',
#  '$475',
#  '$179',
#  '$259',
#  '$254',
#  '$162',
#  '$63',
# ...

# %%
len(ppsqft_name12)
# Out:
# 123

# %%
print(len(address_name12),len(price_name12),len(beds_name12),len(baths_name12),len(sqft_name12),len(ppsqft_name12))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name12[120:123]

# %%
import pandas as pd
df13=pd.DataFrame({'Address':address_name12,'Price':price_name12,'Beds':beds_name12,'Baths':baths_name12,'Total sqft':sqft_name12,'Price per sqft':ppsqft_name12})
df13
# Out:
#                                             Address     Price    Beds  \
# 0            2135 Clymer St, Philadelphia, PA 19146  $374,999  2 beds
# 1      912 E Phil Ellena St, Philadelphia, PA 19150  $495,000  3 beds
# 2          3013 Glenview St, Philadelphia, PA 19149  $271,000  3 beds
# 3    2001 Hamilton St #1501, Philadelphia, PA 19130  $464,900  2 beds
# 4          224 W Ontario St, Philadelphia, PA 19140  $199,999  3 beds
# ..                                              ...       ...     ...
# 115       8657 Michener Ave, Philadelphia, PA 19150  $172,500  3 beds
# 116      2045 Brandywine St, Philadelphia, PA 19130  $754,900  3 beds
# 117        5541 Pulaski Ave, Philadelphia, PA 19144  $395,000  4 beds
# 118           2226 Moore St, Philadelphia, PA 19145  $299,900  3 beds
# 119       5426 Christian St, Philadelphia, PA 19143  $200,000  3 beds
#
#          Baths Total sqft Price per sqft
# 0       1 bath        864           $434
# 1    3.5 baths      1,701           $291
# ...

# %%
df13.to_csv('file13.csv')

# %%
-----------------Nashville--------------

# %%
address_name14=[]
price_name14=[]
beds_name14=[]
baths_name14=[]
sqft_name14=[]
ppsqft_name14=[]

# %%
address_name14=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag14 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag14:
        address_name14.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name14
# Out:
# ['',
#  '7277 Charlotte Pike #208, Nashville, TN 37209',
#  '903 Churchill Xing, Madison, TN 37115',
#  '119 Highland Villa Dr, Nashville, TN 37211',
#  '1212 Laurel St #701, Nashville, TN 37203',
#  '1518 Long Ave, Nashville, TN 37206',
#  '115 Forest Park Rd, Madison, TN 37115',
#  '1441 Pawnee Trl, Madison, TN 37115',
#  '553 Huntington Pkwy, Nashville, TN 37211',
#  '6609 Broken Bow Dr, Antioch, TN 37013',
#  '2508 Pleasant Green Rd, Nashville, TN 37214',
#  '4929 Hickory Woods E, Antioch, TN 37013',
#  '3605 Bentfield Dr, Antioch, TN 37013',
#  '209 Leonard Ave, Nashville, TN 37205',
#  '1815 Forest Ave, Nashville, TN 37206',
#  '4369 Chickering Ln, Nashville, TN 37215',
#  '3712 Belle Oaks Dr, Antioch, TN 37013',
#  '4005 Indiana Ave, Nashville, TN 37209',
#  '3176 Penn Meade Way, Nashville, TN 37214',
#  '810 S 12th St, Nashville, TN 37206',
#  '2016 Jones Cir, Nashville, TN 37207',
#  '2411 Old Hickory Blvd W, Nashville, TN 37221',
#  '919 Fairwin Ave, Nashville, TN 37216',
# ...

# %%
len(address_name14)
# Out:
# 123

# %%
price_name14=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag14 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag14:
        price_name14.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name14
# Out:
# ['',
#  '$398,500',
#  '$280,000',
#  '$365,000',
#  '$2,250,000',
#  '$1,075,000',
#  '$379,000',
#  '$950,000',
#  '$599,900',
#  '$489,000',
#  '$649,900',
#  '$535,000',
#  '$450,000',
#  '$2,995,000',
#  '$820,000',
#  '$3,750,000',
#  '$400,000',
#  '$1,760,000',
#  '$404,750',
#  '$495,000',
#  '$399,000',
#  '$3,399,000',
#  '$424,900',
#  '$294,700',
#  '$2,400,000',
#  '$4,300,000',
#  '$549,000',
#  '$469,000',
#  '$585,000',
#  '$385,000',
#  '$418,000',
#  '$399,900',
#  '$409,900',
#  '$540,000',
#  '$1,100,000',
#  '$875,000',
#  '$1,070,000',
#  '$439,900',
#  '$672,500',
#  '$199,900',
#  '$699,999',
#  '',
#  '$398,500',
#  '$280,000',
#  '$365,000',
#  '$2,250,000',
#  '$1,075,000',
#  '$379,000',
#  '$950,000',
#  '$599,900',
#  '$489,000',
#  '$649,900',
#  '$535,000',
#  '$450,000',
#  '$2,995,000',
#  '$820,000',
#  '$3,750,000',
#  '$400,000',
#  '$1,760,000',
#  '$404,750',
#  '$495,000',
#  '$399,000',
#  '$3,399,000',
#  '$424,900',
#  '$294,700',
# ...

# %%
len(price_name14)
# Out:
# 123

# %%
beds_name14=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag14 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag14:
        beds_name14.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name14
# Out:
# ['',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '4 beds',
#  '5 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '5 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '5 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '4 beds',
#  '4 beds',
#  '5 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '5 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '5 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
# ...

# %%
len(beds_name14)
# Out:
# 123

# %%
baths_name14=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag14 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag14:
        baths_name14.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name14
# Out:
# ['',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '3 baths',
#  '3 baths',
#  '2 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '6 baths',
#  '3 baths',
#  '5 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '4.5 baths',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '6 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '1 bath',
#  '4 baths',
#  '',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '3 baths',
#  '3 baths',
#  '2 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '6 baths',
#  '3 baths',
#  '5 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '4.5 baths',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '6 baths',
#  '2 baths',
# ...

# %%
len(baths_name14)
# Out:
# 123

# %%
sqft_name14=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag14 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag14:
        sqft_name14.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
sqft_name14
# Out:
# ['1,512',
#  '1,139',
#  '1,348',
#  '1,916',
#  '2,632',
#  '1,552',
#  '2,601',
#  '2,235',
#  '2,151',
#  '1,793',
#  '2,694',
#  '2,370',
#  '8,265',
#  '2,215',
#  '5,826',
#  '2,253',
#  '2,108',
#  '1,820',
#  '952',
#  '757',
#  '7,061',
#  '1,299',
#  '1,051',
#  '4,165',
#  '7,108',
#  '897',
#  '1,020',
#  '1,029',
#  '1,298',
#  '2,249',
#  '1,880',
#  '1,132',
#  '1,422',
#  '1,959',
#  '3,211',
#  '2,641',
#  '2,240',
#  '3,091',
#  '754',
#  '2,054',
#  '1,856',
#  '1,512',
#  '1,139',
#  '1,348',
#  '1,916',
#  '2,632',
#  '1,552',
#  '2,601',
#  '2,235',
#  '2,151',
#  '1,793',
#  '2,694',
#  '2,370',
#  '8,265',
#  '2,215',
#  '5,826',
#  '2,253',
#  '2,108',
#  '1,820',
#  '952',
#  '757',
#  '7,061',
#  '1,299',
#  '1,051',
#  '4,165',
#  '7,108',
#  '897',
#  '1,020',
#  '1,029',
#  '1,298',
#  '2,249',
#  '1,880',
#  '1,132',
#  '1,422',
#  '1,959',
#  '3,211',
#  '2,641',
#  '2,240',
#  '3,091',
#  '754',
#  '2,054',
#  '1,856',
#  '1,512',
#  '1,139',
# ...

# %%
len(sqft_name14)
# Out:
# 123

# %%
ppsqft_name14=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag14 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag14:
        ppsqft_name14.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name14
# Out:
# ['$264',
#  '$246',
#  '$271',
#  '$1,174',
#  '$408',
#  '$244',
#  '$365',
#  '$268',
#  '$227',
#  '$362',
#  '$199',
#  '$190',
#  '$362',
#  '$370',
#  '$644',
#  '$178',
#  '$835',
#  '$222',
#  '$520',
#  '$527',
#  '$481',
#  '$327',
#  '$280',
#  '$576',
#  '$605',
#  '$612',
#  '$460',
#  '$569',
#  '$297',
#  '$186',
#  '$213',
#  '$362',
#  '$380',
#  '$562',
#  '$273',
#  '$405',
#  '$196',
#  '$218',
#  '$265',
#  '$341',
#  '$302',
#  '$264',
#  '$246',
#  '$271',
#  '$1,174',
#  '$408',
#  '$244',
#  '$365',
#  '$268',
#  '$227',
#  '$362',
#  '$199',
#  '$190',
#  '$362',
#  '$370',
#  '$644',
#  '$178',
#  '$835',
#  '$222',
#  '$520',
#  '$527',
#  '$481',
#  '$327',
#  '$280',
#  '$576',
#  '$605',
#  '$612',
#  '$460',
#  '$569',
#  '$297',
#  '$186',
#  '$213',
#  '$362',
#  '$380',
#  '$562',
#  '$273',
#  '$405',
#  '$196',
#  '$218',
#  '$265',
#  '$341',
#  '$302',
#  '$264',
#  '$246',
#  '$271',
#  '$1,174',
#  '$408',
#  '$244',
#  '$365',
#  '$268',
# ...

# %%
len(ppsqft_name14)
# Out:
# 123

# %%
print(len(address_name14),len(price_name14),len(beds_name14),len(baths_name14),len(sqft_name14),len(ppsqft_name14))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name14[120:123]

# %%
import pandas as pd
df14=pd.DataFrame({'Address':address_name14,'Price':price_name14,'Beds':beds_name14,'Baths':baths_name14,'Total sqft':sqft_name14,'Price per sqft':ppsqft_name14})
df14
# Out:
#                                            Address       Price    Beds  \
# 0
# 1    7277 Charlotte Pike #208, Nashville, TN 37209    $398,500  3 beds
# 2            903 Churchill Xing, Madison, TN 37115    $280,000  2 beds
# 3       119 Highland Villa Dr, Nashville, TN 37211    $365,000  2 beds
# 4         1212 Laurel St #701, Nashville, TN 37203  $2,250,000  2 beds
# ..                                             ...         ...     ...
# 115          416 Normandy Cir, Nashville, TN 37209    $540,000  2 beds
# 116          5853 Mount View Rd, Antioch, TN 37013  $1,100,000  3 beds
# 117        5721 Templegate Dr, Nashville, TN 37221    $875,000  4 beds
# 118           612 Davidson Rd, Nashville, TN 37205  $1,070,000  3 beds
# 119           4212 Sandstone Dr, Antioch, TN 37013    $439,900  4 beds
#
#          Baths Total sqft Price per sqft
# 0                   1,512           $264
# 1    2.5 baths      1,139           $246
# 2      2 baths      1,348           $271
# ...

# %%
df14.to_csv('file14.csv')

# %%
----------Miami----------

# %%
address_name15=[]
price_name15=[]
beds_name15=[]
baths_name15=[]
sqft_name15=[]
ppsqft_name15=[]

# %%
address_name15=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag15 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag15:
        address_name15.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name15
# Out:
# ['',
#  '1613 Sienna Ct, Orlando, FL 32825',
#  '1133 Pando Loop, Orlando, FL 32824',
#  '3616 Bellington Dr, Orlando, FL 32835',
#  'Undisclosed address, Orlando, FL 32808',
#  '15079 Willow Arbor Cir, Orlando, FL 32824',
#  '14533 Broadhaven Blvd, Orlando, FL 32828',
#  '8101 Resort Village Dr, Orlando, FL 32821',
#  '62 W Muriel St, Orlando, FL 32806',
#  '9443 Merrifield St, Orlando, FL 32827',
#  '3345 Knightsbridge Rd, Orlando, FL 32818',
#  '2614 Lyndscape St, Orlando, FL 32833',
#  '10305 Rocking A Run, Orlando, FL 32825',
#  '8125 Resort Village Dr #5705, Orlando, FL 32821',
#  '802 Rugby St Unit 802C, Orlando, FL 32804',
#  '8801 Villa View Cir #107, Orlando, FL 32821',
#  '6912 Salinas Dr, Orlando, FL 32822',
#  '2759 L B Mcleod Rd, Orlando, FL 32805',
#  '4213 Boca Woods Dr, Orlando, FL 32826',
#  '2217 Woodwind Dr, Orlando, FL 32808',
#  '3002 Bargate St, Orlando, FL 32824',
#  '300 E South St #4001, Orlando, FL 32801',
#  '860 N Orange Ave #310, Orlando, FL 32801',
# ...

# %%
len(address_name15)
# Out:
# 123

# %%
price_name15=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag15 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag15:
        price_name15.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name15
# Out:
# ['',
#  '$435,000',
#  '$550,000',
#  '$925,000',
#  '$300,000',
#  '$460,000',
#  '$725,000',
#  '$205,000',
#  '$425,000',
#  '$749,000',
#  '$369,000',
#  '$411,000',
#  '$375,000',
#  '$199,950',
#  '$210,000',
#  '$319,990',
#  '$70,000',
#  '$81,000',
#  '$379,900',
#  '$369,900',
#  '$375,000',
#  '$255,000',
#  '$325,000',
#  '$399,900',
#  '$147,000',
#  '$499,750',
#  '$475,000',
#  '$446,500',
#  '$699,000',
#  '$110,000',
#  '$420,000',
#  '$687,990',
#  '$475,000',
#  '$242,000',
#  '$585,900',
#  '$385,000',
#  '$450,000',
#  '$170,000',
#  '$221,900',
#  '$549,000',
#  '$279,900',
#  '',
#  '$435,000',
#  '$550,000',
#  '$925,000',
#  '$300,000',
#  '$460,000',
#  '$725,000',
#  '$205,000',
#  '$425,000',
#  '$749,000',
#  '$369,000',
#  '$411,000',
#  '$375,000',
#  '$199,950',
#  '$210,000',
#  '$319,990',
#  '$70,000',
#  '$81,000',
#  '$379,900',
#  '$369,900',
#  '$375,000',
#  '$255,000',
#  '$325,000',
#  '$399,900',
#  '$147,000',
#  '$499,750',
#  '$475,000',
# ...

# %%
len(price_name15)
# Out:
# 123

# %%
beds_name15=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag15 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag15:
        beds_name15.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name15
# Out:
# ['',
#  '3 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '0 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '5 beds',
#  '4 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '',
#  '3 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '2 beds',
#  '2 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '0 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '2 beds',
#  '5 beds',
#  '4 beds',
#  '4 beds',
# ...

# %%
len(beds_name15)
# Out:
# 123

# %%
baths_name15=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag15 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag15:
        baths_name15.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 baths_name15
# Out:
# ['',
#  '2.5 baths',
#  '3.5 baths',
#  '4.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '3 baths',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '— baths',
#  '2.5 baths',
#  '1 bath',
#  '2.5 baths',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '',
#  '2.5 baths',
#  '3.5 baths',
#  '4.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '3 baths',
#  '2 baths',
#  '1 bath',
#  '3.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '— baths',
# ...

# %%
len( baths_name15)
# Out:
# 123

# %%
sqft_name15=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag15 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag15:
        sqft_name15.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
sqft_name15
# Out:
# ['1,403',
#  '2,117',
#  '3,361',
#  '1,108',
#  '2,094',
#  '2,668',
#  '1,060',
#  '1,052',
#  '2,367',
#  '1,721',
#  '2,309',
#  '1,311',
#  '1,060',
#  '779',
#  '1,378',
#  '929',
#  '780',
#  '1,719',
#  '1,554',
#  '1,717',
#  '1,115',
#  '1,004',
#  '1,708',
#  '825',
#  '1,177',
#  '1,655',
#  '1,707',
#  '2,191',
#  '642',
#  '1,555',
#  '2,365',
#  '2,052',
#  '1,388',
#  '2,532',
#  '1,686',
#  '2,270',
#  '830',
#  '1,107',
#  '1,589',
#  '720',
#  '1,670',
#  '1,403',
#  '2,117',
#  '3,361',
#  '1,108',
#  '2,094',
#  '2,668',
#  '1,060',
#  '1,052',
#  '2,367',
#  '1,721',
#  '2,309',
#  '1,311',
#  '1,060',
#  '779',
#  '1,378',
#  '929',
#  '780',
#  '1,719',
#  '1,554',
#  '1,717',
#  '1,115',
#  '1,004',
#  '1,708',
#  '825',
#  '1,177',
#  '1,655',
#  '1,707',
#  '2,191',
#  '642',
#  '1,555',
#  '2,365',
#  '2,052',
#  '1,388',
#  '2,532',
#  '1,686',
#  '2,270',
#  '830',
#  '1,107',
#  '1,589',
#  '720',
#  '1,670',
#  '1,403',
#  '2,117',
#  '3,361',
# ...

# %%
len(sqft_name15)
# Out:
# 123

# %%
ppsqft_name15=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag15 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag15:
        ppsqft_name15.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name15
# Out:
# ['$310',
#  '$260',
#  '$275',
#  '$271',
#  '$220',
#  '$272',
#  '$193',
#  '$404',
#  '$316',
#  '$214',
#  '$178',
#  '$286',
#  '$189',
#  '$270',
#  '$232',
#  '$75',
#  '$104',
#  '$221',
#  '$238',
#  '$218',
#  '$229',
#  '$324',
#  '$234',
#  '$178',
#  '$425',
#  '$287',
#  '$262',
#  '$319',
#  '$171',
#  '$270',
#  '$291',
#  '$231',
#  '$174',
#  '$231',
#  '$228',
#  '$198',
#  '$205',
#  '$200',
#  '$346',
#  '$389',
#  '$263',
#  '$310',
#  '$260',
#  '$275',
#  '$271',
#  '$220',
#  '$272',
#  '$193',
#  '$404',
#  '$316',
#  '$214',
#  '$178',
#  '$286',
#  '$189',
#  '$270',
#  '$232',
#  '$75',
#  '$104',
#  '$221',
#  '$238',
#  '$218',
#  '$229',
#  '$324',
#  '$234',
#  '$178',
#  '$425',
#  '$287',
#  '$262',
#  '$319',
#  '$171',
#  '$270',
#  '$291',
#  '$231',
#  '$174',
#  '$231',
#  '$228',
#  '$198',
#  '$205',
#  '$200',
#  '$346',
#  '$389',
#  '$263',
#  '$310',
#  '$260',
#  '$275',
#  '$271',
#  '$220',
#  '$272',
#  '$193',
#  '$404',
#  '$316',
# ...

# %%
len(ppsqft_name15)
# Out:
# 123

# %%
print(len(address_name15),len(price_name15),len(beds_name15),len(baths_name15),len(sqft_name15),len(ppsqft_name15))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df15=pd.DataFrame({'Address':address_name15,'Price':price_name15,'Beds':beds_name15,'Baths':baths_name15,'Total sqft':sqft_name15,'Price per sqft':ppsqft_name15})
df15
# Out:
#                                                Address     Price    Beds  \
# 0
# 1                    1613 Sienna Ct, Orlando, FL 32825  $435,000  3 beds
# 2                   1133 Pando Loop, Orlando, FL 32824  $550,000  4 beds
# 3                3616 Bellington Dr, Orlando, FL 32835  $925,000  5 beds
# 4               Undisclosed address, Orlando, FL 32808  $300,000  3 beds
# ..                                                 ...       ...     ...
# 118                  719 Dawson Ave, Orlando, FL 32825  $450,000  4 beds
# 119  2047 Dixie Belle Dr Unit 2047K, Orlando, FL 32812  $170,000  2 beds
# 120               3280 Soho St #202, Orlando, FL 32835  $221,900  2 beds
# 121                  6907 Higgs Aly, Orlando, FL 32827  $549,000  3 beds
# 122                 11610 Baltic St, Orlando, FL 32817  $279,900  2 beds
#
#          Baths Total sqft Price per sqft
# 0                   1,403           $310
# 1    2.5 baths      2,117           $260
# ...

# %%
df15.to_csv('file15.csv')

# %%
address_name16=[]
price_name16=[]
beds_name16=[]
baths_name16=[]
sqft_name16=[]
ppsqft_name16=[]

# %%
address_name16=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag16 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag16:
        address_name16.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name16
# Out:
# ['',
#  '12432 Caracara Ct, Charlotte, NC 28278',
#  '8509 Aspen Ct, Charlotte, NC 28227',
#  '1109 Pamlico St, Charlotte, NC 28205',
#  '7923 Oratorio Pl, Charlotte, NC 28270',
#  '1220 Berry Ridge Rd, Charlotte, NC 28270',
#  '803 Herrin Ave, Charlotte, NC 28205',
#  '1321 Ferncliff Rd, Charlotte, NC 28211',
#  '2515 Dalston Ln, Charlotte, NC 28210',
#  '12427 Elkhorn Dr, Charlotte, NC 28278',
#  '3620 Speer Blvd, Charlotte, NC 28217',
#  '4735 Hedgemore Dr, Charlotte, NC 28209',
#  '331 Austin Dr, Charlotte, NC 28213',
#  '16418 Bunch Walnuts Rd, Charlotte, NC 28278',
#  '8113 Strawberry Point Dr, Charlotte, NC 28215',
#  '709 Aberdeen Glen Pl, Charlotte, NC 28214',
#  '5730 Closeburn Rd Unit G, Charlotte, NC 28210',
#  '6131 Trotters Ridge Rd, Charlotte, NC 28227',
#  '12018 Portobello Way, Charlotte, NC 28273',
#  '431 Nottingham Dr, Charlotte, NC 28211',
#  '1320 Fillmore Ave #102, Charlotte, NC 28203',
#  '248 Kingston Ave, Charlotte, NC 28203',
# ...

# %%
len(address_name16)
# Out:
# 123

# %%
price_name16=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag16 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag16:
        price_name16.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name16
# Out:
# ['',
#  '$385,000',
#  '$724,500',
#  '$1,450,000',
#  '$635,000',
#  '$500,000',
#  '$824,900',
#  '$1,250,000',
#  '$439,500',
#  '$798,000',
#  '$410,000',
#  '$279,000',
#  '$340,900',
#  '$1,499,999',
#  '$280,000',
#  '$335,000',
#  '$389,999',
#  '$341,000',
#  '$345,000',
#  '$844,000',
#  '$424,900',
#  '$1,295,000',
#  '$1,450,000',
#  '$399,000',
#  '$425,000',
#  '$485,000',
#  '$799,500',
#  '$549,900',
#  '$283,000',
#  '$185,000',
#  '$799,000',
#  '$419,555',
#  '$404,894',
#  '$419,000',
#  '$397,225',
#  '$397,737',
#  '$450,000',
#  '$825,000',
#  '$575,000',
#  '$399,781',
#  '$1,595,000',
#  '',
#  '$385,000',
#  '$724,500',
#  '$1,450,000',
#  '$635,000',
#  '$500,000',
#  '$824,900',
#  '$1,250,000',
#  '$439,500',
#  '$798,000',
#  '$410,000',
#  '$279,000',
#  '$340,900',
#  '$1,499,999',
#  '$280,000',
#  '$335,000',
#  '$389,999',
#  '$341,000',
#  '$345,000',
#  '$844,000',
#  '$424,900',
#  '$1,295,000',
#  '$1,450,000',
#  '$399,000',
#  '$425,000',
# ...

# %%
len(price_name16)
# Out:
# 123

# %%
beds_name16=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag16 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag16:
        beds_name16.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name16=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag16 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag16:
        baths_name16.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 baths_name16
# Out:
# ['',
#  '2.5 baths',
#  '3.5 baths',
#  '4 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '0.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '4 baths',
#  '4 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '4 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '4 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '3.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '3.5 baths',
#  '',
#  '2.5 baths',
#  '3.5 baths',
#  '4 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '3.5 baths',
#  '3.5 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '0.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '4 baths',
#  '4 baths',
#  '2 baths',
#  '2.5 baths',
#  '2.5 baths',
# ...

# %%
len( baths_name16)
# Out:
# 123

# %%
sqft_name16=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag16 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag16:
        sqft_name16.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
sqft_name16
# Out:
# ['1,854',
#  '3,414',
#  '3,378',
#  '2,690',
#  '1,543',
#  '2,358',
#  '2,154',
#  '1,298',
#  '3,695',
#  '1,994',
#  '1,076',
#  '1,200',
#  '2,238',
#  '1,175',
#  '1,673',
#  '1,075',
#  '1,548',
#  '1,214',
#  '2,250',
#  '1,154',
#  '2,753',
#  '3,034',
#  '1,113',
#  '2,140',
#  '2,585',
#  '2,908',
#  '1,404',
#  '1,615',
#  '1,176',
#  '2,819',
#  '1,895',
#  '1,849',
#  '1,850',
#  '1,895',
#  '1,895',
#  '1,490',
#  '2,320',
#  '1,310',
#  '1,849',
#  '3,517',
#  '1,886',
#  '1,854',
#  '3,414',
#  '3,378',
#  '2,690',
#  '1,543',
#  '2,358',
#  '2,154',
#  '1,298',
#  '3,695',
#  '1,994',
#  '1,076',
#  '1,200',
#  '2,238',
#  '1,175',
#  '1,673',
#  '1,075',
#  '1,548',
#  '1,214',
#  '2,250',
#  '1,154',
#  '2,753',
#  '3,034',
#  '1,113',
#  '2,140',
#  '2,585',
#  '2,908',
#  '1,404',
#  '1,615',
#  '1,176',
#  '2,819',
#  '1,895',
#  '1,849',
#  '1,850',
#  '1,895',
#  '1,895',
#  '1,490',
#  '2,320',
#  '1,310',
#  '1,849',
#  '3,517',
#  '1,886',
#  '1,854',
# ...

# %%
len(sqft_name16)
# Out:
# 123

# %%
ppsqft_name16=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag16 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag16:
        ppsqft_name16.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name16
# Out:
# ['$208',
#  '$212',
#  '$429',
#  '$236',
#  '$324',
#  '$350',
#  '$580',
#  '$339',
#  '$216',
#  '$206',
#  '$259',
#  '$284',
#  '$670',
#  '$238',
#  '$200',
#  '$363',
#  '$220',
#  '$284',
#  '$375',
#  '$368',
#  '$470',
#  '$478',
#  '$358',
#  '$199',
#  '$188',
#  '$275',
#  '$392',
#  '$175',
#  '$157',
#  '$283',
#  '$221',
#  '$219',
#  '$226',
#  '$210',
#  '$210',
#  '$302',
#  '$356',
#  '$439',
#  '$216',
#  '$454',
#  '$258',
#  '$208',
#  '$212',
#  '$429',
#  '$236',
#  '$324',
#  '$350',
#  '$580',
#  '$339',
#  '$216',
#  '$206',
#  '$259',
#  '$284',
#  '$670',
#  '$238',
#  '$200',
#  '$363',
#  '$220',
#  '$284',
#  '$375',
#  '$368',
#  '$470',
#  '$478',
#  '$358',
#  '$199',
#  '$188',
#  '$275',
#  '$392',
#  '$175',
#  '$157',
#  '$283',
#  '$221',
#  '$219',
#  '$226',
#  '$210',
#  '$210',
#  '$302',
#  '$356',
#  '$439',
#  '$216',
#  '$454',
#  '$258',
#  '$208',
#  '$212',
#  '$429',
#  '$236',
#  '$324',
#  '$350',
#  '$580',
#  '$339',
# ...

# %%
len(ppsqft_name16)
# Out:
# 123

# %%
print(len(address_name16),len(price_name16),len(beds_name16),len(baths_name16),len(sqft_name16),len(ppsqft_name16))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df16=pd.DataFrame({'Address':address_name16,'Price':price_name16,'Beds':beds_name16,'Baths':baths_name16,'Total sqft':sqft_name16,'Price per sqft':ppsqft_name16})
df16
# Out:
#                                     Address       Price    Beds      Baths  \
# 0
# 1    12432 Caracara Ct, Charlotte, NC 28278    $385,000  3 beds  2.5 baths
# 2        8509 Aspen Ct, Charlotte, NC 28227    $724,500  4 beds  3.5 baths
# 3      1109 Pamlico St, Charlotte, NC 28205  $1,450,000  5 beds    4 baths
# 4     7923 Oratorio Pl, Charlotte, NC 28270    $635,000  3 beds  2.5 baths
# ..                                      ...         ...     ...        ...
# 118  6719 Woodshed Cir, Charlotte, NC 28270    $450,000  3 beds    2 baths
# 119     3244 Harrow Pl, Charlotte, NC 28205    $825,000  4 beds  3.5 baths
# 120   3663 Vallette Ct, Charlotte, NC 28203    $575,000  2 beds  2.5 baths
# 121    1808 Blanche St, Charlotte, NC 28262    $399,781  3 beds  2.5 baths
# 122  705 Templeton Ave, Charlotte, NC 28203  $1,595,000  4 beds  3.5 baths
#
#     Total sqft Price per sqft
# 0        1,854           $208
# 1        3,414           $212
# 2        3,378           $429
# ...

# %%
df16.to_csv('file16.csv')

# %%
------------Pittsburgh condos------------

# %%
address_name17=[]
price_name17=[]
beds_name17=[]
baths_name17=[]
sqft_name17=[]
ppsqft_name17=[]

# %%
address_name17=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag17 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag17:
        address_name17.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name17
# Out:
# ['',
#  '5100 Fifth Ave #514, Shadyside, PA 15232',
#  '3725 Butler St #206, Lawrenceville, PA 15201',
#  '306 4th Ave #902, Downtown Pgh, PA 15222',
#  '5 Bayard Rd #500, Shadyside, PA 15213',
#  '424 S Winebiddle St, Bloomfield, PA 15224',
#  '196 36th St Unit 3F, Lawrenceville, PA 15201',
#  '3809 Liberty Ave #404, Lawrenceville, PA 15201',
#  '4601 Fifth Avene #323, Oakland, PA 15213',
#  '320 Fort Duquesne Blvd Unit 23E, Downtown Pgh, PA 15222',
#  '5425 5th Ave #102, Shadyside, PA 15232',
#  '5523 Ellsworth Ave Unit 7B, Shadyside, PA 15232',
#  '5900 Babcock Blvd #31, Ross Twp, PA 15237',
#  '5825 5th Ave Unit 207A, Shadyside, PA 15232',
#  '372 S Highland Ave #202, Shadyside, PA 15206',
#  '471 Cherry Ct, Ross Twp, PA 15237',
#  '350 Oliver Ave #908, Downtown Pgh, PA 15222',
#  '350 Oliver Ave #1205, Downtown Pgh, PA 15222',
#  '4002 Lenox Oval, Ross Twp, PA 15237',
#  '300 Gilkeson Rd Unit 10A, Mt. Lebanon, PA 15228',
#  '3809 Liberty #207, Lawrenceville, PA 15201',
# ...

# %%
len(address_name17)
# Out:
# 123

# %%
price_name17=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag17 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag17:
        price_name17.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name17
# Out:
# ['',
#  '$239,000',
#  '$450,000',
#  '$369,900',
#  '$279,900',
#  '$179,900',
#  '$300,000',
#  '$565,000',
#  '$225,000',
#  '$249,000',
#  '$250,000',
#  '$160,000',
#  '$125,000',
#  '$225,000',
#  '$289,000',
#  '$259,900',
#  '$349,900',
#  '$574,000',
#  '$242,900',
#  '$190,000',
#  '$299,000',
#  '$129,900',
#  '$452,500',
#  '$350,000',
#  '$269,900',
#  '$399,000',
#  '$415,000',
#  '$300,000',
#  '$169,900',
#  '$99,000',
#  '$320,000',
#  '$160,000',
#  '$595,000',
#  '$195,000',
#  '$329,500',
#  '$350,000',
#  '$725,000',
#  '$293,607',
#  '$339,000',
#  '$699,000',
#  '$103,900',
#  '',
#  '$239,000',
#  '$450,000',
#  '$369,900',
#  '$279,900',
#  '$179,900',
#  '$300,000',
#  '$565,000',
#  '$225,000',
#  '$249,000',
#  '$250,000',
#  '$160,000',
#  '$125,000',
#  '$225,000',
#  '$289,000',
#  '$259,900',
#  '$349,900',
#  '$574,000',
#  '$242,900',
#  '$190,000',
#  '$299,000',
#  '$129,900',
#  '$452,500',
#  '$350,000',
#  '$269,900',
#  '$399,000',
# ...

# %%
len(price_name17)
# Out:
# 123

# %%
beds_name17=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag17 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag17:
        beds_name17.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name17
# Out:
# ['',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '0 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '0 beds',
#  '3 beds',
#  '1 bed',
#  '2 beds',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
# ...

# %%
len(beds_name17)
# Out:
# 123

# %%
baths_name17=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag17 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag17:
        baths_name17.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name17
# Out:
# ['',
#  '1.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1.5 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '',
#  '1.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1.5 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '2.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '1.5 baths',
#  '1.5 baths',
#  '1 bath',
# ...

# %%
len(baths_name17)
# Out:
# 123

# %%
sqft_name17=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag17 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag17:
        sqft_name17.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 sqft_name17
# Out:
# ['—',
#  '1,094',
#  '1,485',
#  '1,270',
#  '936',
#  '1,167',
#  '1,442',
#  '1,023',
#  '1,140',
#  '828',
#  '640',
#  '1,000',
#  '1,210',
#  '1,106',
#  '1,534',
#  '641',
#  '1,050',
#  '1,474',
#  '979',
#  '745',
#  '1,367',
#  '1,602',
#  '2,060',
#  '1,162',
#  '1,609',
#  '1,546',
#  '1,500',
#  '1,200',
#  '—',
#  '1,680',
#  '763',
#  '1,800',
#  '—',
#  '1,082',
#  '—',
#  '1,837',
#  '590',
#  '848',
#  '1,773',
#  '500',
#  '1,298',
#  '—',
#  '1,094',
#  '1,485',
#  '1,270',
#  '936',
#  '1,167',
#  '1,442',
#  '1,023',
#  '1,140',
#  '828',
#  '640',
#  '1,000',
#  '1,210',
#  '1,106',
#  '1,534',
#  '641',
#  '1,050',
#  '1,474',
#  '979',
#  '745',
#  '1,367',
#  '1,602',
#  '2,060',
#  '1,162',
#  '1,609',
#  '1,546',
#  '1,500',
#  '1,200',
#  '—',
#  '1,680',
#  '763',
#  '1,800',
#  '—',
#  '1,082',
#  '—',
#  '1,837',
#  '590',
#  '848',
#  '1,773',
#  '500',
#  '1,298',
#  '—',
#  '1,094',
#  '1,485',
#  '1,270',
#  '936',
#  '1,167',
#  '1,442',
# ...

# %%
len( sqft_name17)
# Out:
# 123

# %%
ppsqft_name17=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag17 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag17:
        ppsqft_name17.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name17
# Out:
# ['—',
#  '$411',
#  '$249',
#  '$220',
#  '$192',
#  '$257',
#  '$392',
#  '$220',
#  '$218',
#  '$302',
#  '$250',
#  '$125',
#  '$186',
#  '$261',
#  '$169',
#  '$546',
#  '$547',
#  '$165',
#  '$194',
#  '$401',
#  '$95',
#  '$282',
#  '$170',
#  '$232',
#  '$248',
#  '$268',
#  '$200',
#  '$142',
#  '—',
#  '$190',
#  '$210',
#  '$331',
#  '—',
#  '$305',
#  '—',
#  '$395',
#  '$498',
#  '$400',
#  '$394',
#  '$208',
#  '$293',
#  '—',
#  '$411',
#  '$249',
#  '$220',
#  '$192',
#  '$257',
#  '$392',
#  '$220',
#  '$218',
#  '$302',
#  '$250',
#  '$125',
#  '$186',
#  '$261',
#  '$169',
#  '$546',
#  '$547',
#  '$165',
#  '$194',
#  '$401',
#  '$95',
#  '$282',
#  '$170',
#  '$232',
#  '$248',
#  '$268',
#  '$200',
#  '$142',
#  '—',
#  '$190',
#  '$210',
#  '$331',
#  '—',
#  '$305',
#  '—',
#  '$395',
#  '$498',
#  '$400',
#  '$394',
#  '$208',
#  '$293',
#  '—',
#  '$411',
#  '$249',
#  '$220',
#  '$192',
#  '$257',
#  '$392',
#  '$220',
#  '$218',
#  '$302',
#  '$250',
# ...

# %%
len(ppsqft_name17)
# Out:
# 123

# %%
print(len(address_name17),len(price_name17),len(beds_name17),len(baths_name17),len(sqft_name17),len(ppsqft_name17))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df17=pd.DataFrame({'Address':address_name17,'Price':price_name17,'Beds':beds_name17,'Baths':baths_name17,'Total sqft':sqft_name17,'Price per sqft':ppsqft_name17})
df17
# Out:
#                                                Address     Price    Beds  \
# 0
# 1             5100 Fifth Ave #514, Shadyside, PA 15232  $239,000   1 bed
# 2         3725 Butler St #206, Lawrenceville, PA 15201  $450,000   1 bed
# 3             306 4th Ave #902, Downtown Pgh, PA 15222  $369,900  2 beds
# 4                5 Bayard Rd #500, Shadyside, PA 15213  $279,900  2 beds
# ..                                                 ...       ...     ...
# 118   501 Grandview Ave #1001, Mt Washington, PA 15211  $725,000  2 beds
# 119     3809 Liberty Ave #208, Lawrenceville, PA 15201  $293,607   1 bed
# 120     3809 Liberty Ave #304, Lawrenceville, PA 15201  $339,000   1 bed
# 121     3809 Liberty Ave #402, Lawrenceville, PA 15201  $699,000  2 beds
# 122  1987 Centurion Dr #611, Forest Hills Boro, PA ...  $103,900   1 bed
#
#          Baths Total sqft Price per sqft
# 0                       —              —
# 1    1.5 baths      1,094           $411
# ...

# %%
df17.to_csv('file17.csv')

# %%
-------------Jacksonville, FL, USA homes-----------

# %%
address_name18=[]
price_name18=[]
beds_name18=[]
baths_name18=[]
sqft_name18=[]
ppsqft_name18=[]

# %%
address_name18=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag18 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag18:
        address_name18.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name18
# Out:
# ['',
#  '311 W Ashley St #503, Jacksonville, FL 32202',
#  '311 W Ashley St #602, Jacksonville, FL 32202',
#  '311 W Ashley St #311, Jacksonville, FL 32202',
#  '311 W Ashley St #1206, Jacksonville, FL 32202',
#  '311 W Ashley St #710, Jacksonville, FL 32202',
#  '311 Ashley St W #509, Jacksonville, FL 32202',
#  '311 W Ashley St #302, Jacksonville, FL 32202',
#  '311 W Ashley St #507, Jacksonville, FL 32202',
#  '0 W 2nd St, Jacksonville, FL 32206',
#  '111 E 1st St #35, Jacksonville, FL 32206',
#  '217 E 1st St, Jacksonville, FL 32206',
#  '1125 N Market St, Jacksonville, FL 32206',
#  '1315 N Laura St, Jacksonville, FL 32206',
#  '0 4th St, Jacksonville, FL 32206',
#  '400 E Bay St #1610-1611, Jacksonville, FL 32202',
#  '400 E Bay St #6, Jacksonville, FL 32202',
#  '400 E Bay St #1007, Jacksonville, FL 32202',
#  '400 E Bay St #311, Jacksonville, FL 32202',
#  '400 E Bay St #411, Jacksonville, FL 32202',
#  '400 E Bay St #1902, Jacksonville, FL 32202',
# ...

# %%
len(address_name18)
# Out:
# 123

# %%
price_name18=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag18 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag18:
        price_name18.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
price_name18
# Out:
# ['',
#  '$98,000',
#  '$115,000',
#  '$95,000',
#  '$120,000',
#  '$94,900',
#  '$94,500',
#  '$104,900',
#  '$114,900',
#  '$15,000',
#  '$157,000',
#  '$219,000',
#  '$779,000',
#  '$419,900',
#  '$12,000',
#  '$659,900',
#  '$1,299,900',
#  '$469,000',
#  '$329,900',
#  '$319,900',
#  '$329,000',
#  '$399,999',
#  '$469,900',
#  '$379,900',
#  '$335,000',
#  '$399,000',
#  '$425,000',
#  '$685,000',
#  '$250,000',
#  '$99,000',
#  '$85,000',
#  '$600,000',
#  '$418,000',
#  '$724,900',
#  '$479,000',
#  '$439,900',
#  '$65,000',
#  '$399,000',
#  '$264,500',
#  '$529,770',
#  '$475,000',
#  '',
#  '$98,000',
#  '$115,000',
#  '$95,000',
#  '$120,000',
#  '$94,900',
#  '$94,500',
#  '$104,900',
#  '$114,900',
#  '$15,000',
#  '$157,000',
#  '$219,000',
#  '$779,000',
#  '$419,900',
#  '$12,000',
#  '$659,900',
#  '$1,299,900',
#  '$469,000',
#  '$329,900',
#  '$319,900',
#  '$329,000',
#  '$399,999',
#  '$469,900',
#  '$379,900',
#  '$335,000',
#  '$399,000',
#  '$425,000',
# ...

# %%
len(price_name18)
# Out:
# 123

# %%
beds_name18=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag18 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag18:
        beds_name18.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name18
# Out:
# ['',
#  '1 bed',
#  '1 bed',
#  '0 beds',
#  '1 bed',
#  '0 beds',
#  '0 beds',
#  '1 bed',
#  '1 bed',
#  '— beds',
#  '2 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '— beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '6 beds',
#  '— beds',
#  '— beds',
#  '— beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '— beds',
#  '3 beds',
#  '5 beds',
#  '4 beds',
#  '4 beds',
#  '',
#  '1 bed',
#  '1 bed',
#  '0 beds',
#  '1 bed',
#  '0 beds',
#  '0 beds',
#  '1 bed',
#  '1 bed',
#  '— beds',
#  '2 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '— beds',
#  '3 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '1 bed',
#  '1 bed',
#  '2 beds',
#  '2 beds',
#  '2 beds',
#  '1 bed',
#  '3 beds',
#  '3 beds',
#  '6 beds',
#  '— beds',
#  '— beds',
#  '— beds',
#  '3 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '4 beds',
#  '— beds',
#  '3 beds',
# ...

# %%
len(beds_name18)
# Out:
# 123

# %%
baths_name18=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag18 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag18:
        baths_name18.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 baths_name18
# Out:
# ['',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '— baths',
#  '1.5 baths',
#  '3 baths',
#  '5 baths',
#  '2.5 baths',
#  '— baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '1.5 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '3 baths',
#  '— baths',
#  '— baths',
#  '— baths',
#  '2.5 baths',
#  '3 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2.5 baths',
#  '— baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '1 bath',
#  '— baths',
#  '1.5 baths',
#  '3 baths',
#  '5 baths',
#  '2.5 baths',
#  '— baths',
#  '2.5 baths',
#  '2.5 baths',
#  '2 baths',
#  '1 bath',
#  '1.5 baths',
#  '1 bath',
#  '1 bath',
#  '2 baths',
#  '1 bath',
#  '1 bath',
#  '2.5 baths',
#  '2.5 baths',
#  '3 baths',
#  '— baths',
#  '— baths',
# ...

# %%
len( baths_name18)
# Out:
# 123

# %%
sqft_name18=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag18 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag18:
        sqft_name18.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
sqft_name18
# Out:
# ['456',
#  '573',
#  '425',
#  '456',
#  '425',
#  '401',
#  '573',
#  '573',
#  '—',
#  '953',
#  '3,237',
#  '4,371',
#  '1,638',
#  '—',
#  '2,100',
#  '2,922',
#  '1,338',
#  '920',
#  '920',
#  '1,175',
#  '1,100',
#  '1,578',
#  '1,100',
#  '1,175',
#  '1,872',
#  '1,476',
#  '3,608',
#  '—',
#  '—',
#  '—',
#  '2,084',
#  '2,354',
#  '2,321',
#  '1,820',
#  '1,838',
#  '—',
#  '1,936',
#  '2,024',
#  '1,848',
#  '2,554',
#  '1,356',
#  '456',
#  '573',
#  '425',
#  '456',
#  '425',
#  '401',
#  '573',
#  '573',
#  '—',
#  '953',
#  '3,237',
#  '4,371',
#  '1,638',
#  '—',
#  '2,100',
#  '2,922',
#  '1,338',
#  '920',
#  '920',
#  '1,175',
#  '1,100',
#  '1,578',
#  '1,100',
#  '1,175',
#  '1,872',
#  '1,476',
#  '3,608',
#  '—',
#  '—',
#  '—',
#  '2,084',
#  '2,354',
#  '2,321',
#  '1,820',
#  '1,838',
#  '—',
#  '1,936',
#  '2,024',
#  '1,848',
#  '2,554',
#  '1,356',
#  '456',
#  '573',
#  '425',
#  '456',
#  '425',
#  '401',
#  '573',
#  '573',
#  '—',
#  '953',
# ...

# %%
len(sqft_name18)
# Out:
# 123

# %%
ppsqft_name18=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag18 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag18:
        ppsqft_name18.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
ppsqft_name18
# Out:
# ['$215',
#  '$201',
#  '$224',
#  '$263',
#  '$223',
#  '$236',
#  '$183',
#  '$201',
#  '—',
#  '$165',
#  '$68',
#  '$178',
#  '$256',
#  '—',
#  '$314',
#  '$445',
#  '$351',
#  '$359',
#  '$348',
#  '$280',
#  '$364',
#  '$298',
#  '$345',
#  '$285',
#  '$213',
#  '$288',
#  '$190',
#  '—',
#  '—',
#  '—',
#  '$288',
#  '$178',
#  '$312',
#  '$263',
#  '$239',
#  '—',
#  '$206',
#  '$131',
#  '$287',
#  '$186',
#  '$184',
#  '$215',
#  '$201',
#  '$224',
#  '$263',
#  '$223',
#  '$236',
#  '$183',
#  '$201',
#  '—',
#  '$165',
#  '$68',
#  '$178',
#  '$256',
#  '—',
#  '$314',
#  '$445',
#  '$351',
#  '$359',
#  '$348',
#  '$280',
#  '$364',
#  '$298',
#  '$345',
#  '$285',
#  '$213',
#  '$288',
#  '$190',
#  '—',
#  '—',
#  '—',
#  '$288',
#  '$178',
#  '$312',
#  '$263',
#  '$239',
#  '—',
#  '$206',
#  '$131',
#  '$287',
#  '$186',
#  '$184',
#  '$215',
#  '$201',
#  '$224',
#  '$263',
#  '$223',
#  '$236',
#  '$183',
#  '$201',
#  '—',
#  '$165',
#  '$68',
#  '$178',
# ...

# %%
len(ppsqft_name18)
# Out:
# 123

# %%
print(len(address_name18),len(price_name18),len(beds_name18),len(baths_name18),len(sqft_name18),len(ppsqft_name18))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df18=pd.DataFrame({'Address':address_name18,'Price':price_name18,'Beds':beds_name18,'Baths':baths_name18,'Total sqft':sqft_name18,'Price per sqft':ppsqft_name18})
df18
# Out:
#                                            Address     Price    Beds  \
# 0
# 1     311 W Ashley St #503, Jacksonville, FL 32202   $98,000   1 bed
# 2     311 W Ashley St #602, Jacksonville, FL 32202  $115,000   1 bed
# 3     311 W Ashley St #311, Jacksonville, FL 32202   $95,000  0 beds
# 4    311 W Ashley St #1206, Jacksonville, FL 32202  $120,000   1 bed
# ..                                             ...       ...     ...
# 118            17 W 5th St, Jacksonville, FL 32206   $65,000  — beds
# 119           219 E 5th St, Jacksonville, FL 32206  $399,000  3 beds
# 120          1222 Clark St, Jacksonville, FL 32206  $264,500  5 beds
# 121            36 W 6th St, Jacksonville, FL 32206  $529,770  4 beds
# 122        1532 N Pearl St, Jacksonville, FL 32206  $475,000  4 beds
#
#          Baths Total sqft Price per sqft
# 0                     456           $215
# 1       1 bath        573           $201
# 2       1 bath        425           $224
# ...

# %%
df18.to_csv('file18.csv')

# %%
--------Phoenix homes---------

# %%
address_name19=[]
price_name19=[]
beds_name19=[]
baths_name19=[]
sqft_name19=[]
ppsqft_name19=[]

# %%
address_name19=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag19 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag19:
        address_name19.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 address_name19
# Out:
# ['',
#  '3434 E Baseline Rd #259, Phoenix, AZ 85042',
#  '6900 E Princess Dr #1192, Phoenix, AZ 85054',
#  '2636 E Hidalgo Ave, Phoenix, AZ 85040',
#  '3540 E Wayland Dr, Phoenix, AZ 85040',
#  '4126 E Sunnyside Dr, Phoenix, AZ 85028',
#  '1416 W Clarendon Ave, Phoenix, AZ 85013',
#  '2417 E Yucca St, Phoenix, AZ 85028',
#  '4056 W Charlotte Dr, Glendale, AZ 85310',
#  '4423 W Westcott Dr, Glendale, AZ 85308',
#  '531 E Sack Dr, Phoenix, AZ 85024',
#  '4201 E Darrow St, Phoenix, AZ 85042',
#  '3406 E Libby St, Phoenix, AZ 85032',
#  '5655 E Saint John Rd, Scottsdale, AZ 85254',
#  '520 W Clarendon Ave Unit G2, Phoenix, AZ 85013',
#  '3607 W Alice Ave, Phoenix, AZ 85051',
#  '2531 E Mine Creek Rd, Phoenix, AZ 85024',
#  '2309 W Hadley St, Phoenix, AZ 85009',
#  '7231 W Carter Rd, Laveen, AZ 85339',
#  '6230 N 33rd Ave #135, Phoenix, AZ 85017',
#  '7805 W Warner St, Phoenix, AZ 85043',
#  '2431 E Tracy Ln #2, Phoenix, AZ 85032',
#  '2431 W Dusty Wren Dr, Phoenix, AZ 85085',
# ...

# %%
len( address_name19)
# Out:
# 123

# %%
price_name19=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag19 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag19:
        price_name19.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 price_name19
# Out:
# ['',
#  '$289,950',
#  '$399,000',
#  '$374,000',
#  '$449,000',
#  '$685,000',
#  '$735,000',
#  '$775,000',
#  '$575,000',
#  '$350,000',
#  '$485,000',
#  '$415,000',
#  '$605,000',
#  '$899,000',
#  '$260,000',
#  '$359,000',
#  '$619,900',
#  '$218,900',
#  '$510,000',
#  '$258,000',
#  '$625,000',
#  '$315,000',
#  '$505,000',
#  '$210,000',
#  '$384,999',
#  '$747,990',
#  '$479,990',
#  '$360,000',
#  '$454,990',
#  '$849,000',
#  '$479,990',
#  '$435,000',
#  '$465,000',
#  '$708,000',
#  '$485,000',
#  '$236,000',
#  '$399,000',
#  '$543,000',
#  '$329,900',
#  '$339,000',
#  '$1,399,000',
#  '',
#  '$289,950',
#  '$399,000',
#  '$374,000',
#  '$449,000',
#  '$685,000',
#  '$735,000',
#  '$775,000',
#  '$575,000',
#  '$350,000',
#  '$485,000',
#  '$415,000',
#  '$605,000',
#  '$899,000',
#  '$260,000',
#  '$359,000',
#  '$619,900',
#  '$218,900',
#  '$510,000',
#  '$258,000',
#  '$625,000',
#  '$315,000',
#  '$505,000',
#  '$210,000',
#  '$384,999',
#  '$747,990',
# ...

# %%
len( price_name19)
# Out:
# 123

# %%
beds_name19=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag19 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag19:
        beds_name19.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
beds_name19
# Out:
# ['',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '5 beds',
#  '3 beds',
#  '6 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '',
#  '2 beds',
#  '2 beds',
#  '3 beds',
#  '5 beds',
#  '3 beds',
#  '6 beds',
#  '4 beds',
#  '4 beds',
#  '3 beds',
#  '4 beds',
#  '5 beds',
#  '3 beds',
#  '4 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '5 beds',
#  '2 beds',
#  '3 beds',
#  '2 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '4 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '3 beds',
#  '1 bed',
#  '4 beds',
# ...

# %%
len(beds_name19)
# Out:
# 123

# %%
baths_name19=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag19 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag19:
        baths_name19.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
baths_name19
# Out:
# ['',
#  '2 baths',
#  '1.75 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '3 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '3.5 baths',
#  '1 bath',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '3 baths',
#  '',
#  '2 baths',
#  '1.75 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '3 baths',
#  '2.5 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '2.5 baths',
#  '2 baths',
#  '2.5 baths',
#  '1.5 baths',
#  '2 baths',
#  '3 baths',
#  '2 baths',
#  '2 baths',
#  '2 baths',
# ...

# %%
len(baths_name19)
# Out:
# 123

# %%
sqft_name19=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag19 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag19:
        sqft_name19.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 sqft_name19
# Out:
# ['944',
#  '985',
#  '1,341',
#  '2,252',
#  '1,998',
#  '—',
#  '2,628',
#  '2,723',
#  '1,437',
#  '1,950',
#  '2,095',
#  '1,560',
#  '1,941',
#  '1,320',
#  '1,100',
#  '1,827',
#  '1,384',
#  '2,712',
#  '951',
#  '2,390',
#  '952',
#  '1,882',
#  '1,050',
#  '1,120',
#  '2,649',
#  '1,400',
#  '1,367',
#  '1,232',
#  '2,010',
#  '1,411',
#  '1,172',
#  '2,109',
#  '1,487',
#  '1,734',
#  '849',
#  '1,916',
#  '1,992',
#  '1,460',
#  '1,126',
#  '2,459',
#  '1,701',
#  '944',
#  '985',
#  '1,341',
#  '2,252',
#  '1,998',
#  '—',
#  '2,628',
#  '2,723',
#  '1,437',
#  '1,950',
#  '2,095',
#  '1,560',
#  '1,941',
#  '1,320',
#  '1,100',
#  '1,827',
#  '1,384',
#  '2,712',
#  '951',
#  '2,390',
#  '952',
#  '1,882',
#  '1,050',
#  '1,120',
#  '2,649',
#  '1,400',
#  '1,367',
#  '1,232',
#  '2,010',
#  '1,411',
#  '1,172',
#  '2,109',
#  '1,487',
#  '1,734',
#  '849',
#  '1,916',
#  '1,992',
#  '1,460',
#  '1,126',
#  '2,459',
#  '1,701',
#  '944',
#  '985',
#  '1,341',
#  '2,252',
# ...

# %%
 len(sqft_name19)
# Out:
# 123

# %%
ppsqft_name19=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag19 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag19:
        ppsqft_name19.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
 ppsqft_name19
# Out:
# ['$307',
#  '$405',
#  '$279',
#  '$199',
#  '$343',
#  '—',
#  '$295',
#  '$211',
#  '$244',
#  '$249',
#  '$198',
#  '$388',
#  '$463',
#  '$197',
#  '$326',
#  '$339',
#  '$158',
#  '$188',
#  '$271',
#  '$262',
#  '$331',
#  '$268',
#  '$200',
#  '$344',
#  '$282',
#  '$343',
#  '$263',
#  '$369',
#  '$422',
#  '$340',
#  '$371',
#  '$220',
#  '$476',
#  '$280',
#  '$278',
#  '$208',
#  '$273',
#  '$226',
#  '$301',
#  '$569',
#  '$295',
#  '$307',
#  '$405',
#  '$279',
#  '$199',
#  '$343',
#  '—',
#  '$295',
#  '$211',
#  '$244',
#  '$249',
#  '$198',
#  '$388',
#  '$463',
#  '$197',
#  '$326',
#  '$339',
#  '$158',
#  '$188',
#  '$271',
#  '$262',
#  '$331',
#  '$268',
#  '$200',
#  '$344',
#  '$282',
#  '$343',
#  '$263',
#  '$369',
#  '$422',
#  '$340',
#  '$371',
#  '$220',
#  '$476',
#  '$280',
#  '$278',
#  '$208',
#  '$273',
#  '$226',
#  '$301',
#  '$569',
#  '$295',
#  '$307',
#  '$405',
#  '$279',
#  '$199',
#  '$343',
#  '—',
#  '$295',
#  '$211',
#  '$244',
# ...

# %%
len( ppsqft_name19)
# Out:
# 123

# %%
print(len(address_name19),len(price_name19),len(beds_name19),len(baths_name19),len(sqft_name19),len(ppsqft_name19))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df19=pd.DataFrame({'Address':address_name19,'Price':price_name19,'Beds':beds_name19,'Baths':baths_name19,'Total sqft':sqft_name19,'Price per sqft':ppsqft_name19})
df19
# Out:
#                                          Address       Price    Beds  \
# 0
# 1     3434 E Baseline Rd #259, Phoenix, AZ 85042    $289,950  2 beds
# 2    6900 E Princess Dr #1192, Phoenix, AZ 85054    $399,000  2 beds
# 3          2636 E Hidalgo Ave, Phoenix, AZ 85040    $374,000  3 beds
# 4           3540 E Wayland Dr, Phoenix, AZ 85040    $449,000  5 beds
# ..                                           ...         ...     ...
# 118           7346 W Roma Ave, Phoenix, AZ 85033    $399,000  4 beds
# 119          2801 E Avalon Dr, Phoenix, AZ 85016    $543,000  3 beds
# 120     1716 W Cortez St #149, Phoenix, AZ 85029    $329,900  3 beds
# 121           4628 N 71st Ave, Phoenix, AZ 85033    $339,000  3 beds
# 122            9418 N 19th St, Phoenix, AZ 85020  $1,399,000  3 beds
#
#           Baths Total sqft Price per sqft
# 0                      944           $307
# 1       2 baths        985           $405
# 2    1.75 baths      1,341           $279
# ...

# %%
df19.to_csv('file19.csv')

# %%
----------Salt Lake City, UT homes ------------

# %%
address_name20=[]
price_name20=[]
beds_name20=[]
baths_name20=[]
sqft_name20=[]
ppsqft_name20=[]

# %%
address_name20=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag20 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag20:
        address_name20.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

# %%
address_name20
# Out:
# ['',
#  '234 E 100 S Unit B6, Salt Lake City, UT 84111',
#  '374 N I St E, Salt Lake City, UT 84103',
#  '122 N St #7, Salt Lake City, UT 84103',
#  '1512 E Claridge Dr S, Salt Lake City, UT 84124',
#  '1036 S 800 W, Salt Lake City, UT 84104',
#  '260 W 500 N #6, Salt Lake City, UT 84103',
#  '1506 W 2250 S, West Valley City, UT 84119',
#  '4314 S Jupiter Dr, Salt Lake City, UT 84124',
#  '4595 W 5175 S, Kearns, UT 84118',
#  '1340 E Browning Ave, Salt Lake City, UT 84105',
#  '3578 S 805 E #238, Millcreek, UT 84106',
#  '1957 E 3300 S #9, Millcreek, UT 84106',
#  '1945 E 3300 S #12, Millcreek, UT 84106',
#  '4950 S 4820 W, Salt Lake City, UT 84118',
#  '5778 S Lodestone Ave, Salt Lake City, UT 84118',
#  '813 S 800 E, Salt Lake City, UT 84102',
#  '934 E 700 S #10, Salt Lake City, UT 84102',
#  '4538 S Thousand Oaks Dr, Millcreek, UT 84124',
#  '4993 W Niagara Cir, Salt Lake City, UT 84118',
#  '3597 E Millcreek Canyon Rd Rd, Millcreek, UT 84109',
# ...

# %%
len(address_name20)
# Out:
# 123

# %%
price_name20=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag20 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag20:
        price_name20.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name20)

print(len(price_name20))
# Out:
# ['', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305
# ...

# %%
beds_name20=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag20 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag20:
        beds_name20.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name20)

print(len(price_name20))
# Out:
# ['', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305
# ...

# %%
baths_name20=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag20 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag20:
        baths_name20.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name20)

print(len(price_name20))
# Out:
# ['', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305
# ...

# %%
sqft_name20=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag20 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag20:
        sqft_name20.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name20)

print(len(price_name20))
# Out:
# ['', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305
# ...

# %%
ppsqft_name20=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag20 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag20:
        ppsqft_name20.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name20)

print(len(price_name20))
# Out:
# ['', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305,000', '$1,060,000', '$349,000', '$459,000', '$875,000', '$1,150,000', '$400,000', '$800,000', '$450,000', '$655,000', '$354,999', '$724,900', '$724,900', '$424,900', '$430,000', '$925,000', '$339,000', '$4,250,000', '$462,000', '$1,775,000', '$559,685', '$561,967', '$363,900', '$399,000', '$659,000', '$305,000', '$1,295,000', '$549,000', '$378,000', '$380,000', '$745,000', '$525,000', '$775,000', '$495,000', '$550,000', '$584,000', '$439,999', '$550,000', '$549,000', '$455,000', '', '$305
# ...

# %%
print(len(address_name20),len(price_name20),len(beds_name20),len(baths_name20),len(sqft_name20),len(ppsqft_name20))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df20=pd.DataFrame({'Address':address_name20,'Price':price_name20,'Beds':beds_name20,'Baths':baths_name20,'Total sqft':sqft_name20,'Price per sqft':ppsqft_name20})
df20
# Out:
#                                              Address       Price    Beds  \
# 0
# 1      234 E 100 S Unit B6, Salt Lake City, UT 84111    $305,000   1 bed
# 2             374 N I St E, Salt Lake City, UT 84103  $1,060,000  4 beds
# 3              122 N St #7, Salt Lake City, UT 84103    $349,000  2 beds
# 4     1512 E Claridge Dr S, Salt Lake City, UT 84124    $459,000  2 beds
# ..                                               ...         ...     ...
# 118          962 S Lake St, Salt Lake City, UT 84105    $584,000  3 beds
# 119  537 S Montgomery St W, Salt Lake City, UT 84104    $439,999  5 beds
# 120           417 N 1400 W, Salt Lake City, UT 84116    $550,000  5 beds
# 121     882 N Catherine St, Salt Lake City, UT 84116    $549,000  6 beds
# 122           620 E 3945 S, Salt Lake City, UT 84107    $455,000  3 beds
#
#          Baths Total sqft Price per sqft
# 0                     563           $542
# 1       1 bath      2,983           $355
# ...

# %%
df20.to_csv('file20.csv')

# %%
------------New Orleans homes-------------

# %%
address_name21=[]
price_name21=[]
beds_name21=[]
baths_name21=[]
sqft_name21=[]
ppsqft_name21=[]

# %%
address_name21=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag21 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag21:
        address_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name21)

print(len(address_name21))
# Out:
# []
# 0

# %%
address_name21
# Out:
# ['',
#  '4205 07 S Johnson St, New Orleans, LA 70125',
#  '23 Idlewood Pl, River Ridge, LA 70123',
#  '3604 06 3rd St, New Orleans, LA 70125',
#  '1547 49 N Galvez St, New Orleans, LA 70119',
#  '1754 Jackson Ave #1754, New Orleans, LA 70113',
#  '3544 Timber Wolf Ln, New Orleans, LA 70131',
#  '1722 Esplanade Ave, New Orleans, LA 70116',
#  '1936-38 Saint Philip St, New Orleans, LA 70116',
#  '910-12 12 N Prieur St, New Orleans, LA 70116',
#  '914-916 N Prieur St, New Orleans, LA 70116',
#  '1900 Saint Philip St, New Orleans, LA 70116',
#  '815 Patterson St, New Orleans, LA 70114',
#  '1004 Governor Nicholls St Unit G, New Orleans, LA 70116',
#  '832 S Clearview Pkwy #434, Harahan, LA 70123',
#  '3136 Octavia St, New Orleans, LA 70125',
#  '4213 Burgundy St, New Orleans, LA 70117',
#  '2209 Marigny St, New Orleans, LA 70117',
#  '609 Wendy Ln, River Ridge, LA 70123',
#  '5610 New England Dr, New Orleans, LA 70129',
#  '722 Cadiz St, New Orleans, LA 70115',
# ...

# %%
print(len(address_name21))
# Out:
# 123

# %%
price_name21=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag21 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag21:
        price_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785
# ...

# %%
beds_name21=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag21 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag21:
        beds_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785
# ...

# %%
baths_name21=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag21 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag21:
        baths_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785
# ...

# %%
sqft_name21=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag21 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag21:
        sqft_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785
# ...

# %%
ppsqft_name21=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag21 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag21:
        ppsqft_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785,000', '$369,000', '$720,000', '$420,000', '$160,000', '$1,400,000', '$378,250', '$378,250', '$358,250', '$435,250', '$1,225,000', '$220,000', '$210,000', '$749,000', '$289,000', '$160,000', '$380,000', '$205,000', '$575,000', '$540,500', '$745,000', '$429,000', '$285,000', '$375,000', '$475,000', '$249,900', '$599,900', '$430,000', '$649,000', '$270,000', '$539,000', '$214,900', '$289,000', '$124,900', '$224,900', '$230,000', '$899,000', '$115,000', '$639,000', '', '$342,000', '$785
# ...

# %%
print(len(address_name21),len(price_name21),len(beds_name21),len(baths_name21),len(sqft_name21),len(ppsqft_name21))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df21=pd.DataFrame({'Address':address_name21,'Price':price_name21,'Beds':beds_name21,'Baths':baths_name21,'Total sqft':sqft_name21,'Price per sqft':ppsqft_name21})
df21
# Out:
#                                          Address     Price    Beds    Baths  \
# 0
# 1    4205 07 S Johnson St, New Orleans, LA 70125  $342,000  4 beds  2 baths
# 2          23 Idlewood Pl, River Ridge, LA 70123  $785,000  4 beds  3 baths
# 3          3604 06 3rd St, New Orleans, LA 70125  $369,000  6 beds  2 baths
# 4     1547 49 N Galvez St, New Orleans, LA 70119  $720,000  6 beds  4 baths
# ..                                           ...       ...     ...      ...
# 118          1925 Fern St, New Orleans, LA 70118  $224,900  4 beds
# 119           9015 Fig St, New Orleans, LA 70118  $230,000  2 beds
# 120       4121 Baronne St, New Orleans, LA 70115  $899,000  3 beds
# 121     7430 Crestmont Rd, New Orleans, LA 70126  $115,000  3 beds
# 122       5643 Canal Blvd, New Orleans, LA 70124  $639,000  4 beds
#
#     Total sqft Price per sqft
# 0        2,035           $168
# 1        3,037           $258
# 2        2,623           $141
# 3        3,552           $203
# ...

# %%
df21.to_csv('file21.csv')

# %%
-------------Oklahoma City, OK homes--------------

# %%
address_name21=[]
price_name21=[]
beds_name21=[]
baths_name21=[]
sqft_name21=[]
ppsqft_name21=[]

# %%
address_name21=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag21 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag21:
        address_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name21)

print(len(address_name21))
# Out:
# []
# 0

# %%
print(len(address_name21))
# Out:
# 123

# %%
price_name21=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag21 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag21:
        price_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7a3b253a73ee> in <module>
#      12     first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
#      13     first_button.click()
# ---> 14 print(price_name20)
#      15
#      16 print(len(price_name20))
#
# NameError: name 'price_name20' is not defined

# %%
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000
# ...

# %%
beds_name21=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag21 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag21:
        beds_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000
# ...

# %%
baths_name21=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag21 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag21:
        baths_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000
# ...

# %%
sqft_name21=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag21 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag21:
        sqft_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000
# ...

# %%
ppsqft_name21=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag21 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag21:
        ppsqft_name21.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name21)

print(len(price_name21))
# Out:
# ['', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000', '$410,000', '$195,000', '$425,000', '$300,000', '$315,000', '$185,000', '$294,900', '$339,990', '$225,000', '$219,900', '$379,900', '$281,802', '$175,000', '$299,900', '$210,658', '$394,500', '$260,000', '$335,900', '$341,450', '$289,900', '$289,900', '$390,750', '$488,000', '$215,000', '$694,900', '$5,200,000', '$349,900', '$269,900', '$449,000', '$739,000', '$399,900', '$325,000', '$154,900', '$360,000', '$290,000', '$230,000', '$325,000', '$285,000', '', '$385,000', '$350,000
# ...

# %%
print(len(address_name21),len(price_name21),len(beds_name21),len(baths_name21),len(sqft_name21),len(ppsqft_name21))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df22=pd.DataFrame({'Address':address_name21,'Price':price_name21,'Beds':beds_name21,'Baths':baths_name21,'Total sqft':sqft_name21,'Price per sqft':ppsqft_name21})
df22
# Out:
#                                        Address     Price    Beds      Baths  \
# 0
# 1            2520 Sunshine Ln, Yukon, OK 73099  $385,000  4 beds  2.5 baths
# 2    4055 Spyglass Dr, Oklahoma City, OK 73120  $350,000  4 beds    3 baths
# 3            901 NW 188th St, Edmond, OK 73012  $410,000  4 beds    3 baths
# 4     1741 N Roff Ave, Oklahoma City, OK 73107  $195,000  3 beds  1.5 baths
# ..                                         ...       ...     ...        ...
# 118  2508 NW 129th St, Oklahoma City, OK 73120  $360,000  3 beds  2.5 baths
# 119   2518 NW 20th St, Oklahoma City, OK 73107  $290,000  — beds    2 baths
# 120  6109 Westpark Dr, Oklahoma City, OK 73142  $230,000  3 beds    2 baths
# 121        16108 Petaluma Pl, Edmond, OK 73013  $325,000  3 beds    2 baths
# 122    6201 Woodcreek Ct, Warr Acres, OK 73122  $285,000  3 beds    2 baths
#
#     Total sqft Price per sqft
# 0        3,000           $128
# 1        2,555           $137
# 2        2,101           $195
# ...

# %%
df22.to_csv('file22.csv')

# %%
-------------Open Houses for Sale in Oklahoma City----------

# %%
address_name23=[]
price_name23=[]
beds_name23=[]
baths_name23=[]
sqft_name23=[]
ppsqft_name23=[]

# %%
address_name23=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag23 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag23:
        address_name23.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name23)

print(len(address_name23))
# Out:
# ['', '4633 Prominence Dr, Oklahoma City, OK 73179', '4601 N Linn Ave, Oklahoma City, OK 73112', '2304 Sandpiper Ct, Oklahoma City, OK 73170', '17109 Prestwick Cir, Edmond, OK 73012', '2933 Cashion Pl, Oklahoma City, OK 73112', '9800 S Mckinley Ave, Oklahoma City, OK 73139', '631 NW 22nd St, Oklahoma City, OK 73103', '5716 NW 33rd St, Oklahoma City, OK 73122', '3132 SW 140th St, Oklahoma City, OK 73170', '14005 Canterbury Dr, Edmond, OK 73013', '10028 Velletri Ave, Yukon, OK 73099', '6317 Hyde Park Dr, Oklahoma City, OK 73162', '15208 Bedford Rd, Edmond, OK 73013', '11720 Sundance Mountain Rd, Oklahoma City, OK 73162', '1621 NW 146th Ter, Edmond, OK 73013', '6401 NW 164th St, Edmond, OK 73013', '313 Partridge Run Rd, Yukon, OK 73099', '8209 NW 161st Ter, Edmond, OK 73013', '717 Red River Dr, Yukon, OK 73099', '2708 Kingsley Ln, Oklahoma City, OK 73128', '9824 High Noon Rd, Yukon, OK 73099', '15300 SE 49th St, Choctaw, OK 73020', '1419 NW 14th St, Oklahoma City, OK 73106', '917 NW 19th
# ...

# %%
price_name23=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag23 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag23:
        price_name23.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name23)

print(len(price_name23))
# Out:
# ['', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000
# ...

# %%
beds_name23=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag23 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag23:
        beds_name23.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name23)

print(len(price_name23))
# Out:
# ['', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000
# ...

# %%
baths_name23=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag23 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag23:
        baths_name23.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name23)

print(len(price_name23))
# Out:
# ['', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000
# ...

# %%
sqft_name23=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag23 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag23:
        sqft_name23.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name23)

print(len(price_name23))
# Out:
# ['', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000
# ...

# %%
ppsqft_name23=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag23 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag23:
        ppsqft_name23.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name23)

print(len(price_name23))
# Out:
# ['', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000', '$424,900', '$449,000', '$325,000', '$265,000', '$499,000', '$221,500', '$450,000', '$350,000', '$538,500', '$420,000', '$416,900', '$485,900', '$230,000', '$1,282,000', '$299,999', '$338,900', '$430,000', '$335,000', '$245,000', '$509,900', '$565,000', '$719,000', '$215,000', '$249,990', '$597,535', '$479,900', '$325,000', '$345,000', '$314,997', '$258,888', '$324,900', '$225,000', '$285,000', '$899,000', '$350,000', '$289,900', '$370,000', '$465,000', '', '$267,500', '$175,000
# ...

# %%
print(len(address_name23),len(price_name23),len(beds_name23),len(baths_name23),len(sqft_name23),len(ppsqft_name23))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df23=pd.DataFrame({'Address':address_name23,'Price':price_name23,'Beds':beds_name23,'Baths':baths_name23,'Total sqft':sqft_name23,'Price per sqft':ppsqft_name23})
df23
# Out:
#                                          Address     Price    Beds      Baths  \
# 0
# 1    4633 Prominence Dr, Oklahoma City, OK 73179  $267,500  3 beds    2 baths
# 2       4601 N Linn Ave, Oklahoma City, OK 73112  $175,000  3 beds     1 bath
# 3     2304 Sandpiper Ct, Oklahoma City, OK 73170  $424,900  4 beds  2.5 baths
# 4          17109 Prestwick Cir, Edmond, OK 73012  $449,000  4 beds  2.5 baths
# ..                                           ...       ...     ...        ...
# 118   8901 Acre View Dr, Oklahoma City, OK 73151  $899,000  4 beds  3.5 baths
# 119   2201 Belleview Dr, Oklahoma City, OK 73112  $350,000  3 beds    2 baths
# 120             3420 Moraine Dr, Yukon, OK 73099  $289,900  4 beds    2 baths
# 121          3205 NW 192nd Ter, Edmond, OK 73012  $370,000  4 beds  2.5 baths
# 122             9224 NW 85th St, Yukon, OK 73099  $465,000  4 beds  2.5 baths
#
#     Total sqft Price per sqft
# 0        1,347           $199
# 1        1,094           $160
# ...

# %%
df23.to_csv('file23.csv')

# %%
-----------Honolulu open houses----------

# %%
address_name24=[]
price_name24=[]
beds_name24=[]
baths_name24=[]
sqft_name24=[]
ppsqft_name24=[]

# %%
address_name24=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag24 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag24:
        address_name24.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name24)

print(len(address_name24))
# Out:
# ['', '1631 Kapiolani Blvd #3307, Honolulu, HI 96814', '1600 Ala Moana Blvd #1012, Honolulu, HI 96815', '1255 Nuuanu Ave Unit E801, Honolulu, HI 96817', '445 Kaiolu St #1110, Honolulu, HI 96815', '2211 Ala Wai Blvd #1603, Honolulu, HI 96815', '2740 Kuilei St #807, Honolulu, HI 96826', '1025 Kalo Pl #503, Honolulu, HI 96826', '1634 Nuuanu Ave #113, Honolulu, HI 96817', '1556 Piikoi St #1802, Honolulu, HI 96822', '1231 Rycroft St, Honolulu, HI 96814', '168 Queen St #1202, Honolulu, HI 96813', '96 Moaniala Pl, Honolulu, HI 96821', '3137 Lincoln Ave, Honolulu, HI 96816', '400 Hobron Ln #3310, Honolulu, HI 96815', '2754 Kuilei St #1405, Honolulu, HI 96826', '780 Amana St #908, Honolulu, HI 96814', '318 Honono St, Honolulu, HI 96825', '876 Curtis St #2501, Honolulu, HI 96813', '222 Kaiulani Ave #202, Honolulu, HI 96815', '1360 Kaeleku St, Honolulu, HI 96825', '1095 Luapele Dr, Honolulu, HI 96818', '747 Amana St #901, Honolulu, HI 96814', '725 Kapiolani Blvd #806, Honolulu, HI 96813', '3148 
# ...

# %%
price_name24=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag24 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag24:
        price_name24.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name24)

print(len(price_name24))
# Out:
# ['', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,985,000', '$2,795,000', '', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,9
# ...

# %%
beds_name24=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag24 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag24:
        beds_name24.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name24)

print(len(price_name24))
# Out:
# ['', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,985,000', '$2,795,000', '', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,9
# ...

# %%
baths_name24=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag24 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag24:
        baths_name24.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name24)

print(len(price_name24))
# Out:
# ['', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,985,000', '$2,795,000', '', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,9
# ...

# %%
sqft_name24=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag24 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag24:
        sqft_name24.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name24)

print(len(price_name24))
# Out:
# ['', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,985,000', '$2,795,000', '', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,9
# ...

# %%
ppsqft_name24=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag24 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag24:
        ppsqft_name24.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name24)

print(len(price_name24))
# Out:
# ['', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,985,000', '$2,795,000', '', '$915,000', '$1,050,000', '$640,000', '$340,000', '$328,000', '$425,000', '$290,000', '$525,000', '$399,999', '$1,200,000', '$749,100', '$3,950,000', '$920,000', '$455,000', '$518,000', '$498,000', '$1,225,000', '$520,000', '$450,000', '$1,390,000', '$1,360,000', '$285,000', '$585,000', '$419,500', '$925,000', '$1,050,000', '$375,000', '$630,000', '$862,800', '$1,150,000', '$1,350,000', '$259,000', '$390,000', '$1,880,000', '$830,000', '$345,000', '$868,000', '$1,079,000', '$2,9
# ...

# %%
print(len(address_name24),len(price_name24),len(beds_name24),len(baths_name24),len(sqft_name24),len(ppsqft_name24))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df24=pd.DataFrame({'Address':address_name24,'Price':price_name24,'Beds':beds_name24,'Baths':baths_name24,'Total sqft':sqft_name24,'Price per sqft':ppsqft_name24})
df24
# Out:
#                                            Address       Price    Beds  \
# 0
# 1    1631 Kapiolani Blvd #3307, Honolulu, HI 96814    $915,000  2 beds
# 2    1600 Ala Moana Blvd #1012, Honolulu, HI 96815  $1,050,000  2 beds
# 3    1255 Nuuanu Ave Unit E801, Honolulu, HI 96817    $640,000  2 beds
# 4          445 Kaiolu St #1110, Honolulu, HI 96815    $340,000   1 bed
# ..                                             ...         ...     ...
# 118    2500 Kalakaua Ave #2103, Honolulu, HI 96815    $345,000   1 bed
# 119          88 Piikoi St #904, Honolulu, HI 96814    $868,000  2 beds
# 120     629 Keeaumoku St #1710, Honolulu, HI 96814  $1,079,000  2 beds
# 121            148 Makaweli St, Honolulu, HI 96825  $2,985,000  3 beds
# 122        2139 Kamehameha Ave, Honolulu, HI 96822  $2,795,000  3 beds
#
#        Baths Total sqft Price per sqft
# 0                   898         $1,019
# 1    2 baths      1,428           $735
# 2    2 baths      1,000           $640
# ...

# %%
df24.to_csv('file24.csv')

# %%
---------Condos for Sale in Baltimore--------

# %%
address_name25=[]
price_name25=[]
beds_name25=[]
baths_name25=[]
sqft_name25=[]
ppsqft_name25=[]

# %%
address_name25=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag25 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag25:
        address_name25.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name25)

print(len(address_name25))
# Out:
# ['', '11 W Biddle St Unit 2B, Baltimore, MD 21201', '100 Harborview Dr #1113, Baltimore, MD 21230', '111 Hamlet Hill Rd #410, Baltimore, MD 21210', '801 Key Hwy #423, Baltimore, MD 21230', '6 W Mount Vernon Pl Unit B1, Baltimore, MD 21201', '2201-F Falls Gable Ln Unit F, Baltimore, MD 21209', '911 S Charles St S #302, Baltimore, MD 21230', '1726 Aliceanna St Unit 304-SB, Baltimore, MD 21231', '11 Suntop Ct Unit T-2, Baltimore, MD 21209', '100 Harborview Dr #614, Baltimore, MD 21230', '2702 Lighthouse Pt E #517, Baltimore, MD 21224', '1120 Saint Paul St #25, Baltimore, MD 21202', '675 President St #2302, Baltimore, MD 21202', '1726 Aliceanna St Unit 307-NB, Baltimore, MD 21231', '1000 Fell St #240, Baltimore, MD 21231', '3000 Stone Cliff Dr #111, Baltimore, MD 21209', '1001 Saint Paul St Unit 3G, Baltimore, MD 21202', '3635 Glengyle Ave Unit 5C, Baltimore, MD 21215', '1211 Light St #105, Baltimore, MD 21230', '4408 Falls Bridge Dr Unit D, Baltimore, MD 21211', '3011 Fallstaff Rd Unit 
# ...

# %%
price_name25=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag25 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag25:
        price_name25.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name25)

print(len(price_name25))
# Out:
# ['', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170
# ...

# %%
beds_name25=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag25 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag25:
        beds_name25.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name25)

print(len(price_name25))
# Out:
# ['', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170
# ...

# %%
baths_name25=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag25 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag25:
        baths_name25.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name25)

print(len(price_name25))
# Out:
# ['', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170
# ...

# %%
sqft_name25=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag25 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag25:
        sqft_name25.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name25)

print(len(price_name25))
# Out:
# ['', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170
# ...

# %%
ppsqft_name25=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag25 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag25:
        ppsqft_name25.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name25)

print(len(price_name25))
# Out:
# ['', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170,000', '$499,000', '$320,000', '$245,000', '$239,900', '$349,900', '$142,900', '$400,000', '$249,900', '$145,000', '$335,000', '$250,000', '$205,000', '$860,000', '$90,000', '$175,000', '$188,900', '$80,000', '$229,000', '$329,000', '$575,000', '$139,944', '$499,000', '$199,900', '$378,000', '$275,000', '$425,000', '$179,900', '$385,000', '$115,000', '$639,000', '$350,000', '$655,000', '$319,000', '$135,000', '$335,000', '$120,000', '$155,000', '', '$156,900', '$350,000', '$170
# ...

# %%
print(len(address_name25),len(price_name25),len(beds_name25),len(baths_name25),len(sqft_name25),len(ppsqft_name25))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df25=pd.DataFrame({'Address':address_name25,'Price':price_name25,'Beds':beds_name25,'Baths':baths_name25,'Total sqft':sqft_name25,'Price per sqft':ppsqft_name25})
df25
# Out:
#                                              Address     Price    Beds  \
# 0
# 1        11 W Biddle St Unit 2B, Baltimore, MD 21201  $156,900   1 bed
# 2       100 Harborview Dr #1113, Baltimore, MD 21230  $350,000  2 beds
# 3       111 Hamlet Hill Rd #410, Baltimore, MD 21210  $170,000   1 bed
# 4              801 Key Hwy #423, Baltimore, MD 21230  $499,000  2 beds
# ..                                               ...       ...     ...
# 118        1200 Steuart St #325, Baltimore, MD 21230  $319,000   1 bed
# 119           1 E Chase St #906, Baltimore, MD 21202  $135,000   1 bed
# 120     3801 Canterbury Rd #603, Baltimore, MD 21218  $335,000  2 beds
# 121  6606 Park Heights Ave #505, Baltimore, MD 21215  $120,000  2 beds
# 122          2202 Park Ave #201, Baltimore, MD 21217  $155,000  3 beds
#
#          Baths Total sqft Price per sqft
# 0                     760           $206
# 1       1 bath      1,355           $258
# 2      2 baths        961           $177
# ...

# %%
df25.to_csv('file25.csv')

# %%
------------Condos for Sale Jersey City-------------

# %%
address_name26=[]
price_name26=[]
beds_name26=[]
baths_name26=[]
sqft_name26=[]
ppsqft_name26=[]

# %%
address_name26=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag26 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag26:
        address_name26.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name26)

print(len(address_name26))
# Out:
# ['349 3RD St #1, Jersey City, NJ 07302', '77 HUDSON St #3608, Jersey City, NJ 07302', '104 ZABRISKIE St #1, Jersey City, NJ 07307', '1 2ND St #908, Jersey City, NJ 07302', '232 PAVONIA Ave Unit 323a, Jersey City, NJ 07302', '302 PALISADE Ave #203, Jersey City, NJ 07307', '77 HUDSON St Ph 4904/05, Jersey City, NJ 07302', '386 5TH St #202, Jersey City, NJ 07302', '127 BOORAEM Ave Unit 3L, Jersey City, NJ 07307', '205 10TH St Unit 9V, Jersey City, NJ 07302', '1 GREENE St #411, Jersey City, NJ 07302', '444 JERSEY Ave #13, Jersey City, NJ 07306', '45 RIVER Dr S #1405, Jersey City, NJ 07310', '1 2ND St #707, Jersey City, NJ 07302', '75 PARK Ln S #420, Jersey City, NJ 07310', '236 BOWERS St #3, Jersey City, NJ 07307', '201 LUIS M MARIN Blvd #507, Jersey City, NJ 07302', '25 MCWILLIAMS Pl Ph 507, Jersey City, NJ 07302', '300 Communipaw Ave, Jersey City, NJ 07304', '300 Communipaw Ave #108, Jersey City, NJ 07304-4075', '323 4TH St, Jersey City, NJ 07302', '661 Jersey Ave #2, Jersey City, NJ 0
# ...

# %%
price_name26=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag26 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag26:
        price_name26.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name26)

print(len(price_name26))
# Out:
# ['$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '$849,000', '$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '
# ...

# %%
beds_name26=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag26 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag26:
        beds_name26.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name26)

print(len(price_name26))
# Out:
# ['$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '$849,000', '$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '
# ...

# %%
baths_name26=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag26 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag26:
        baths_name26.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name26)

print(len(price_name26))
# Out:
# ['$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '$849,000', '$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '
# ...

# %%
sqft_name26=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag26 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag26:
        sqft_name26.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name26)

print(len(price_name26))
# Out:
# ['$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '$849,000', '$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '
# ...

# %%
ppsqft_name26=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag26 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag26:
        ppsqft_name26.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name26)

print(len(price_name26))
# Out:
# ['$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '$849,000', '$1,297,000', '$1,049,000', '$949,000', '$679,000', '$1,390,000', '$789,000', '$6,995,000', '$599,000', '$482,000', '$799,000', '$699,000', '$579,000', '$829,000', '$559,000', '$600,000', '$550,000', '$1,080,000', '$1,250,000', '$449,000', '$449,000', '$1,299,000', '$888,000', '$227,930', '$1,170,000', '$969,999', '$650,000', '$699,000', '$999,000', '$999,000', '$1,197,000', '$220,000', '$995,000', '$749,000', '$269,000', '$1,125,000', '$1,050,000', '$1,590,000', '$799,000', '$799,000', '
# ...

# %%
print(len(address_name26),len(price_name26),len(beds_name26),len(baths_name26),len(sqft_name26),len(ppsqft_name26))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name26[120:123]

# %%
import pandas as pd
df26=pd.DataFrame({'Address':address_name26,'Price':price_name26,'Beds':beds_name26,'Baths':baths_name26,'Total sqft':sqft_name26,'Price per sqft':ppsqft_name26})
df26
# Out:
#                                                Address       Price    Beds  \
# 0                 349 3RD St #1, Jersey City, NJ 07302  $1,297,000  3 beds
# 1            77 HUDSON St #3608, Jersey City, NJ 07302  $1,049,000   1 bed
# 2           104 ZABRISKIE St #1, Jersey City, NJ 07307    $949,000  3 beds
# 3                 1 2ND St #908, Jersey City, NJ 07302    $679,000   1 bed
# 4     232 PAVONIA Ave Unit 323a, Jersey City, NJ 07302  $1,390,000  2 beds
# ..                                                 ...         ...     ...
# 115              49 GRACE St #2, Jersey City, NJ 07307  $1,050,000  3 beds
# 116           25 HUDSON St #308, Jersey City, NJ 07302  $1,590,000  2 beds
# 117  201 LUIS M MARIN Blvd #6010, Jersey City, NJ 0...    $799,000   1 bed
# 118           135 NELSON Ave #2, Jersey City, NJ 07307    $799,000  3 beds
# 119           135 NELSON Ave #1, Jersey City, NJ 07307    $849,000  3 beds
#
#          Baths Total sqft Price per sqft
# ...

# %%
df26.to_csv('file26.csv')

# %%
---------------Condos for Sale in Indianapolis-----------

# %%
address_name27=[]
price_name27=[]
beds_name27=[]
baths_name27=[]
sqft_name27=[]
ppsqft_name27=[]

# %%
address_name27=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag27 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag27:
        address_name27.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name27)

print(len(address_name27))
# Out:
# ['', '7467 Prairie Lake Dr, Indianapolis, IN 46256', '141 S Meridian St Ste 503, Indianapolis, IN 46225', '877 N East St #103, Indianapolis, IN 46202', '5146 Cobham Way, Indianapolis, IN 46237', '2048 Oak Run South Dr, Indianapolis, IN 46260', '624 E Walnut St #46, Indianapolis, IN 46204', '4000 N Meridian St Unit 15F, Indianapolis, IN 46208', '7604 Castleton Farms Dr N, Indianapolis, IN 46256', '9526 Cedar Springs Dr, Indianapolis, IN 46260', '9331 Doubloon Rd, Indianapolis, IN 46268', '5347 N College Ave #205, Indianapolis, IN 46220', '919 Broadway St Unit D, Indianapolis, IN 46202', '8751 Jaffa Court Dr E #35, Indianapolis, IN 46260', '5755 Spruce Knoll Cir, Indianapolis, IN 46220', '4000 N Meridian St Unit 1G, Indianapolis, IN 46208', '5908 Streamwood Ln, Indianapolis, IN 46237', '4000 N Meridian St Unit 7G, Indianapolis, IN 46208', '5645 Bradston Way, Indianapolis, IN 46237', '490 E 10th St, Indianapolis, IN 46202', '7434 King George Dr Unit D, Indianapolis, IN 46260', '877 N Ea
# ...

# %%
price_name27=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag27 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag27:
        price_name27.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name27)

print(len(price_name27))
# Out:
# ['', '$260,000', '$420,000', '$895,000', '$269,900', '$240,000', '$517,000', '$198,500', '$200,000', '$400,000', '$249,900', '$197,500', '$250,000', '$245,000', '$319,000', '$499,500', '$215,500', '$324,900', '$185,000', '$319,900', '$200,000', '$516,100', '$429,400', '$215,000', '$199,500', '$235,000', '$167,700', '$215,000', '$225,000', '$137,000', '$585,500', '$590,900', '$448,200', '$139,000', '$185,000', '$235,000', '$480,000', '$229,499', '$245,000', '$235,000', '$149,900', '', '$260,000', '$420,000', '$895,000', '$269,900', '$240,000', '$517,000', '$198,500', '$200,000', '$400,000', '$249,900', '$197,500', '$250,000', '$245,000', '$319,000', '$499,500', '$215,500', '$324,900', '$185,000', '$319,900', '$200,000', '$516,100', '$429,400', '$215,000', '$199,500', '$235,000', '$167,700', '$215,000', '$225,000', '$137,000', '$585,500', '$590,900', '$448,200', '$139,000', '$185,000', '$235,000', '$480,000', '$229,499', '$245,000', '$235,000', '$149,900', '', '$260,000', '$420,000', '
# ...

# %%
beds_name27=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag27 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag27:
        beds_name27.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(beds_name27)
print(len(beds_name27))
# Out:
# ['', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '1 bed', '3 beds', '3 beds', '3 beds', '1 bed', '2 beds', '2 beds', '1 bed', '2 beds', '', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '1 bed', '3 beds', '3 beds', '3 beds', '1 bed', '2 beds', '2 beds', '1 bed', '2 beds', '', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds',
# ...

# %%
baths_name27=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag27 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag27:
        baths_name27.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(baths_name27)

print(len(baths_name27))
# Out:
# ['', '2.5 baths', '2 baths', '3 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2.5 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2 baths', '2 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '2 baths', '2 baths', '2 baths', '1.5 baths', '2 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2 baths', '1.5 baths', '2.5 baths', '1 bath', '1.5 baths', '2 baths', '1 bath', '2 baths', '', '2.5 baths', '2 baths', '3 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2.5 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2 baths', '2 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '2 baths', '2 baths', '2 baths', '1.5 baths', '2 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2 baths', '1.5 baths', '2.5 baths', '1 bath', '1.5 baths', '2 baths', '1 bath', '2 baths', '', '2.5 baths', '2 baths', '3 baths', '2 baths', '2 baths', '2 baths', '1 bath', '
# ...

# %%
baths_name27=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag27 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag27:
        baths_name27.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(baths_name27)

print(len(baths_name27))
# Out:
# ['', '2.5 baths', '2 baths', '3 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2.5 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2 baths', '2 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '2 baths', '2 baths', '2 baths', '1.5 baths', '2 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2 baths', '1.5 baths', '2.5 baths', '1 bath', '1.5 baths', '2 baths', '1 bath', '2 baths', '', '2.5 baths', '2 baths', '3 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2.5 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2 baths', '2 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '2 baths', '2 baths', '2 baths', '1.5 baths', '2 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2 baths', '1.5 baths', '2.5 baths', '1 bath', '1.5 baths', '2 baths', '1 bath', '2 baths', '', '2.5 baths', '2 baths', '3 baths', '2 baths', '2 baths', '2 baths', '1 bath', '
# ...

# %%
sqft_name27=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag27 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag27:
        sqft_name27.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name27)

print(len(price_name27))
# Out:
# ['', '$260,000', '$420,000', '$895,000', '$269,900', '$240,000', '$517,000', '$198,500', '$200,000', '$400,000', '$249,900', '$197,500', '$250,000', '$245,000', '$319,000', '$499,500', '$215,500', '$324,900', '$185,000', '$319,900', '$200,000', '$516,100', '$429,400', '$215,000', '$199,500', '$235,000', '$167,700', '$215,000', '$225,000', '$137,000', '$585,500', '$590,900', '$448,200', '$139,000', '$185,000', '$235,000', '$480,000', '$229,499', '$245,000', '$235,000', '$149,900', '', '$260,000', '$420,000', '$895,000', '$269,900', '$240,000', '$517,000', '$198,500', '$200,000', '$400,000', '$249,900', '$197,500', '$250,000', '$245,000', '$319,000', '$499,500', '$215,500', '$324,900', '$185,000', '$319,900', '$200,000', '$516,100', '$429,400', '$215,000', '$199,500', '$235,000', '$167,700', '$215,000', '$225,000', '$137,000', '$585,500', '$590,900', '$448,200', '$139,000', '$185,000', '$235,000', '$480,000', '$229,499', '$245,000', '$235,000', '$149,900', '', '$260,000', '$420,000', '
# ...

# %%
ppsqft_name27=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag27 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag27:
        ppsqft_name27.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name27)

print(len(price_name27))
# Out:
# ['', '$260,000', '$420,000', '$895,000', '$269,900', '$240,000', '$517,000', '$198,500', '$200,000', '$400,000', '$249,900', '$197,500', '$250,000', '$245,000', '$319,000', '$499,500', '$215,500', '$324,900', '$185,000', '$319,900', '$200,000', '$516,100', '$429,400', '$215,000', '$199,500', '$235,000', '$167,700', '$215,000', '$225,000', '$137,000', '$585,500', '$590,900', '$448,200', '$139,000', '$185,000', '$235,000', '$480,000', '$229,499', '$245,000', '$235,000', '$149,900', '', '$260,000', '$420,000', '$895,000', '$269,900', '$240,000', '$517,000', '$198,500', '$200,000', '$400,000', '$249,900', '$197,500', '$250,000', '$245,000', '$319,000', '$499,500', '$215,500', '$324,900', '$185,000', '$319,900', '$200,000', '$516,100', '$429,400', '$215,000', '$199,500', '$235,000', '$167,700', '$215,000', '$225,000', '$137,000', '$585,500', '$590,900', '$448,200', '$139,000', '$185,000', '$235,000', '$480,000', '$229,499', '$245,000', '$235,000', '$149,900', '', '$260,000', '$420,000', '
# ...

# %%
print(len(address_name27),len(price_name27),len(beds_name27),len(baths_name27),len(sqft_name27),len(ppsqft_name27))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df27=pd.DataFrame({'Address':address_name27,'Price':price_name27,'Beds':beds_name27,'Baths':baths_name27,'Total sqft':sqft_name27,'Price per sqft':ppsqft_name27})
df27
# Out:
#                                                Address     Price    Beds  \
# 0
# 1         7467 Prairie Lake Dr, Indianapolis, IN 46256  $260,000  2 beds
# 2    141 S Meridian St Ste 503, Indianapolis, IN 46225  $420,000  2 beds
# 3           877 N East St #103, Indianapolis, IN 46202  $895,000  3 beds
# 4              5146 Cobham Way, Indianapolis, IN 46237  $269,900  2 beds
# ..                                                 ...       ...     ...
# 118         855 N East St #106, Indianapolis, IN 46202  $480,000   1 bed
# 119        9620 Highgate Cir N, Indianapolis, IN 46250  $229,499  2 beds
# 120       2637 Big Bear Ln #77, Indianapolis, IN 46217  $245,000  2 beds
# 121  802 N Meridian St N Unit 307, Indianapolis, IN...  $235,000   1 bed
# 122  4291 Village Parkway Cir W #12, Indianapolis, ...  $149,900  2 beds
#
#          Baths Total sqft Price per sqft
# 0                   2,124           $122
# 1    2.5 baths      2,340           $179
# ...

# %%
df27.to_csv('file27.csv')

# %%
-----------------Condos for Sale in Milwaukee, WI-------------

# %%
address_name28=[]
price_name28=[]
beds_name28=[]
baths_name28=[]
sqft_name28=[]
ppsqft_name28=[]

# %%
address_name28=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag28 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag28:
        address_name28.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name28)

print(len(address_name28))
# Out:
# ['1028 E Juneau Ave #418, Milwaukee, WI 53202', '6991 W Glenbrook Rd #2, Milwaukee, WI 53223', '11946 W Mill Rd #15, Milwaukee, WI 53225', '545 E Wells St #401, Milwaukee, WI 53202', '9258 N 70th St #1, Milwaukee, WI 53223', '1915 N Water St #107, Milwaukee, WI 53202', '106 W Seeboth St #609, Milwaukee, WI 53204', '106 W Seeboth St #514, Milwaukee, WI 53204', '3243 S 92nd St #100, Milwaukee, WI 53227', '8910 N 95th St Unit M, Milwaukee, WI 53224', '1313 N Franklin Pl #1604, Milwaukee, WI 53202', '3320 N Lake Dr, Milwaukee, WI 53211', '1300 N Prospect Ave #208, Milwaukee, WI 53202', '7841 W Heather Ave, Milwaukee, WI 53223', '1919 N Summit Ave Unit 3A, Milwaukee, WI 53202', '8634 N Servite Dr, Milwaukee, WI 53223', '6266 W Port Ave, Milwaukee, WI 53223', '777 N Prospect Ave Unit South Tier 4, Milwaukee, WI 53202', '8860 N 95th St, Milwaukee, WI 53224', '8027 N 94th St, Milwaukee, WI 53224', '1550 E Royall Pl #509, Milwaukee, WI 53202', '904 E Pearson St #323, Milwaukee, WI 53202', '15
# ...

# %%
price_name28=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag28 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag28:
        price_name28.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name28)

print(len(price_name28))
# Out:
# ['$125,000', '$129,000', '$149,900', '$199,900', '$128,000', '$265,000', '$409,900', '$379,900', '$194,900', '$89,900', '$1,550,000', '$675,000', '$850,000', '$154,900', '$249,900', '$119,900', '$79,900', '$799,900', '$74,900', '$130,000', '$399,000', '$192,000', '$245,000', '$169,900', '$527,900', '$499,000', '$156,000', '$379,900', '$780,000', '$425,000', '$130,000', '$159,900', '$235,000', '$990,000', '$425,000', '$159,900', '$109,900', '$158,500', '$689,000', '$469,800', '$125,000', '$129,000', '$149,900', '$199,900', '$128,000', '$265,000', '$409,900', '$379,900', '$194,900', '$89,900', '$1,550,000', '$675,000', '$850,000', '$154,900', '$249,900', '$119,900', '$79,900', '$799,900', '$74,900', '$130,000', '$399,000', '$192,000', '$245,000', '$169,900', '$527,900', '$499,000', '$156,000', '$379,900', '$780,000', '$425,000', '$130,000', '$159,900', '$235,000', '$990,000', '$425,000', '$159,900', '$109,900', '$158,500', '$689,000', '$469,800', '$125,000', '$129,000', '$149,900', '$1
# ...

# %%
beds_name28=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag28 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag28:
        beds_name28.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(beds_name28)

print(len(beds_name28))
# Out:
# ['0 beds', '3 beds', '2 beds', '1 bed', '3 beds', '1 bed', '1 bed', '1 bed', '2 beds', '4 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '3 beds', '3 beds', '2 beds', '1 bed', '1 bed', '2 beds', '2 beds', '3 beds', '3 beds', '1 bed', '2 beds', '2 beds', '3 beds', '3 beds', '1 bed', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '0 beds', '3 beds', '2 beds', '1 bed', '3 beds', '1 bed', '1 bed', '1 bed', '2 beds', '4 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '3 beds', '3 beds', '2 beds', '1 bed', '1 bed', '2 beds', '2 beds', '3 beds', '3 beds', '1 bed', '2 beds', '2 beds', '3 beds', '3 beds', '1 bed', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '0 beds', '3 beds', '2 beds', '1 bed', '3 beds', '1 bed', '1 bed', '1 bed', '2 beds', '4 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '3 beds', '3 beds', '2 beds', '1 bed'
# ...

# %%
baths_name28=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag28 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag28:
        baths_name28.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(baths_name28)

print(len(baths_name28))
# Out:
# ['1 bath', '2.5 baths', '1.5 baths', '1 bath', '1.5 baths', '1 bath', '1 bath', '1 bath', '2 baths', '1.5 baths', '3 baths', '2.5 baths', '2 baths', '2 baths', '1.5 baths', '1.5 baths', '2 baths', '2 baths', '1.5 baths', '1.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '3.5 baths', '1.5 baths', '1.5 baths', '2 baths', '1.5 baths', '1.5 baths', '2.5 baths', '1 bath', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2.5 baths', '2.5 baths', '1 bath', '2.5 baths', '1.5 baths', '1 bath', '1.5 baths', '1 bath', '1 bath', '1 bath', '2 baths', '1.5 baths', '3 baths', '2.5 baths', '2 baths', '2 baths', '1.5 baths', '1.5 baths', '2 baths', '2 baths', '1.5 baths', '1.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '3.5 baths', '1.5 baths', '1.5 baths', '2 baths', '1.5 baths', '1.5 baths', '2.5 baths', '1 bath', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2.5 baths', '2.5 baths', '1 bath', '2.5 baths', '1.5 baths', '1 bath', '1.5 baths', '1 bat
# ...

# %%
sqft_name28=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag28 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag28:
        sqft_name28.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name28)

print(len(price_name28))
# Out:
# ['$125,000', '$129,000', '$149,900', '$199,900', '$128,000', '$265,000', '$409,900', '$379,900', '$194,900', '$89,900', '$1,550,000', '$675,000', '$850,000', '$154,900', '$249,900', '$119,900', '$79,900', '$799,900', '$74,900', '$130,000', '$399,000', '$192,000', '$245,000', '$169,900', '$527,900', '$499,000', '$156,000', '$379,900', '$780,000', '$425,000', '$130,000', '$159,900', '$235,000', '$990,000', '$425,000', '$159,900', '$109,900', '$158,500', '$689,000', '$469,800', '$125,000', '$129,000', '$149,900', '$199,900', '$128,000', '$265,000', '$409,900', '$379,900', '$194,900', '$89,900', '$1,550,000', '$675,000', '$850,000', '$154,900', '$249,900', '$119,900', '$79,900', '$799,900', '$74,900', '$130,000', '$399,000', '$192,000', '$245,000', '$169,900', '$527,900', '$499,000', '$156,000', '$379,900', '$780,000', '$425,000', '$130,000', '$159,900', '$235,000', '$990,000', '$425,000', '$159,900', '$109,900', '$158,500', '$689,000', '$469,800', '$125,000', '$129,000', '$149,900', '$1
# ...

# %%
ppsqft_name28=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag28 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag28:
        ppsqft_name28.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name28)

print(len(price_name28))
# Out:
# ['$125,000', '$129,000', '$149,900', '$199,900', '$128,000', '$265,000', '$409,900', '$379,900', '$194,900', '$89,900', '$1,550,000', '$675,000', '$850,000', '$154,900', '$249,900', '$119,900', '$79,900', '$799,900', '$74,900', '$130,000', '$399,000', '$192,000', '$245,000', '$169,900', '$527,900', '$499,000', '$156,000', '$379,900', '$780,000', '$425,000', '$130,000', '$159,900', '$235,000', '$990,000', '$425,000', '$159,900', '$109,900', '$158,500', '$689,000', '$469,800', '$125,000', '$129,000', '$149,900', '$199,900', '$128,000', '$265,000', '$409,900', '$379,900', '$194,900', '$89,900', '$1,550,000', '$675,000', '$850,000', '$154,900', '$249,900', '$119,900', '$79,900', '$799,900', '$74,900', '$130,000', '$399,000', '$192,000', '$245,000', '$169,900', '$527,900', '$499,000', '$156,000', '$379,900', '$780,000', '$425,000', '$130,000', '$159,900', '$235,000', '$990,000', '$425,000', '$159,900', '$109,900', '$158,500', '$689,000', '$469,800', '$125,000', '$129,000', '$149,900', '$1
# ...

# %%
print(len(address_name28),len(price_name28),len(beds_name28),len(baths_name28),len(sqft_name28),len(ppsqft_name28))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name28[120:123]

# %%
import pandas as pd
df28=pd.DataFrame({'Address':address_name28,'Price':price_name28,'Beds':beds_name28,'Baths':baths_name28,'Total sqft':sqft_name28,'Price per sqft':ppsqft_name28})
df28
# Out:
#                                           Address     Price    Beds  \
# 0     1028 E Juneau Ave #418, Milwaukee, WI 53202  $125,000  0 beds
# 1     6991 W Glenbrook Rd #2, Milwaukee, WI 53223  $129,000  3 beds
# 2        11946 W Mill Rd #15, Milwaukee, WI 53225  $149,900  2 beds
# 3        545 E Wells St #401, Milwaukee, WI 53202  $199,900   1 bed
# 4          9258 N 70th St #1, Milwaukee, WI 53223  $128,000  3 beds
# ..                                            ...       ...     ...
# 115  8118 W Oklahoma Ave #6, West Allis, WI 53219  $159,900  2 beds
# 116   8549 N Servite Dr #106, Milwaukee, WI 53223  $109,900  2 beds
# 117   8605 N Servite Dr #103, Milwaukee, WI 53223  $158,500  2 beds
# 118         1113 N Edison St, Milwaukee, WI 53202  $689,000  2 beds
# 119      2121 N Riverboat Rd, Milwaukee, WI 53212  $469,800  2 beds
#
#          Baths Total sqft Price per sqft
# 0       1 bath        325           $385
# 1    2.5 baths      1,553            $83
# ...

# %%
df28.to_csv('file28.csv')

# %%
--------------Memphis homes-------------

# %%
address_name29=[]
price_name29=[]
beds_name29=[]
baths_name29=[]
sqft_name29=[]
ppsqft_name29=[]

# %%
address_name29=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag29 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag29:
        address_name29.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name29)

print(len(address_name29))
# Out:
# ['5400 Park Ave #305, Memphis, TN 38119', '2263 Young Ave #204, Memphis, TN 38104', '4771 Audubon View Cir #3005, Memphis, TN 38117', '2195 Poplar Ave #203, Memphis, TN 38104', '1118 Poplar Ave #11, Memphis, TN 38105', '3968 Grahamdale Cir, Memphis, TN 38122', '838 Thistledown Dr #1101, Memphis, TN 38117', '1738 Fox Hunt Ln #1738, Memphis, TN 38134', '6660 Pondside Cir #2, Memphis, TN 38119', '731 Litty Ct #204, Memphis, TN 38103', '232 S Highland St #707, Memphis, TN 38111', '702 Hedgegrove Dr #4201, Memphis, TN 38117', '232 S Highland Ave #103, Memphis, TN 38111', '760 Harbor Bend Rd #106, Memphis, TN 38103', '6746 Quail Hollow Ct #1, Memphis, TN 38120', '66 Monroe Ave #306, Memphis, TN 38103', '475 N Highland St Unit 1B, Memphis, TN 38122', '655 Riverside Dr #203, Memphis, TN 38103', '3981 Grahamdale Cir Unit 3981B, Memphis, TN 38122', '3989 Grahamdale Cir Unit 3989A, Memphis, TN 38122', '3967 Grahamdale Cir Unit 3967B, Memphis, TN 38122', '5718 Quince Rd #1, Memphis, TN 38119', '
# ...

# %%
price_name29=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag29 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag29:
        price_name29.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name29)

print(len(price_name29))
# Out:
# ['$290,000', '$79,900', '$99,900', '$275,000', '$155,000', '$140,000', '$395,000', '$107,500', '$220,000', '$235,000', '$200,000', '$259,000', '$60,000', '$44,000', '$116,000', '$42,000', '$419,000', '$129,000', '$465,000', '$50,000', '$50,000', '$175,000', '$1,250,000', '$285,000', '$275,000', '$219,000', '$129,000', '$385,000', '$250,000', '$169,900', '$319,900', '$499,000', '$190,000', '$130,000', '$224,900', '$79,500', '$395,000', '$299,999', '$219,000', '$445,000', '$290,000', '$79,900', '$99,900', '$275,000', '$155,000', '$140,000', '$395,000', '$107,500', '$220,000', '$235,000', '$200,000', '$259,000', '$60,000', '$44,000', '$116,000', '$42,000', '$419,000', '$129,000', '$465,000', '$50,000', '$50,000', '$175,000', '$1,250,000', '$285,000', '$275,000', '$219,000', '$129,000', '$385,000', '$250,000', '$169,900', '$319,900', '$499,000', '$190,000', '$130,000', '$224,900', '$79,500', '$395,000', '$299,999', '$219,000', '$445,000', '$290,000', '$79,900', '$99,900', '$275,000', '$1
# ...

# %%
beds_name29=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag29 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag29:
        beds_name29.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(beds_name29)

print(len(beds_name29))
# Out:
# ['1 bed', '3 beds', '2 beds', '2 beds', '1 bed', '3 beds', '2 beds', '1 bed', '2 beds', '1 bed', '1 bed', '1 bed', '2 beds', '1 bed', '0 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '4 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '1 bed', '1 bed', '2 beds', '1 bed', '2 beds', '1 bed', '2 beds', '1 bed', '3 beds', '2 beds', '2 beds', '1 bed', '3 beds', '2 beds', '1 bed', '2 beds', '1 bed', '1 bed', '1 bed', '2 beds', '1 bed', '0 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '4 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '1 bed', '1 bed', '2 beds', '1 bed', '2 beds', '1 bed', '2 beds', '1 bed', '3 beds', '2 beds', '2 beds', '1 bed', '3 beds', '2 beds', '1 bed', '2 beds', '1 bed', '1 bed', '1 bed', '2 beds', '1 bed', '0 beds', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '2 beds', '4 bed
# ...

# %%
baths_name29=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag29 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag29:
        baths_name29.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(baths_name29)

print(len(baths_name29))
# Out:
# ['1 bath', '1.5 baths', '2.5 baths', '1.5 baths', '1 bath', '2.5 baths', '2 baths', '1 bath', '2 baths', '1 bath', '1.5 baths', '1 bath', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '2 baths', '2.5 baths', '2 baths', '1.5 baths', '2 baths', '4 baths', '2 baths', '2.5 baths', '2.5 baths', '1 bath', '2.5 baths', '2 baths', '1.5 baths', '2 baths', '2 baths', '2 baths', '1 bath', '1 bath', '1 bath', '1.5 baths', '2 baths', '1 bath', '2 baths', '1 bath', '1.5 baths', '2.5 baths', '1.5 baths', '1 bath', '2.5 baths', '2 baths', '1 bath', '2 baths', '1 bath', '1.5 baths', '1 bath', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '2 baths', '2.5 baths', '2 baths', '1.5 baths', '2 baths', '4 baths', '2 baths', '2.5 baths', '2.5 baths', '1 bath', '2.5 baths', '2 baths', '1.5 baths', '2 baths', '2 baths', '2 baths', '1 bath', '1 bath', '1 bath', '1.5 baths', '2 baths', '1 bath', '2 baths', '1 bath', '1.5 baths', '2.5 baths', '1.5 baths', '1 bath', '2.5 baths', '2 baths', '1 bath', 
# ...

# %%
sqft_name29=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag29 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag29:
        sqft_name29.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name22)

print(len(price_name22))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-ed6301fa4af4> in <module>
#      12     first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
#      13     first_button.click()
# ---> 14 print(price_name22)
#      15
#      16 print(len(price_name22))
#
# NameError: name 'price_name22' is not defined

# %%
ppsqft_name29=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag29 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag29:
        ppsqft_name29.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name29)

print(len(price_name29))
# Out:
# ['$290,000', '$79,900', '$99,900', '$275,000', '$155,000', '$140,000', '$395,000', '$107,500', '$220,000', '$235,000', '$200,000', '$259,000', '$60,000', '$44,000', '$116,000', '$42,000', '$419,000', '$129,000', '$465,000', '$50,000', '$50,000', '$175,000', '$1,250,000', '$285,000', '$275,000', '$219,000', '$129,000', '$385,000', '$250,000', '$169,900', '$319,900', '$499,000', '$190,000', '$130,000', '$224,900', '$79,500', '$395,000', '$299,999', '$219,000', '$445,000', '$290,000', '$79,900', '$99,900', '$275,000', '$155,000', '$140,000', '$395,000', '$107,500', '$220,000', '$235,000', '$200,000', '$259,000', '$60,000', '$44,000', '$116,000', '$42,000', '$419,000', '$129,000', '$465,000', '$50,000', '$50,000', '$175,000', '$1,250,000', '$285,000', '$275,000', '$219,000', '$129,000', '$385,000', '$250,000', '$169,900', '$319,900', '$499,000', '$190,000', '$130,000', '$224,900', '$79,500', '$395,000', '$299,999', '$219,000', '$445,000', '$290,000', '$79,900', '$99,900', '$275,000', '$1
# ...

# %%
print(len(address_name29),len(price_name29),len(beds_name29),len(baths_name29),len(sqft_name29),len(ppsqft_name29))
# Out:
# 120 120 120 120 120 120

# %%
del ppsqft_name29[120:123]

# %%
import pandas as pd
df29=pd.DataFrame({'Address':address_name29,'Price':price_name29,'Beds':beds_name29,'Baths':baths_name29,'Total sqft':sqft_name29,'Price per sqft':ppsqft_name29})
df29
# Out:
#                                             Address     Price    Beds  \
# 0             5400 Park Ave #305, Memphis, TN 38119  $290,000   1 bed
# 1            2263 Young Ave #204, Memphis, TN 38104   $79,900  3 beds
# 2    4771 Audubon View Cir #3005, Memphis, TN 38117   $99,900  2 beds
# 3           2195 Poplar Ave #203, Memphis, TN 38104  $275,000  2 beds
# 4            1118 Poplar Ave #11, Memphis, TN 38105  $155,000   1 bed
# ..                                              ...       ...     ...
# 115      3007 Walnut Grove Rd #1, Memphis, TN 38111   $79,500  2 beds
# 116    505 Tennessee St Unit RG6, Memphis, TN 38103  $395,000   1 bed
# 117      113 Harbor Town Sq #201, Memphis, TN 38103  $299,999  2 beds
# 118          408 S Front St #309, Memphis, TN 38103  $219,000   1 bed
# 119   591 Lexington Club Ct #202, Memphis, TN 38117  $445,000  2 beds
#
#          Baths Total sqft Price per sqft
# 0       1 bath          —           $242
# 1    1.5 baths          —            $57
# ...

# %%
df29.to_csv('file29.csv')

# %%
---------------Tucson homes----------

# %%
address_name30=[]
price_name30=[]
beds_name30=[]
baths_name30=[]
sqft_name30=[]
ppsqft_name30=[]

# %%
address_name30=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag30 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag30:
        address_name30.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name30)

print(len(address_name30))
# Out:
# ['', '55 N Cherry Ave #102, Tucson, AZ 85719', '2 Bedroom 2 Bath Plan, Tucson, AZ 85718', '1 Bedroom + Den Plan, Tucson, AZ 85718', '1 Bedroom Plan, Tucson, AZ 85718', '1001 E 17th St #107, Tucson, AZ 85719', '446 N Campbell Ave #1302, Tucson, AZ 85719', '446 N Campbell Ave #1208, Tucson, AZ 85719', '6451 N Tierra De Las Catalinas #66, Tucson, AZ 85718', '6510 N Tierra De Las Catalinas #83, Tucson, AZ 85718', '101 S Players Club Dr #24103, Tucson, AZ 85745', '101 S Players Club #27201 Dr, Tucson, AZ 85745', '2414 E Blue Diamond Dr, Tucson, AZ 85718', '2801 N Columbus Blvd #7, Tucson, AZ 85712', '941 N Euclid Ave #221, Tucson, AZ 85719', '6352 N Barcelona Ln #108, Tucson, AZ 85704', '451 W Yucca Ct #216, Tucson, AZ 85704', '441 W Yucca Ct #209, Tucson, AZ 85704', '6341 N Barcelona Ct #809, Tucson, AZ 85704', '6325 N Barcelona Ln #707, Tucson, AZ 85704', '6325 N Barcelona Ln #708, Tucson, AZ 85704', '6365 N Barcelona Ln #422, Tucson, AZ 85704', '471 W Yucca Ct #321, Tucson, AZ 85704', 
# ...

# %%
price_name30=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag30 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag30:
        price_name30.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name30)

print(len(price_name30))
# Out:
# ['', '$165,000', '$379,900', '$314,900', '$284,900', '$287,500', '$565,000', '$499,999', '$325,000', '$299,900', '$269,000', '$275,000', '$475,000', '$180,000', '$310,000', '$158,000', '$134,900', '$134,900', '$115,000', '$140,000', '$145,000', '$159,900', '$147,000', '$115,000', '$139,000', '$135,000', '$134,000', '$349,900', '$250,000', '$200,000', '$251,900', '$158,000', '$160,000', '$155,000', '$200,000', '$425,000', '$259,900', '$145,000', '$205,000', '$349,000', '$353,000', '', '$165,000', '$379,900', '$314,900', '$284,900', '$287,500', '$565,000', '$499,999', '$325,000', '$299,900', '$269,000', '$275,000', '$475,000', '$180,000', '$310,000', '$158,000', '$134,900', '$134,900', '$115,000', '$140,000', '$145,000', '$159,900', '$147,000', '$115,000', '$139,000', '$135,000', '$134,000', '$349,900', '$250,000', '$200,000', '$251,900', '$158,000', '$160,000', '$155,000', '$200,000', '$425,000', '$259,900', '$145,000', '$205,000', '$349,000', '$353,000', '', '$165,000', '$379,900', '
# ...

# %%
beds_name30=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag30 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag30:
        beds_name30.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(beds_name30)

print(len(beds_name30))
# Out:
# ['', '1 bed', '2 beds', '1 bed', '1 bed', '0 beds', '2 beds', '3 beds', '1 bed', '1 bed', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '1 bed', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '4 beds', '2 beds', '1 bed', '1 bed', '2 beds', '2 beds', '', '1 bed', '2 beds', '1 bed', '1 bed', '0 beds', '2 beds', '3 beds', '1 bed', '1 bed', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '1 bed', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '3 beds', '2 beds', '1 bed', '2 beds', '2 beds', '2 beds', '2 beds', '2 beds', '4 beds', '2 beds', '1 bed', '1 bed', '2 beds', '2 beds', '', '1 bed', '2 beds', '1 bed', '1 bed', '0 beds', '2 beds', '3 beds', '1 bed', '1 bed', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '3 beds', '2 beds', '2 beds', '1 bed', '2 beds', '2 beds', '1 bed', '2 b
# ...

# %%
baths_name30=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag30 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag30:
        baths_name30.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(baths_name30)

print(len(baths_name30))
# Out:
# ['', '1 bath', '2 baths', '1 bath', '1 bath', '1 bath', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '2.5 baths', '1 bath', '1.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '1 bath', '1.5 baths', '1 bath', '2 baths', '1 bath', '1 bath', '1 bath', '1 bath', '2 baths', '2 baths', '1 bath', '2 baths', '1.5 baths', '1.5 baths', '2 baths', '1.5 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '', '1 bath', '2 baths', '1 bath', '1 bath', '1 bath', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '2.5 baths', '1 bath', '1.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '1 bath', '1.5 baths', '1 bath', '2 baths', '1 bath', '1 bath', '1 bath', '1 bath', '2 baths', '2 baths', '1 bath', '2 baths', '1.5 baths', '1.5 baths', '2 baths', '1.5 baths', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2 baths', '', '1 bath', '2 baths', '1 bath', '1 bath', '1 bath', '2.5 baths', '2 baths', '1 bath', '1 bath', '2 baths', '2 ba
# ...

# %%
sqft_name30=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag30 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag30:
        sqft_name30.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(sqft_name30)

print(len(sqft_name30))
# Out:
# ['579', '1,074', '850', '765', '642', '1,546', '1,166', '913', '938', '1,005', '1,005', '1,811', '816', '1,086', '1,300', '912', '912', '672', '912', '912', '672', '960', '672', '912', '912', '912', '1,515', '1,014', '753', '991', '957', '957', '957', '1,120', '2,592', '1,094', '706', '1,001', '1,454', '1,048', '945', '579', '1,074', '850', '765', '642', '1,546', '1,166', '913', '938', '1,005', '1,005', '1,811', '816', '1,086', '1,300', '912', '912', '672', '912', '912', '672', '960', '672', '912', '912', '912', '1,515', '1,014', '753', '991', '957', '957', '957', '1,120', '2,592', '1,094', '706', '1,001', '1,454', '1,048', '945', '579', '1,074', '850', '765', '642', '1,546', '1,166', '913', '938', '1,005', '1,005', '1,811', '816', '1,086', '1,300', '912', '912', '672', '912', '912', '672', '960', '672', '912', '912', '912', '1,515', '1,014', '753', '991', '957', '957', '957', '1,120', '2,592', '1,094', '706', '1,001', '1,454', '1,048', '945']
# 123

# %%
ppsqft_name30=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag30 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag30:
        ppsqft_name30.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name30)

print(len(price_name30))
# Out:
# ['', '$165,000', '$379,900', '$314,900', '$284,900', '$287,500', '$565,000', '$499,999', '$325,000', '$299,900', '$269,000', '$275,000', '$475,000', '$180,000', '$310,000', '$158,000', '$134,900', '$134,900', '$115,000', '$140,000', '$145,000', '$159,900', '$147,000', '$115,000', '$139,000', '$135,000', '$134,000', '$349,900', '$250,000', '$200,000', '$251,900', '$158,000', '$160,000', '$155,000', '$200,000', '$425,000', '$259,900', '$145,000', '$205,000', '$349,000', '$353,000', '', '$165,000', '$379,900', '$314,900', '$284,900', '$287,500', '$565,000', '$499,999', '$325,000', '$299,900', '$269,000', '$275,000', '$475,000', '$180,000', '$310,000', '$158,000', '$134,900', '$134,900', '$115,000', '$140,000', '$145,000', '$159,900', '$147,000', '$115,000', '$139,000', '$135,000', '$134,000', '$349,900', '$250,000', '$200,000', '$251,900', '$158,000', '$160,000', '$155,000', '$200,000', '$425,000', '$259,900', '$145,000', '$205,000', '$349,000', '$353,000', '', '$165,000', '$379,900', '
# ...

# %%
print(len(address_name30),len(price_name30),len(beds_name30),len(baths_name30),len(sqft_name30),len(ppsqft_name30))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df30=pd.DataFrame({'Address':address_name30,'Price':price_name30,'Beds':beds_name30,'Baths':baths_name30,'Total sqft':sqft_name30,'Price per sqft':ppsqft_name30})
df30
# Out:
#                                               Address     Price    Beds  \
# 0
# 1              55 N Cherry Ave #102, Tucson, AZ 85719  $165,000   1 bed
# 2             2 Bedroom 2 Bath Plan, Tucson, AZ 85718  $379,900  2 beds
# 3              1 Bedroom + Den Plan, Tucson, AZ 85718  $314,900   1 bed
# 4                    1 Bedroom Plan, Tucson, AZ 85718  $284,900   1 bed
# ..                                                ...       ...     ...
# 118        7778 E Via Ventana Norte, Tucson, AZ 85750  $259,900  2 beds
# 119  2601 W Broadway Blvd Unit E545, Tucson, AZ 85745  $145,000   1 bed
# 120               3032 E 6th St #69, Tucson, AZ 85716  $205,000   1 bed
# 121              2820 E 6th St #214, Tucson, AZ 85716  $349,000  2 beds
# 122              2820 E 6th St #206, Tucson, AZ 85716  $353,000  2 beds
#
#        Baths Total sqft Price per sqft
# 0                   579           $285
# 1     1 bath      1,074           $354
# 2    2 baths        850           $370
# ...

# %%
df30.to_csv('file30.csv')

# %%
-------------Anchorage homes ----------

# %%
address_name31=[]
price_name31=[]
beds_name31=[]
baths_name31=[]
sqft_nam31=[]
ppsqft_name31=[]

# %%
address_name31=[]
## scraping address
start=0
end=3
for page in range(start,end):
    address_tag31 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag31:
        address_name31.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()

print(address_name31)

print(len(address_name31))
# Out:
# ['', '7061 Weimer St #3, Anchorage, AK 99502', '5569 Big Bear Way #22, Anchorage, AK 99504', '7005 Fairweather Dr #3, Anchorage, AK 99518', '8101 Peck Ave Unit C22, Anchorage, AK 99504', '8101 Peck Ave Unit C24, Anchorage, AK 99504', '8050 Pioneer Dr #1301, Anchorage, AK 99504', '237 Cook Inlet Loop Unit 2C, Anchorage, AK 99501', '316 Shageluk St, Anchorage, AK 99504', '318 Shageluk St, Anchorage, AK 99504', '6926 Fairweather Dr Unit 2-2-4, Anchorage, AK 99518', '11435 Discovery View Dr #64, Anchorage, AK 99515', '5701 Sapphire Loop, Anchorage, AK 99504', '9371 Blackberry #1, Anchorage, AK 99502', '275 Creekside St #4, Anchorage, AK 99504', '8050 Pioneer Dr #102, Anchorage, AK 99504', '4345 Constellation Dr #16, Anchorage, AK 99517', '2602 Curlew Cir, Anchorage, AK 99502', '10283 Jamestown Dr Unit i-803, Anchorage, AK 99507', '355 Donna Dr #5, Anchorage, AK 99504', '305 Donna Dr #21, Anchorage, AK 99504', '2200 Minerva Way Unit B3, Anchorage, AK 99515', '8101 Peck Ave Unit A1, Anchor
# ...

# %%
price_name31=[]
## scraping price
start=0
end=3
for page in range(start,end):
    price_tag31 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag31:
        price_name31.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name31)

print(len(price_name31))
# Out:
# ['', '$75,000', '$449,000', '$329,500', '$189,000', '$189,000', '$279,000', '$379,999', '$437,000', '$435,000', '$334,900', '$595,000', '$329,500', '$189,900', '$275,000', '$280,000', '$270,000', '$595,000', '$158,000', '$169,000', '$160,000', '$129,000', '$189,000', '$295,000', '$229,000', '$115,000', '$139,900', '$339,900', '$285,000', '$460,000', '$312,000', '$130,000', '$428,900', '$142,500', '$159,000', '$485,000', '$329,000', '$495,000', '$149,900', '$779,000', '$349,500', '', '$75,000', '$449,000', '$329,500', '$189,000', '$189,000', '$279,000', '$379,999', '$437,000', '$435,000', '$334,900', '$595,000', '$329,500', '$189,900', '$275,000', '$280,000', '$270,000', '$595,000', '$158,000', '$169,000', '$160,000', '$129,000', '$189,000', '$295,000', '$229,000', '$115,000', '$139,900', '$339,900', '$285,000', '$460,000', '$312,000', '$130,000', '$428,900', '$142,500', '$159,000', '$485,000', '$329,000', '$495,000', '$149,900', '$779,000', '$349,500', '', '$75,000', '$449,000', '$32
# ...

# %%
beds_name31=[]
## scraping beds
start=0
end=3
for page in range(start,end):
    beds_tag31 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag31:
        beds_name31.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(beds_name31)

print(len(beds_name31))
# Out:
# ['', '1 bed', '4 beds', '3 beds', '2 beds', '2 beds', '2 beds', '2 beds', '3 beds', '3 beds', '3 beds', '3 beds', '3 beds', '2 beds', '3 beds', '3 beds', '2 beds', '3 beds', '1 bed', '2 beds', '2 beds', '1 bed', '2 beds', '3 beds', '2 beds', '1 bed', '1 bed', '2 beds', '2 beds', '2 beds', '4 beds', '2 beds', '4 beds', '1 bed', '2 beds', '2 beds', '3 beds', '1 bed', '2 beds', '2 beds', '2 beds', '', '1 bed', '4 beds', '3 beds', '2 beds', '2 beds', '2 beds', '2 beds', '3 beds', '3 beds', '3 beds', '3 beds', '3 beds', '2 beds', '3 beds', '3 beds', '2 beds', '3 beds', '1 bed', '2 beds', '2 beds', '1 bed', '2 beds', '3 beds', '2 beds', '1 bed', '1 bed', '2 beds', '2 beds', '2 beds', '4 beds', '2 beds', '4 beds', '1 bed', '2 beds', '2 beds', '3 beds', '1 bed', '2 beds', '2 beds', '2 beds', '', '1 bed', '4 beds', '3 beds', '2 beds', '2 beds', '2 beds', '2 beds', '3 beds', '3 beds', '3 beds', '3 beds', '3 beds', '2 beds', '3 beds', '3 beds', '2 beds', '3 beds', '1 bed', '2 beds', '2 beds', '
# ...

# %%
baths_name31=[]
## scraping baths
start=0
end=3
for page in range(start,end):
    baths_tag31 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag31:
        baths_name31.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(baths_name31)

print(len(baths_name31))
# Out:
# ['', '1 bath', '3.5 baths', '2 baths', '1.5 baths', '1.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2 baths', '1 bath', '2 baths', '2.5 baths', '2 baths', '2.5 baths', '1 bath', '1 bath', '1 bath', '1 bath', '1.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '2.5 baths', '1 bath', '2.5 baths', '2 baths', '1 bath', '2.5 baths', '1 bath', '1 bath', '2.5 baths', '2.5 baths', '1 bath', '1 bath', '2 baths', '2 baths', '', '1 bath', '3.5 baths', '2 baths', '1.5 baths', '1.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2.5 baths', '2 baths', '1 bath', '2 baths', '2.5 baths', '2 baths', '2.5 baths', '1 bath', '1 bath', '1 bath', '1 bath', '1.5 baths', '2 baths', '1 bath', '1 bath', '1 bath', '2.5 baths', '1 bath', '2.5 baths', '2 baths', '1 bath', '2.5 baths', '1 bath', '1 bath', '2.5 baths', '2.5 baths', '1 bath', '1 bath', '2 baths', '2 baths', '', '1 bath', '3.5 baths', '2 baths', '1.5 baths', '1.5 baths', '2.5 ba
# ...

# %%
sqft_name31=[]
## scraping sqft
start=0
end=3
for page in range(start,end):
    sqft_tag31 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag31:
        sqft_name31.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name31)

print(len(price_name31))
# Out:
# ['', '$75,000', '$449,000', '$329,500', '$189,000', '$189,000', '$279,000', '$379,999', '$437,000', '$435,000', '$334,900', '$595,000', '$329,500', '$189,900', '$275,000', '$280,000', '$270,000', '$595,000', '$158,000', '$169,000', '$160,000', '$129,000', '$189,000', '$295,000', '$229,000', '$115,000', '$139,900', '$339,900', '$285,000', '$460,000', '$312,000', '$130,000', '$428,900', '$142,500', '$159,000', '$485,000', '$329,000', '$495,000', '$149,900', '$779,000', '$349,500', '', '$75,000', '$449,000', '$329,500', '$189,000', '$189,000', '$279,000', '$379,999', '$437,000', '$435,000', '$334,900', '$595,000', '$329,500', '$189,900', '$275,000', '$280,000', '$270,000', '$595,000', '$158,000', '$169,000', '$160,000', '$129,000', '$189,000', '$295,000', '$229,000', '$115,000', '$139,900', '$339,900', '$285,000', '$460,000', '$312,000', '$130,000', '$428,900', '$142,500', '$159,000', '$485,000', '$329,000', '$495,000', '$149,900', '$779,000', '$349,500', '', '$75,000', '$449,000', '$32
# ...

# %%
ppsqft_name31=[]
## scraping price per sqft
start=0
end=3
for page in range(start,end):
    ppsqft_tag31 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag31:
        ppsqft_name31.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    first_button.click()
print(price_name31)

print(len(price_name31))
# Out:
# ['', '$75,000', '$449,000', '$329,500', '$189,000', '$189,000', '$279,000', '$379,999', '$437,000', '$435,000', '$334,900', '$595,000', '$329,500', '$189,900', '$275,000', '$280,000', '$270,000', '$595,000', '$158,000', '$169,000', '$160,000', '$129,000', '$189,000', '$295,000', '$229,000', '$115,000', '$139,900', '$339,900', '$285,000', '$460,000', '$312,000', '$130,000', '$428,900', '$142,500', '$159,000', '$485,000', '$329,000', '$495,000', '$149,900', '$779,000', '$349,500', '', '$75,000', '$449,000', '$329,500', '$189,000', '$189,000', '$279,000', '$379,999', '$437,000', '$435,000', '$334,900', '$595,000', '$329,500', '$189,900', '$275,000', '$280,000', '$270,000', '$595,000', '$158,000', '$169,000', '$160,000', '$129,000', '$189,000', '$295,000', '$229,000', '$115,000', '$139,900', '$339,900', '$285,000', '$460,000', '$312,000', '$130,000', '$428,900', '$142,500', '$159,000', '$485,000', '$329,000', '$495,000', '$149,900', '$779,000', '$349,500', '', '$75,000', '$449,000', '$32
# ...

# %%
print(len(address_name31),len(price_name31),len(beds_name31),len(baths_name31),len(sqft_name31),len(ppsqft_name31))
# Out:
# 123 123 123 123 123 123

# %%
import pandas as pd
df31=pd.DataFrame({'Address':address_name31,'Price':price_name31,'Beds':beds_name31,'Baths':baths_name31,'Total sqft':sqft_name31,'Price per sqft':ppsqft_name31})
df31
# Out:
#                                                Address     Price    Beds  \
# 0
# 1               7061 Weimer St #3, Anchorage, AK 99502   $75,000   1 bed
# 2           5569 Big Bear Way #22, Anchorage, AK 99504  $449,000  4 beds
# 3          7005 Fairweather Dr #3, Anchorage, AK 99518  $329,500  3 beds
# 4          8101 Peck Ave Unit C22, Anchorage, AK 99504  $189,000  2 beds
# ..                                                 ...       ...     ...
# 118       6915 Gemini Dr Unit A-2, Anchorage, AK 99504  $329,000  3 beds
# 119  282 Crystal Mountain Rd Unit 101S, Girdwood, A...  $495,000   1 bed
# 120       2632 Glacier St Unit B7, Anchorage, AK 99508  $149,900  2 beds
# 121             604 Ocean Pl #102, Anchorage, AK 99501  $779,000  2 beds
# 122  11408 Conquistador Dr Unit C, Eagle River, AK ...  $349,500  2 beds
#
#          Baths Total sqft Price per sqft
# 0                     499           $150
# 1       1 bath      2,142           $210
# ...

# %%
df31.to_csv('file31.csv')

# %%
address_name9=[]
price_name9=[]
beds_name9=[]
baths_name9=[]
sqft_name9=[]
ppsqft_name9=[]

# %%
address_name9=[]
## scraping address
start=4
end=6
for page in range(start,end):
    address_tag9 = driver.find_elements(By.XPATH,'//div[@class="bp-Homecard__Address flex align-center color-text-primary font-body-xsmall-compact"]')
    for i in address_tag9:
        address_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    #first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
    #first_button.click()

#print(address_name9)

#print(len(address_name9))

# %%
first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
first_button.click()

# %%
print(address_name9)

print(len(address_name9))
# Out:
# ['', '2240 W Berridge Ln, Phoenix, AZ 85015', '3107 S 74th Ln, Phoenix, AZ 85043', '2434 E Cathedral Rock Dr, Phoenix, AZ 85048', '3434 E Baseline Rd #259, Phoenix, AZ 85042', '6502 N Central Ave Unit B103, Phoenix, AZ 85012', '10042 N 25th St, Phoenix, AZ 85028', '303 E South Mountain Ave #60, Phoenix, AZ 85042', '6334 W Latona Rd, Laveen, AZ 85339', '2230 E Belmont Ave, Phoenix, AZ 85020', '1045 E Cloud Rd, Phoenix, AZ 85086', '9020 W Highland Ave #111, Phoenix, AZ 85037', '8050 N 11th Pl, Phoenix, AZ 85020', '2410 N 40th Street St, Phoenix, AZ 85008', '4142 W Wagon Wheel Dr, Phoenix, AZ 85051', '3201 E Nisbet Rd, Phoenix, AZ 85032', '4706 E Piedmont Rd, Phoenix, AZ 85044', '16849 N 38th Ln, Phoenix, AZ 85053', '1326 N Central Ave #413, Phoenix, AZ 85004', '41432 N Bent Creek Way, Phoenix, AZ 85086', '6404 W Prickly Pear Trl, Phoenix, AZ 85083', '3429 E Poinsettia Dr, Phoenix, AZ 85028', '8821 W Albeniz Pl, Tolleson, AZ 85353', '10814 N 16 Ave, Phoenix, AZ 85029', '1542 W Sahuaro D
# ...

# %%
price_name20=[]
## scraping price
start=4
end=6
for page in range(start,end):
    price_tag20 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Price--value"]')
    for i in price_tag20:
        price_name20.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    
print(price_name20)

print(len(price_name20))
# Out:
# ['', '$480,000', '$440,000', '$535,000', '$289,950', '$595,000', '$820,000', '$100,000', '$539,995', '$1,575,000', '$1,200,000', '$235,000', '$535,000', '$629,000', '$317,900', '$355,000', '$420,000', '$499,900', '$745,000', '$510,000', '$467,000', '$685,000', '$409,280', '$899,500', '$899,500', '$875,000', '$181,000', '$399,950', '$450,000', '$1,050,000', '$1,250,000', '$105,000', '$685,250', '$650,000', '$194,900', '$365,000', '$3,250,000', '$415,000', '$4,150,000', '$715,900', '$423,500', '', '$360,000', '$424,900', '$519,000', '$278,900', '$579,900', '$410,000', '$1,200,000', '$272,000', '$274,900', '$365,000', '$715,000', '$410,000', '$600,000', '$715,000', '$679,000', '$875,000', '$679,500', '$450,000', '$224,999', '$379,900', '$1,029,715', '$469,999', '$1,100,000', '$979,000', '$375,000', '$682,275', '$997,914', '$490,000', '$539,000', '$539,000', '$350,000', '$284,000', '$559,900', '$449,000', '$425,000', '$219,400', '$1,850,000', '$485,000', '$340,000', '$374,900']
# 82

# %%
first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
first_button.click()

# %%
beds_name9=[]
## scraping beds
start=4
end=6
for page in range(start,end):
    beds_tag9 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--beds text-nowrap"]')
    for i in beds_tag9:
        beds_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    
print(beds_name9)

print(len(beds_name9))
# Out:
# ['', '4 beds', '3 beds', '4 beds', '2 beds', '2 beds', '3 beds', '2 beds', '5 beds', '3 beds', '4 beds', '2 beds', '4 beds', '3 beds', '3 beds', '2 beds', '2 beds', '3 beds', '2 beds', '3 beds', '3 beds', '4 beds', '4 beds', '— beds', '— beds', '4 beds', '1 bed', '4 beds', '5 beds', '4 beds', '4 beds', '2 beds', '3 beds', '5 beds', '2 beds', '3 beds', '4 beds', '2 beds', '3 beds', '3 beds', '3 beds', '', '3 beds', '2 beds', '3 beds', '2 beds', '3 beds', '4 beds', '4 beds', '2 beds', '3 beds', '2 beds', '3 beds', '5 beds', '3 beds', '3 beds', '3 beds', '4 beds', '3 beds', '4 beds', '3 beds', '1 bed', '3 beds', '3 beds', '4 beds', '3 beds', '4 beds', '4 beds', '4 beds', '3 beds', '3 beds', '5 beds', '3 beds', '2 beds', '3 beds', '4 beds', '3 beds', '3 beds', '4 beds', '3 beds', '3 beds', '4 beds']
# 82

# %%
first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
first_button.click()

# %%
baths_name9=[]
## scraping baths
start=4
end=6
for page in range(start,end):
    baths_tag9 = driver.find_elements(By.XPATH,'//span[@class="bp-Homecard__Stats--baths text-nowrap"]')
    for i in baths_tag9:
        baths_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    
print(baths_name9)

print(len(baths_name9))
# Out:
# ['', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '1 bath', '3 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '1 bath', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '— baths', '— baths', '2 baths', '1 bath', '3 baths', '3 baths', '3 baths', '3.5 baths', '2 baths', '3 baths', '3 baths', '2 baths', '1 bath', '4.5 baths', '2 baths', '3.5 baths', '2 baths', '2 baths', '', '2.5 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '3.5 baths', '1.5 baths', '1.75 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2 baths', '2.5 baths', '3 baths', '2 baths', '2 baths', '1 bath', '1 bath', '2.5 baths', '2 baths', '3 baths', '2 baths', '2 baths', '3.5 baths', '3.5 baths', '1 bath', '2.5 baths', '3 baths', '2 baths', '2 baths', '2 baths', '2.5 baths', '2 baths', '1.5 baths', '4 baths', '2 baths', '2 baths', '2 baths']
# 82

# %%
first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
first_button.click()

# %%
table=driver.find_element(By.XPATH,"/html/body/div[1]/div[8]/div[1]/div[2]/div[1]/div[2]/div/div/div/div[2]/div[2]/ul/li[2]/span")
table.click()

# %%
sqft_name9=[]
## scraping sqft
start=4
end=6
for page in range(start,end):
    sqft_tag9 = driver.find_elements(By.XPATH,'//td[@class="column column_6 col_sqft"]')
    for i in sqft_tag9:
        sqft_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    
print(sqft_name9)

print(len(sqft_name9))
# Out:
# ['1,843', '1,907', '1,817', '944', '1,444', '2,250', '896', '2,689', '2,313', '2,874', '803', '1,900', '1,999', '1,178', '854', '1,195', '1,829', '1,491', '2,082', '1,571', '2,112', '1,633', '—', '—', '2,284', '616', '2,325', '2,339', '2,611', '2,926', '784', '2,371', '2,958', '1,024', '1,531', '5,249', '1,059', '3,325', '1,769', '1,093', '1,762', '1,538', '1,259', '1,261', '863', '2,313', '2,146', '2,472', '908', '1,216', '1,056', '1,657', '—', '1,650', '1,963', '1,942', '2,496', '2,045', '2,270', '1,005', '1,069', '2,695', '1,790', '2,980', '1,994', '1,609', '2,511', '2,625', '825', '2,501', '2,798', '1,209', '995', '1,627', '2,284', '1,358', '1,200', '3,580', '1,448', '1,256', '1,680', '1,762']
# 82

# %%
first_button=driver.find_element(By.XPATH,'//a[@class="bp-Button PageNumbers__page Pagination__button bp-Button__type--ghost bp-Button__size--compact"]')
first_button.click()

# %%
ppsqft_name9=[]
## scraping price per sqft
start=4
end=6
for page in range(start,end):
    ppsqft_tag9 = driver.find_elements(By.XPATH,'//td[@class="column column_7 col_ppsqft"]')
    for i in ppsqft_tag9:
        ppsqft_name9.append(i.text)
    next_button=driver.find_element(By.XPATH,'//button[@class="bp-Button PageArrow clickable Pagination__button PageArrow__direction--next bp-Button__type--ghost bp-Button__size--compact bp-Button__icon-only"]')
    next_button.click()
    time.sleep(3)
    
print(ppsqft_name9)

print(len(ppsqft_name9))
# Out:
# ['$260', '$231', '$294', '$307', '$412', '$364', '$112', '$201', '$681', '$418', '$293', '$282', '$315', '$270', '$416', '$351', '$273', '$500', '$245', '$297', '$324', '$251', '—', '—', '$383', '$294', '$172', '$192', '$402', '$427', '$134', '$289', '$220', '$190', '$238', '$619', '$392', '$1,248', '$405', '$387', '$293', '$234', '$337', '$412', '$323', '$251', '$191', '$485', '$300', '$226', '$346', '$432', '—', '$364', '$364', '$350', '$351', '$332', '$198', '$224', '$355', '$382', '$263', '$369', '$491', '$233', '$272', '$380', '$594', '$216', '$193', '$289', '$285', '$344', '$197', '$313', '$183', '$517', '$335', '$271', '$223', '$293']
# 82

# %%
print(len(address_name9),len(price_name20),len(beds_name9),len(baths_name9),len(sqft_name9),len(ppsqft_name9))
# Out:
# 82 82 82 82 82 82

# %%
#del ppsqft_name9[120:123]

# %%
import pandas as pd
df51=pd.DataFrame({'Address':address_name9,'Price':price_name20,'Beds':beds_name9,'Baths':baths_name9,'Total sqft':sqft_name9,'Price per sqft':ppsqft_name9})
df51
# Out:
#                                          Address       Price    Beds  \
# 0
# 1          2240 W Berridge Ln, Phoenix, AZ 85015    $480,000  4 beds
# 2              3107 S 74th Ln, Phoenix, AZ 85043    $440,000  3 beds
# 3    2434 E Cathedral Rock Dr, Phoenix, AZ 85048    $535,000  4 beds
# 4     3434 E Baseline Rd #259, Phoenix, AZ 85042    $289,950  2 beds
# ..                                           ...         ...     ...
# 77  3605 W Bethany Home Rd #2, Phoenix, AZ 85019    $219,400  3 beds
# 78       6602 E Corrine Dr, Scottsdale, AZ 85254  $1,850,000  4 beds
# 79       1219 E Silverwood Dr, Phoenix, AZ 85048    $485,000  3 beds
# 80          17818 N 45th Ave, Glendale, AZ 85308    $340,000  3 beds
# 81             4029 N 75th Dr, Phoenix, AZ 85033    $374,900  4 beds
#
#         Baths Total sqft Price per sqft
# 0                  1,843           $260
# 1     2 baths      1,907           $231
# 2     2 baths      1,817           $294
# 3     2 baths        944           $307
# ...

# %%
df51.to_csv('file51.csv')

# %%
import pandas as pd
df=pd.read_csv("C:/Users/Kirti/Flip robo/1 capstone data/real_estate_data.csv",encoding='latin1')

# %%
df
# Out:
#       Srno                                            Address buy total price  \
# 0        1            1813 24th Ave Unit A, Seattle, WA 98122        5,35,000
# 1        2            9518 Interlake Ave N, Seattle, WA 98103        8,50,000
# 2        3            1817 24th Ave Unit A, Seattle, WA 98122        7,80,000
# 3        4                 2206 28th Ave W, Seattle, WA 98199        4,25,000
# 4        5  912 Martin Luther King Jr Way S, Seattle, WA 9...        4,88,500
# ...    ...                                                ...             ...
# 3166  3167       3605 W Bethany Home Rd #2, Phoenix, AZ 85019        2,19,400
# 3167  3168            6602 E Corrine Dr, Scottsdale, AZ 85254       18,50,000
# 3168  3169            1219 E Silverwood Dr, Phoenix, AZ 85048        4,85,000
# 3169  3170               17818 N 45th Ave, Glendale, AZ 85308        3,40,000
# 3170  3171                  4029 N 75th Dr, Phoenix, AZ 85033        3,74,900
#
# ...

# %%
df.tail(5)
# Out:
#       Srno                                       Address buy total price  \
# 3166  3167  3605 W Bethany Home Rd #2, Phoenix, AZ 85019        2,19,400
# 3167  3168       6602 E Corrine Dr, Scottsdale, AZ 85254       18,50,000
# 3168  3169       1219 E Silverwood Dr, Phoenix, AZ 85048        4,85,000
# 3169  3170          17818 N 45th Ave, Glendale, AZ 85308        3,40,000
# 3170  3171             4029 N 75th Dr, Phoenix, AZ 85033        3,74,900
#
#      buy total price(inr) Unnamed: 4 Baths Carpet Area Price per sqft  \
# 3166          1,82,36,528          3   1.5       3,580            517
# 3167         15,37,72,000          4     4       1,448            335
# 3168          4,03,13,200          3     2       1,256            271
# 3169          2,82,60,800          3     2       1,680            223
# 3170          3,11,61,688          4     2       1,762            293
#
#      Property Type  Balcony City Status car parking Type of ownership Facing  \
# ...
